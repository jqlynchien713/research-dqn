# %% [markdown]
# # Comparisons among Algorithms

# %%
import pandas as pd
import numpy as np
import itertools
from tqdm.notebook import tqdm
import pickle

from matplotlib import pyplot as plt
import random
from datetime import datetime
import pytz

# %%
# EPS_target_rsum_x = pd.read_pickle('../Experiments Results/EPS_target_rsum_x.pkl')
VDBE_target_rsum_asid = pd.read_pickle('../Experiments Results/VDBE_target_rsum_asid.pkl')
VDBE_target_rsum_stream = pd.read_pickle('../Experiments Results/VDBE_target_rsum_stream.pkl')
# EPS_ddqn_rsum_x = pd.read_pickle('../Experiments Results/EPS_ddqn_rsum_x.pkl')
# VDBE_ddqn_rsum_asid = pd.read_pickle('../Experiments Results/VDBE_ddqn_rsum_asid.pkl')
# EPS_baseline_rsum_x = pd.read_pickle('../Experiments Results/EEPS_baseline_rsum_x2.pkl')

# %%
# plt.plot(EPS_target_rsum_x_positive.ep_score_list, label='hit')
# plt.plot(EPS_target_rsum_x_positive.avg_hit_list, label='res')
# plt.plot(dqn_test.win_list, label='Score')
# plt.plot(res, label='Score')
# for l in re:
#   print(l)
#   plt.axvline(x = l, color = 'red')
# plt.plot(pd.Series(EPS_target_rsum_x['score_list']).rolling(30).mean(), label='Random-based DQN')
plt.plot(pd.Series(VDBE_target_rsum_asid['score_list']).rolling(30).mean(), label='VDBE with buyer-index')
plt.plot(pd.Series(VDBE_target_rsum_stream['score_list']).rolling(30).mean(), label='VDBE with stream-index')
# plt.plot(pd.Series(EPS_ddqn_rsum_x['score_list']).rolling(30).mean(), label='DDQN(EPS)')
# plt.plot(pd.Series(VDBE_ddqn_rsum_asid['score_list']).rolling(30).mean(), label='VDBE DDQN')
# plt.plot(pd.Series(EPS_baseline_rsum_x['score_list']).rolling(30).mean(), label='EPS_baseline_rsum_x')
plt.xlabel('100 step')
plt.ylabel('Score')
plt.title('Result Comparison on VDBE Indexes')
# plt.ylim([0.4, 0.6])
plt.legend()

# %%
EPS_target_rsum_x.keys()
# Out:
# dict_keys(['win_list', 'score_list', 'fake_list', 'loss_list', 'EE'])
