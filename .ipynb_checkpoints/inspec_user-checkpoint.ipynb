# %% [markdown]
# # Inspect User to Test DQN

# %%
import pandas as pd
import numpy as np

DATA = pd.read_csv('../data/6897-1y-c.csv')

## Preprocessing
### Handle Username Formats

def replace_invalid(string):
  string = string.replace('-', '')
  string = string.replace('/', '')
  string = string.replace('*', '')
  string = string.replace(' ', '')
  string = string.replace('劉德玲', '')
  return string

DATA['聯絡電話'] = DATA['聯絡電話'].apply(replace_invalid)

# %%
DATA.rename(columns={'聯絡電話':'user'}, inplace=True)

# %% [markdown]
# ---

# %%
DATA.groupby(['user']).count().describe()
# Out:
#                下單日期          商品名稱            規格            單價            數量  \
# count  11778.000000  11778.000000  11778.000000  11778.000000  11778.000000
# mean      24.488283     24.488283      8.965020     24.488283     24.488283
# std       43.672649     43.672649     16.405497     43.672649     43.672649
# min        1.000000      1.000000      0.000000      1.000000      1.000000
# 25%        4.000000      4.000000      1.000000      4.000000      4.000000
# 50%        9.000000      9.000000      4.000000      9.000000      9.000000
# 75%       26.000000     26.000000     10.000000     26.000000     26.000000
# max      765.000000    765.000000    350.000000    765.000000    765.000000
#
#                  折扣           總金額          專屬折扣            運費        信用卡手續費  \
# count  11778.000000  11778.000000  11778.000000  11778.000000  11778.000000
# mean      24.488283     24.488283     24.488283     24.488283     24.488283
# std       43.672649     43.672649     43.672649     43.672649     43.672649
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        4.000000      4.000000      4.000000      4.000000      4.000000
# 50%        9.000000      9.000000      9.000000      9.000000      9.000000
# 75%       26.000000     26.000000     26.000000     26.000000     26.000000
# max      765.000000    765.000000    765.000000    765.000000    765.000000
#
#                紅利折抵          收款金額          付款方式          運送方式           收件人  \
# count  11778.000000  11778.000000  11778.000000  11778.000000  11778.000000
# mean      24.488283     24.488283     24.488283     24.488283     24.488283
# std       43.672649     43.672649     43.672649     43.672649     43.672649
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        4.000000      4.000000      4.000000      4.000000      4.000000
# 50%        9.000000      9.000000      9.000000      9.000000      9.000000
# 75%       26.000000     26.000000     26.000000     26.000000     26.000000
# max      765.000000    765.000000    765.000000    765.000000    765.000000
#
#                寄送地址            場次         處理後名稱          商品分類
# count  11778.000000  11778.000000  11778.000000  11778.000000
# mean      24.486246     23.592800     24.488283     23.131347
# std       43.672045     42.041028     43.672649     41.265072
# min        0.000000      0.000000      1.000000      0.000000
# 25%        4.000000      3.000000      4.000000      3.000000
# 50%        9.000000      9.000000      9.000000      9.000000
# 75%       26.000000     25.000000     26.000000     24.000000
# max      765.000000    715.000000    765.000000    729.000000

# %% [markdown]
# ---

# %%
user_count = DATA.groupby(['user']).count()

uid=user_count['下單日期'].loc[user_count['下單日期'] > 9].index

DATA = DATA.loc[DATA.user.isin(uid)]

# %%
len(DATA['商品分類'].unique())
# Out:
# 226
