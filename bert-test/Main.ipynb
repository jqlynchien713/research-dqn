# %% [markdown]
# # Main Training

# %%
import pandas as pd
import numpy as np
import itertools
from tqdm.notebook import tqdm
import pickle

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from matplotlib import pyplot as plt
import warnings
from sklearn.preprocessing import LabelEncoder
import random
from datetime import datetime
import pytz

# %%
CONTEXT_REPS = pd.read_pickle('final_context.pkl')
STREAM_ITEM_DICT = pd.read_pickle('stream_item_dict.pkl')
BERT_BY_IDX_DF = pd.read_pickle('bert_by_idx_pca.pkl')
BOUGHT_DICT = pd.read_pickle('bought_dict.pkl')

# %%
CONTEXT_REPS.shape, len(STREAM_ITEM_DICT), BERT_BY_IDX_DF.shape, len(BOUGHT_DICT)
# Out:
# ((1397141, 181), 7701, (162189, 160), 79207)

# %%
USER_LIST = CONTEXT_REPS.index.get_level_values('asid').tolist()

# %%
'''
retrieve full state -> should be exported to pickle
'''
USER_ALL_STREAM_INIT = CONTEXT_REPS.describe().loc['50%']

def get_full_state(asid, user_all_streams, stream_list, i):
  # Get full state: current_state = user_stream + item_stream
  # 第一次參加直播/cold start
  # CE paper: user_interest part init with random vector
  # TODO init with random values
  #      Cold start problem
  
  #! 前一個另外處理，其他人直接黏在一起
  if (i - 1) == -1:
    user_part = USER_ALL_STREAM_INIT.copy()
    user_part.name = stream_list[i]
  else:
    user_part = user_all_streams.loc[stream_list[(i - 1)]]
  return user_part

# %%
LB_ITEMS = ['item_id'] + [f'i{x}' for x in range(160)]
INPUT_DF_COL__USR = CONTEXT_REPS.columns.to_list()
INPUT_DF_COL = INPUT_DF_COL__USR + LB_ITEMS

'''
Convert state format to model input format
'''
def get_input(input_state, current_stream):
  # Get item feats
  # STREAM_ITEM_DICT: 要拿到對的 STREAM!!!
  item_list = STREAM_ITEM_DICT[current_stream]
  item_feat = BERT_BY_IDX_DF.loc[item_list]

  # Create new df
  stream_item_feat = pd.DataFrame(columns=INPUT_DF_COL)

  # Fill in other context
  stream_item_feat = stream_item_feat.append([input_state]*len(item_list),ignore_index=True)
  
  # stream_item_feat
  stream_item_feat[LB_ITEMS] = item_feat.reset_index()
  
  return stream_item_feat.astype('float32')

# %%
'''
Generate series: whether elements in A existed in list B
A, B: List
return: pd.Series
example:
  A: [1, 2, 4, 5]
  B: [1, 2, 3, 4, 5, 6, 7]
  return: Series([1, 1, 0, 1, 1, 0, 0], index=[1, 2, 3, 4, 5, 6, 7])
'''
def gen_exist_series(A, B):
  exist_list = [int(item in A) for item in B]
  return pd.Series(exist_list, index=B)

# %%
'''
Comparison function for reward
！考慮「所有」歷史購買紀錄！！！！！！
'''
def r(a, b):
  # if a==1 and b==0: return 0 # -1 when the rule is to punish unrec-bought
  # else: 
  return a & b

def get_reward(asid, stream, action_ids):
  items = action_ids.index # 不確定 action_id 裡面是 series 還是 list
  real_bought_ids = BOUGHT_DICT[asid]
  real_bought_ids_series = gen_exist_series(real_bought_ids, items)
  
  reward_list = [r(a, b) for a, b in zip(real_bought_ids_series.values, action_ids.values)]
  return pd.Series(reward_list, index=items)

# %%
def model_predict_top10(model, input_state, current_stream):
  # Get all items
  full_input = get_input(input_state, current_stream).astype('float32')
  
  # 紀錄所有預測結果
  predicts = model.predict(full_input)
  full_input['predict'] = predicts
  actions = full_input['predict'].nlargest(10).index #['i_item_id'].to_list()
  actions = full_input.loc[actions, 'i_item_id'].values
  return actions

# %%
from sklearn.metrics.pairwise import cosine_similarity

def calculate_interest_change(current, prev):
  return cosine_similarity(current.values.reshape(1, -1), prev.values.reshape(1, -1))[0][0]

# %% [markdown]
# ## Replay

# %%
### Collecting Training Data
import pandas as pd
import numpy as np

class ReplayBuffer:
  def __init__(self, max_memory=100000, discount=.9):
    """
    Setup
    max_memory: the maximum number of experiences we want to store
    memory: a list of experiences
    discount: the discount factor for future experience
    In the memory the information whether the game ended at the state is stored seperately in a nested array
    [...
    [experience, game_over]
    [experience, game_over]
    ...]
    """
    self.max_memory = max_memory
    self.memory = list()
    self.discount = discount

  def remember(self, interest_score, states, game_over):
    # Save a state to memory
    self.memory.append([interest_score, states, game_over])
    # We don't want to store infinite memories, so if we have too many, we just delete the oldest one
    if len(self.memory) > self.max_memory:
      del self.memory[0]

  def get_batch(self, model, batch_size=10):
    # How many experiences do we have?
    len_memory = len(self.memory)

    # Calculate the number of actions that can possibly be taken in the game.
    # Actions: 0 = not recommend, 1 = recommend
    num_actions = model.output_shape[-1]

    # Dimensions of our observed states, ie, the input to our model.
    # Memory:  [
    #   [interest_score, [ [...state], action, reward, next_state_idx], game_over],
    #   [interest_score, [ [...state], action, reward, nexr_state_idx], game_over],
    #   ...
    # ]
    env_dim = len(INPUT_DF_COL)

    inputs = pd.DataFrame(columns=INPUT_DF_COL)
    targets = pd.DataFrame(columns=[0])
    
    
    print('-----start enumerating-----')   
    # We draw states to learn from randomly
    for i, idx in enumerate(np.random.randint(0, len_memory, size=min(len_memory, batch_size))):  
      print(f'--------- batch: {i} | idx: {idx} ---------')
      # Here we load one transition <s, a, r, s'> from memory
      streams, state_t, action_t, reward_t, state_tp1 = self.memory[idx][1]
      current_stream, next_stream = streams
      # state_t = state_t.astype('float32')
      game_over = self.memory[idx][2]

      '''
      修改倒入 state 的方式 input = (state - item) + item_feat
      拆掉 model_predict 成 function
      
      here should be state_t * all_items
      '''
      state_t = get_input(state_t, current_stream).astype('float32')
      print('replay#64', state_t.shape, reward_t.shape)
      # puts state into input
      inputs = pd.concat([inputs, state_t], axis=0)
      # TODO: Modify input shape 0

      # First we fill the target values with the predictions of the model.
      # They will not be affected by training (since the training loss for them is 0)
      # TODO
      '''
      每個 actions 都會被 predict 一個成績/reward
      '''

      # if the game ended, the reward is the final reward
      if game_over:  # if game_over is True
        print(f'g-reward.shape {reward_t.shape}')
        print(f'g-input.shape {inputs.shape}')
        state_t['reward'] = reward_t
        targets = pd.concat([targets, reward_t], axis=0).astype('float32')
      else:
        state_t['reward'] = model.predict(state_t).flatten()
        # 找到 action_t 們，指到 state_t 上去算 discount values
        action_t = list(set(action_t[action_t == 1].index))
        
        state_tp1 = get_input(state_tp1, next_stream)
        Q_sa = np.max(model.predict(state_tp1)[0])
        # r + gamma * max Q(s',a')
        # DataFrame apply
        state_t.loc[state_t['item_id'].isin(action_t)]['reward'] = state_t.loc[state_t['item_id'].isin(action_t)]['reward'].apply(lambda x: x + self.discount * Q_sa).astype('float32')
        print('n-reward.shape', state_t['reward'].shape)
        print('n-input.shape', inputs.shape)
        targets = pd.concat([targets, state_t['reward']], axis=0).astype('float32')
    print('final shape', inputs.shape, targets.shape)
    return inputs, targets

# %% [markdown]
# ## Train

# %%
def train(model, exp_replay, epochs, batch_size, num_episode=1000, verbose=1, reward_set='strict',
          hist=[], c_hist=[], rec_list=[]):
  # total_actions = ITEM_DF.shape[0]
  # total_episodes = len(USER_LIST)
  # Reset win counter
  c_win_cnt = 0

  for e in range(epochs):
    rec_cnt = 0
    win_cnt = 0
    loss = 0.
    # TODO/MAIN: Apply user preference changes as epsilon
    # epsilon for exploration - dependent inversely on the training epoch
    epsilon = 4 / ((e + 1) ** (1 / 2))

    # handling episodes by assigning users from USER_LIST
    # Each user represent an Episode
    episodes = np.random.choice(USER_LIST, num_episode, replace=False)

    print(f'Epoch {e} started.   Time: {datetime.now(pytz.timezone("Asia/Taipei")).strftime("%H:%M:%S")}')
    # ------------------- Episode (User) -------------------------------
    for asid in tqdm(episodes):
      # get [episode data, stream list, final stream] by asid
      user_all_streams = CONTEXT_REPS.xs(asid, level="asid")
      stream_list = user_all_streams.index
      final_stream = max(stream_list)
      
      # ----------------- Runs (User x All_Stream) ---------------------
      for i, stream in enumerate(stream_list):
        print(f'stream {i}')
        game_over = stream == final_stream
                
        # Get full state: current_state = user_stream + item_stream
        # 用上一場紀錄預測下一場直播會購買的商品
        current_state = get_full_state(asid, user_all_streams, stream_list, i)
        stream_items = STREAM_ITEM_DICT[stream]

        # --------------- Explore/Exploit Section ----------------------
        if np.random.rand() <= epsilon:
          # Explore by randomly select 10/n items from candidate_items
          # Get all items from the stream
          sample_actions = random.sample(stream_items, 10) if len(stream_items) > 10 else stream_items
          action_ids = gen_exist_series(sample_actions, stream_items)
        else:
          # Exploit by choosing action from the model's prediction
          pred_actions = model_predict_top10(model, current_state)
          action_ids = gen_exist_series(pred_actions, stream_items)

        # --------------- Get next state & info to store ---------------
        reward = get_reward(asid, stream, action_ids)
        next_state = get_full_state(asid, user_all_streams, stream_list, i+1) if not game_over else []
        
        rec_cnt += 1
        if sum(reward) > 0:
          c_win_cnt += 1
          win_cnt += 1

        # --------------- Calculating Interest Changes -----------------
        interest_score = 0 if i == 0 else calculate_interest_change(user_all_streams.loc[stream_list[i]],
                                                                    user_all_streams.loc[stream_list[i - 1]])
        # print(f'interest: {interest_score},i: {i}')

        # --------------- Store Experience -----------------------------
        print(len(stream_list), (i + 1) == len(stream_list))
        next_stream = 0 if (i + 1) == len(stream_list) else stream_list[i + 1]
        exp_replay.remember(interest_score,
                            [[stream, next_stream], current_state, action_ids, reward, next_state],
                            game_over)
        

        # --------------- Load batch of experiences --------------------
        inputs, targets = exp_replay.get_batch(model, batch_size=batch_size)
        # train model on experiences
        batch_loss = model.train_on_batch(inputs, targets)
        loss += batch_loss
                    
    if verbose > 0:
      print(f'Epoch: {e}/{epochs} | Loss {loss} | Win count {win_cnt} | Rec count {rec_cnt} |\
              Time {datetime.now(pytz.timezone("Asia/Taipei")).strftime("%H:%M:%S")}')
    
    # Track win history to later check if our model is improving at the game over time.
    hist.append(win_cnt)
    c_hist.append(c_win_cnt)
    rec_list.append(rec_cnt)

# %%
pd.set_option('mode.chained_assignment', None)

# parameters
MAX_MEMORY = 1000  # Maximum number of experiences we are storing
BATCH_SIZE = 2  # Number of experiences we use for training per batch
EPOCH = 50
TOTAL_ACTIONS = 1 # probability of ordering
NUM_EPISODE = 100
HIDDEN_SIZE = 512


warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Main Method

# %%
# %%time

exp_replay = ReplayBuffer(max_memory=MAX_MEMORY)# Our model's architecture parameters
input_size = 342 # The input shape for model - this comes from the output shape of the CNN Mobilenet

# Setting up the model with keras.
model = keras.Sequential()
model.add(Dense(HIDDEN_SIZE, input_shape=(input_size,), activation='relu'))
model.add(Dense(HIDDEN_SIZE, activation='tanh'))
model.add(Dense(TOTAL_ACTIONS))
model.compile(Adam(learning_rate=.000001), "mse")

hist = []
c_hist = []
rec_list = []

# Training the model
train(model, 
      exp_replay, 
      epochs=EPOCH, 
      batch_size=BATCH_SIZE, 
      num_episode=NUM_EPISODE, 
      verbose=1, 
      reward_set='strict',
      hist=hist,
      c_hist=c_hist,
      rec_list=rec_list)
# Out:
# Epoch 0 started.   Time: 16:49:47
#   0%|          | 0/100 [00:00<?, ?it/s]
# stream 0
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 0 ---------
# replay#64 (14096, 342) (14096,)
# n-reward.shape (14096,)
# n-input.shape (14096, 342)
# final shape (14096, 342) (14096, 1)
# stream 1
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 0 ---------
# replay#64 (14096, 342) (14096,)
# n-reward.shape (14096,)
# n-input.shape (14096, 342)
# --------- batch: 1 | idx: 0 ---------
# replay#64 (14096, 342) (14096,)
# n-reward.shape (14096,)
# n-input.shape (28192, 342)
# final shape (28192, 342) (28192, 1)
# stream 2
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 1 ---------
# replay#64 (19, 342) (19,)
# n-reward.shape (19,)
# n-input.shape (19, 342)
# --------- batch: 1 | idx: 0 ---------
# replay#64 (14096, 342) (14096,)
# n-reward.shape (14096,)
# n-input.shape (14115, 342)
# final shape (14115, 342) (14115, 1)
# stream 3
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 1 ---------
# replay#64 (19, 342) (19,)
# n-reward.shape (19,)
# n-input.shape (19, 342)
# --------- batch: 1 | idx: 0 ---------
# replay#64 (14096, 342) (14096,)
# n-reward.shape (14096,)
# n-input.shape (14115, 342)
# final shape (14115, 342) (14115, 1)
# stream 4
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 2 ---------
# replay#64 (40, 342) (40,)
# n-reward.shape (40,)
# n-input.shape (40, 342)
# --------- batch: 1 | idx: 2 ---------
# replay#64 (40, 342) (40,)
# n-reward.shape (40,)
# n-input.shape (80, 342)
# final shape (80, 342) (80, 1)
# stream 5
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 1 ---------
# replay#64 (19, 342) (19,)
# n-reward.shape (19,)
# n-input.shape (19, 342)
# --------- batch: 1 | idx: 1 ---------
# replay#64 (19, 342) (19,)
# n-reward.shape (19,)
# n-input.shape (38, 342)
# final shape (38, 342) (38, 1)
# stream 6
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 3 ---------
# replay#64 (32, 342) (32,)
# n-reward.shape (32,)
# n-input.shape (32, 342)
# --------- batch: 1 | idx: 2 ---------
# replay#64 (40, 342) (40,)
# n-reward.shape (40,)
# n-input.shape (72, 342)
# final shape (72, 342) (72, 1)
# stream 7
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 1 ---------
# replay#64 (19, 342) (19,)
# n-reward.shape (19,)
# n-input.shape (19, 342)
# --------- batch: 1 | idx: 7 ---------
# replay#64 (27, 342) (27,)
# n-reward.shape (27,)
# n-input.shape (46, 342)
# final shape (46, 342) (46, 1)
# stream 8
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 6 ---------
# replay#64 (32, 342) (32,)
# n-reward.shape (32,)
# n-input.shape (32, 342)
# --------- batch: 1 | idx: 6 ---------
# replay#64 (32, 342) (32,)
# n-reward.shape (32,)
# n-input.shape (64, 342)
# final shape (64, 342) (64, 1)
# stream 9
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 0 ---------
# replay#64 (14096, 342) (14096,)
# n-reward.shape (14096,)
# n-input.shape (14096, 342)
# --------- batch: 1 | idx: 9 ---------
# replay#64 (58, 342) (58,)
# n-reward.shape (58,)
# n-input.shape (14154, 342)
# final shape (14154, 342) (14154, 1)
# stream 10
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 9 ---------
# replay#64 (58, 342) (58,)
# n-reward.shape (58,)
# n-input.shape (58, 342)
# --------- batch: 1 | idx: 9 ---------
# replay#64 (58, 342) (58,)
# n-reward.shape (58,)
# n-input.shape (116, 342)
# final shape (116, 342) (116, 1)
# stream 11
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 8 ---------
# replay#64 (39, 342) (39,)
# n-reward.shape (39,)
# n-input.shape (39, 342)
# --------- batch: 1 | idx: 10 ---------
# replay#64 (28, 342) (28,)
# n-reward.shape (28,)
# n-input.shape (67, 342)
# final shape (67, 342) (67, 1)
# stream 12
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 2 ---------
# replay#64 (40, 342) (40,)
# n-reward.shape (40,)
# n-input.shape (40, 342)
# --------- batch: 1 | idx: 4 ---------
# replay#64 (55, 342) (55,)
# n-reward.shape (55,)
# n-input.shape (95, 342)
# final shape (95, 342) (95, 1)
# stream 13
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 4 ---------
# replay#64 (55, 342) (55,)
# n-reward.shape (55,)
# n-input.shape (55, 342)
# --------- batch: 1 | idx: 8 ---------
# replay#64 (39, 342) (39,)
# n-reward.shape (39,)
# n-input.shape (94, 342)
# final shape (94, 342) (94, 1)
# stream 14
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 1 ---------
# replay#64 (19, 342) (19,)
# n-reward.shape (19,)
# n-input.shape (19, 342)
# --------- batch: 1 | idx: 6 ---------
# replay#64 (32, 342) (32,)
# n-reward.shape (32,)
# n-input.shape (51, 342)
# final shape (51, 342) (51, 1)
# stream 15
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 7 ---------
# replay#64 (27, 342) (27,)
# n-reward.shape (27,)
# n-input.shape (27, 342)
# --------- batch: 1 | idx: 8 ---------
# replay#64 (39, 342) (39,)
# n-reward.shape (39,)
# n-input.shape (66, 342)
# final shape (66, 342) (66, 1)
# stream 16
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 0 ---------
# replay#64 (14096, 342) (14096,)
# n-reward.shape (14096,)
# n-input.shape (14096, 342)
# --------- batch: 1 | idx: 14 ---------
# replay#64 (18, 342) (18,)
# n-reward.shape (18,)
# n-input.shape (14114, 342)
# final shape (14114, 342) (14114, 1)
# stream 17
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 17 ---------
# replay#64 (23, 342) (23,)
# n-reward.shape (23,)
# n-input.shape (23, 342)
# --------- batch: 1 | idx: 11 ---------
# replay#64 (29, 342) (29,)
# n-reward.shape (29,)
# n-input.shape (52, 342)
# final shape (52, 342) (52, 1)
# stream 18
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 3 ---------
# replay#64 (32, 342) (32,)
# n-reward.shape (32,)
# n-input.shape (32, 342)
# --------- batch: 1 | idx: 18 ---------
# replay#64 (21, 342) (21,)
# n-reward.shape (21,)
# n-input.shape (53, 342)
# final shape (53, 342) (53, 1)
# stream 19
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 10 ---------
# replay#64 (28, 342) (28,)
# n-reward.shape (28,)
# n-input.shape (28, 342)
# --------- batch: 1 | idx: 1 ---------
# replay#64 (19, 342) (19,)
# n-reward.shape (19,)
# n-input.shape (47, 342)
# final shape (47, 342) (47, 1)
# stream 20
# 22 False
# -----start enumerating-----
# --------- batch: 0 | idx: 1 ---------
# replay#64 (19, 342) (19,)
# n-reward.shape (19,)
# n-input.shape (19, 342)
# --------- batch: 1 | idx: 5 ---------
# replay#64 (25, 342) (25,)
# n-reward.shape (25,)
# n-input.shape (44, 342)
# final shape (44, 342) (44, 1)
# stream 21
# 22 True
# -----start enumerating-----
# --------- batch: 0 | idx: 9 ---------
# replay#64 (58, 342) (58,)
# n-reward.shape (58,)
# n-input.shape (58, 342)
# --------- batch: 1 | idx: 20 ---------
# replay#64 (10, 342) (10,)
# n-reward.shape (10,)
# n-input.shape (68, 342)
# final shape (68, 342) (68, 1)
# stream 0
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 12 ---------
# replay#64 (33, 342) (33,)
# n-reward.shape (33,)
# n-input.shape (33, 342)
# --------- batch: 1 | idx: 18 ---------
# replay#64 (21, 342) (21,)
# n-reward.shape (21,)
# n-input.shape (54, 342)
# final shape (54, 342) (54, 1)
# stream 1
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 2 ---------
# replay#64 (40, 342) (40,)
# n-reward.shape (40,)
# n-input.shape (40, 342)
# --------- batch: 1 | idx: 3 ---------
# replay#64 (32, 342) (32,)
# n-reward.shape (32,)
# n-input.shape (72, 342)
# final shape (72, 342) (72, 1)
# stream 2
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 19 ---------
# replay#64 (4, 342) (4,)
# n-reward.shape (4,)
# n-input.shape (4, 342)
# --------- batch: 1 | idx: 14 ---------
# replay#64 (18, 342) (18,)
# n-reward.shape (18,)
# n-input.shape (22, 342)
# final shape (22, 342) (22, 1)
# stream 3
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 8 ---------
# replay#64 (39, 342) (39,)
# n-reward.shape (39,)
# n-input.shape (39, 342)
# --------- batch: 1 | idx: 5 ---------
# replay#64 (25, 342) (25,)
# n-reward.shape (25,)
# n-input.shape (64, 342)
# final shape (64, 342) (64, 1)
# stream 4
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 14 ---------
# replay#64 (18, 342) (18,)
# n-reward.shape (18,)
# n-input.shape (18, 342)
# --------- batch: 1 | idx: 25 ---------
# replay#64 (96, 342) (96,)
# n-reward.shape (96,)
# n-input.shape (114, 342)
# final shape (114, 342) (114, 1)
# stream 5
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 27 ---------
# replay#64 (94, 342) (94,)
# n-reward.shape (94,)
# n-input.shape (94, 342)
# --------- batch: 1 | idx: 26 ---------
# replay#64 (115, 342) (115,)
# n-reward.shape (115,)
# n-input.shape (209, 342)
# final shape (209, 342) (209, 1)
# stream 6
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 25 ---------
# replay#64 (96, 342) (96,)
# n-reward.shape (96,)
# n-input.shape (96, 342)
# --------- batch: 1 | idx: 2 ---------
# replay#64 (40, 342) (40,)
# n-reward.shape (40,)
# n-input.shape (136, 342)
# final shape (136, 342) (136, 1)
# stream 7
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 16 ---------
# replay#64 (37, 342) (37,)
# n-reward.shape (37,)
# n-input.shape (37, 342)
# --------- batch: 1 | idx: 6 ---------
# replay#64 (32, 342) (32,)
# n-reward.shape (32,)
# n-input.shape (69, 342)
# final shape (69, 342) (69, 1)
# stream 8
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 15 ---------
# replay#64 (15, 342) (15,)
# n-reward.shape (15,)
# n-input.shape (15, 342)
# --------- batch: 1 | idx: 12 ---------
# replay#64 (33, 342) (33,)
# n-reward.shape (33,)
# n-input.shape (48, 342)
# final shape (48, 342) (48, 1)
# stream 9
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 1 ---------
# replay#64 (19, 342) (19,)
# n-reward.shape (19,)
# n-input.shape (19, 342)
# --------- batch: 1 | idx: 14 ---------
# replay#64 (18, 342) (18,)
# n-reward.shape (18,)
# n-input.shape (37, 342)
# final shape (37, 342) (37, 1)
# stream 10
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 8 ---------
# replay#64 (39, 342) (39,)
# n-reward.shape (39,)
# n-input.shape (39, 342)
# --------- batch: 1 | idx: 14 ---------
# replay#64 (18, 342) (18,)
# n-reward.shape (18,)
# n-input.shape (57, 342)
# final shape (57, 342) (57, 1)
# stream 11
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 12 ---------
# replay#64 (33, 342) (33,)
# n-reward.shape (33,)
# n-input.shape (33, 342)
# --------- batch: 1 | idx: 33 ---------
# replay#64 (84, 342) (84,)
# n-reward.shape (84,)
# n-input.shape (117, 342)
# final shape (117, 342) (117, 1)
# stream 12
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 22 ---------
# replay#64 (90, 342) (90,)
# n-reward.shape (90,)
# n-input.shape (90, 342)
# --------- batch: 1 | idx: 29 ---------
# replay#64 (85, 342) (85,)
# n-reward.shape (85,)
# n-input.shape (175, 342)
# final shape (175, 342) (175, 1)
# stream 13
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 13 ---------
# replay#64 (23, 342) (23,)
# n-reward.shape (23,)
# n-input.shape (23, 342)
# --------- batch: 1 | idx: 4 ---------
# replay#64 (55, 342) (55,)
# n-reward.shape (55,)
# n-input.shape (78, 342)
# final shape (78, 342) (78, 1)
# stream 14
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 14 ---------
# replay#64 (18, 342) (18,)
# n-reward.shape (18,)
# n-input.shape (18, 342)
# --------- batch: 1 | idx: 19 ---------
# replay#64 (4, 342) (4,)
# n-reward.shape (4,)
# n-input.shape (22, 342)
# final shape (22, 342) (22, 1)
# stream 15
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 8 ---------
# replay#64 (39, 342) (39,)
# n-reward.shape (39,)
# n-input.shape (39, 342)
# --------- batch: 1 | idx: 30 ---------
# replay#64 (79, 342) (79,)
# n-reward.shape (79,)
# n-input.shape (118, 342)
# final shape (118, 342) (118, 1)
# stream 16
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 31 ---------
# replay#64 (78, 342) (78,)
# n-reward.shape (78,)
# n-input.shape (78, 342)
# --------- batch: 1 | idx: 6 ---------
# replay#64 (32, 342) (32,)
# n-reward.shape (32,)
# n-input.shape (110, 342)
# final shape (110, 342) (110, 1)
# stream 17
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 9 ---------
# replay#64 (58, 342) (58,)
# n-reward.shape (58,)
# n-input.shape (58, 342)
# --------- batch: 1 | idx: 38 ---------
# replay#64 (48, 342) (48,)
# n-reward.shape (48,)
# n-input.shape (106, 342)
# final shape (106, 342) (106, 1)
# stream 18
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 0 ---------
# replay#64 (14096, 342) (14096,)
# n-reward.shape (14096,)
# n-input.shape (14096, 342)
# --------- batch: 1 | idx: 37 ---------
# replay#64 (71, 342) (71,)
# n-reward.shape (71,)
# n-input.shape (14167, 342)
# final shape (14167, 342) (14167, 1)
# stream 19
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 23 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (82, 342)
# --------- batch: 1 | idx: 21 ---------
# replay#64 (12, 342) (12,)
# g-reward.shape (12,)
# g-input.shape (94, 342)
# final shape (94, 342) (94, 1)
# stream 20
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 14 ---------
# replay#64 (18, 342) (18,)
# n-reward.shape (18,)
# n-input.shape (18, 342)
# --------- batch: 1 | idx: 2 ---------
# replay#64 (40, 342) (40,)
# n-reward.shape (40,)
# n-input.shape (58, 342)
# final shape (58, 342) (58, 1)
# stream 21
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 30 ---------
# replay#64 (79, 342) (79,)
# n-reward.shape (79,)
# n-input.shape (79, 342)
# --------- batch: 1 | idx: 2 ---------
# replay#64 (40, 342) (40,)
# n-reward.shape (40,)
# n-input.shape (119, 342)
# final shape (119, 342) (119, 1)
# stream 22
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 17 ---------
# replay#64 (23, 342) (23,)
# n-reward.shape (23,)
# n-input.shape (23, 342)
# --------- batch: 1 | idx: 14 ---------
# replay#64 (18, 342) (18,)
# n-reward.shape (18,)
# n-input.shape (41, 342)
# final shape (41, 342) (41, 1)
# stream 23
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 7 ---------
# replay#64 (27, 342) (27,)
# n-reward.shape (27,)
# n-input.shape (27, 342)
# --------- batch: 1 | idx: 23 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (109, 342)
# final shape (109, 342) (109, 1)
# stream 24
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 24 ---------
# replay#64 (75, 342) (75,)
# n-reward.shape (75,)
# n-input.shape (75, 342)
# --------- batch: 1 | idx: 10 ---------
# replay#64 (28, 342) (28,)
# n-reward.shape (28,)
# n-input.shape (103, 342)
# final shape (103, 342) (103, 1)
# stream 25
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 43 ---------
# replay#64 (109, 342) (109,)
# n-reward.shape (109,)
# n-input.shape (109, 342)
# --------- batch: 1 | idx: 5 ---------
# replay#64 (25, 342) (25,)
# n-reward.shape (25,)
# n-input.shape (134, 342)
# final shape (134, 342) (134, 1)
# stream 26
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 47 ---------
# replay#64 (129, 342) (129,)
# n-reward.shape (129,)
# n-input.shape (129, 342)
# --------- batch: 1 | idx: 29 ---------
# replay#64 (85, 342) (85,)
# n-reward.shape (85,)
# n-input.shape (214, 342)
# final shape (214, 342) (214, 1)
# stream 27
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 33 ---------
# replay#64 (84, 342) (84,)
# n-reward.shape (84,)
# n-input.shape (84, 342)
# --------- batch: 1 | idx: 23 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (166, 342)
# final shape (166, 342) (166, 1)
# stream 28
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 35 ---------
# replay#64 (111, 342) (111,)
# n-reward.shape (111,)
# n-input.shape (111, 342)
# --------- batch: 1 | idx: 14 ---------
# replay#64 (18, 342) (18,)
# n-reward.shape (18,)
# n-input.shape (129, 342)
# final shape (129, 342) (129, 1)
# stream 29
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 43 ---------
# replay#64 (109, 342) (109,)
# n-reward.shape (109,)
# n-input.shape (109, 342)
# --------- batch: 1 | idx: 19 ---------
# replay#64 (4, 342) (4,)
# n-reward.shape (4,)
# n-input.shape (113, 342)
# final shape (113, 342) (113, 1)
# stream 30
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 49 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (82, 342)
# --------- batch: 1 | idx: 48 ---------
# replay#64 (71, 342) (71,)
# n-reward.shape (71,)
# n-input.shape (153, 342)
# final shape (153, 342) (153, 1)
# stream 31
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 1 ---------
# replay#64 (19, 342) (19,)
# n-reward.shape (19,)
# n-input.shape (19, 342)
# --------- batch: 1 | idx: 7 ---------
# replay#64 (27, 342) (27,)
# n-reward.shape (27,)
# n-input.shape (46, 342)
# final shape (46, 342) (46, 1)
# stream 32
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 0 ---------
# replay#64 (14096, 342) (14096,)
# n-reward.shape (14096,)
# n-input.shape (14096, 342)
# --------- batch: 1 | idx: 21 ---------
# replay#64 (12, 342) (12,)
# g-reward.shape (12,)
# g-input.shape (14108, 342)
# final shape (14108, 342) (14108, 1)
# stream 33
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 24 ---------
# replay#64 (75, 342) (75,)
# n-reward.shape (75,)
# n-input.shape (75, 342)
# --------- batch: 1 | idx: 7 ---------
# replay#64 (27, 342) (27,)
# n-reward.shape (27,)
# n-input.shape (102, 342)
# final shape (102, 342) (102, 1)
# stream 34
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 19 ---------
# replay#64 (4, 342) (4,)
# n-reward.shape (4,)
# n-input.shape (4, 342)
# --------- batch: 1 | idx: 49 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (86, 342)
# final shape (86, 342) (86, 1)
# stream 35
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 39 ---------
# replay#64 (99, 342) (99,)
# n-reward.shape (99,)
# n-input.shape (99, 342)
# --------- batch: 1 | idx: 29 ---------
# replay#64 (85, 342) (85,)
# n-reward.shape (85,)
# n-input.shape (184, 342)
# final shape (184, 342) (184, 1)
# stream 36
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 56 ---------
# replay#64 (74, 342) (74,)
# n-reward.shape (74,)
# n-input.shape (74, 342)
# --------- batch: 1 | idx: 55 ---------
# replay#64 (22, 342) (22,)
# n-reward.shape (22,)
# n-input.shape (96, 342)
# final shape (96, 342) (96, 1)
# stream 37
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 40 ---------
# replay#64 (78, 342) (78,)
# n-reward.shape (78,)
# n-input.shape (78, 342)
# --------- batch: 1 | idx: 4 ---------
# replay#64 (55, 342) (55,)
# n-reward.shape (55,)
# n-input.shape (133, 342)
# final shape (133, 342) (133, 1)
# stream 38
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 23 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (82, 342)
# --------- batch: 1 | idx: 15 ---------
# replay#64 (15, 342) (15,)
# n-reward.shape (15,)
# n-input.shape (97, 342)
# final shape (97, 342) (97, 1)
# stream 39
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 31 ---------
# replay#64 (78, 342) (78,)
# n-reward.shape (78,)
# n-input.shape (78, 342)
# --------- batch: 1 | idx: 37 ---------
# replay#64 (71, 342) (71,)
# n-reward.shape (71,)
# n-input.shape (149, 342)
# final shape (149, 342) (149, 1)
# stream 40
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 8 ---------
# replay#64 (39, 342) (39,)
# n-reward.shape (39,)
# n-input.shape (39, 342)
# --------- batch: 1 | idx: 49 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (121, 342)
# final shape (121, 342) (121, 1)
# stream 41
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 13 ---------
# replay#64 (23, 342) (23,)
# n-reward.shape (23,)
# n-input.shape (23, 342)
# --------- batch: 1 | idx: 41 ---------
# replay#64 (89, 342) (89,)
# n-reward.shape (89,)
# n-input.shape (112, 342)
# final shape (112, 342) (112, 1)
# stream 42
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 10 ---------
# replay#64 (28, 342) (28,)
# n-reward.shape (28,)
# n-input.shape (28, 342)
# --------- batch: 1 | idx: 18 ---------
# replay#64 (21, 342) (21,)
# n-reward.shape (21,)
# n-input.shape (49, 342)
# final shape (49, 342) (49, 1)
# stream 43
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 54 ---------
# replay#64 (93, 342) (93,)
# n-reward.shape (93,)
# n-input.shape (93, 342)
# --------- batch: 1 | idx: 21 ---------
# replay#64 (12, 342) (12,)
# g-reward.shape (12,)
# g-input.shape (105, 342)
# final shape (105, 342) (105, 1)
# stream 44
# 46 False
# -----start enumerating-----
# --------- batch: 0 | idx: 52 ---------
# replay#64 (92, 342) (92,)
# n-reward.shape (92,)
# n-input.shape (92, 342)
# --------- batch: 1 | idx: 44 ---------
# replay#64 (74, 342) (74,)
# n-reward.shape (74,)
# n-input.shape (166, 342)
# final shape (166, 342) (166, 1)
# stream 45
# 46 True
# -----start enumerating-----
# --------- batch: 0 | idx: 54 ---------
# replay#64 (93, 342) (93,)
# n-reward.shape (93,)
# n-input.shape (93, 342)
# --------- batch: 1 | idx: 52 ---------
# replay#64 (92, 342) (92,)
# n-reward.shape (92,)
# n-input.shape (185, 342)
# final shape (185, 342) (185, 1)
# stream 0
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 28 ---------
# replay#64 (75, 342) (75,)
# n-reward.shape (75,)
# n-input.shape (75, 342)
# --------- batch: 1 | idx: 63 ---------
# replay#64 (41, 342) (41,)
# n-reward.shape (41,)
# n-input.shape (116, 342)
# final shape (116, 342) (116, 1)
# stream 1
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 69 ---------
# replay#64 (99, 342) (99,)
# n-reward.shape (99,)
# n-input.shape (99, 342)
# --------- batch: 1 | idx: 16 ---------
# replay#64 (37, 342) (37,)
# n-reward.shape (37,)
# n-input.shape (136, 342)
# final shape (136, 342) (136, 1)
# stream 2
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 58 ---------
# replay#64 (111, 342) (111,)
# n-reward.shape (111,)
# n-input.shape (111, 342)
# --------- batch: 1 | idx: 31 ---------
# replay#64 (78, 342) (78,)
# n-reward.shape (78,)
# n-input.shape (189, 342)
# final shape (189, 342) (189, 1)
# stream 3
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 48 ---------
# replay#64 (71, 342) (71,)
# n-reward.shape (71,)
# n-input.shape (71, 342)
# --------- batch: 1 | idx: 14 ---------
# replay#64 (18, 342) (18,)
# n-reward.shape (18,)
# n-input.shape (89, 342)
# final shape (89, 342) (89, 1)
# stream 4
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 40 ---------
# replay#64 (78, 342) (78,)
# n-reward.shape (78,)
# n-input.shape (78, 342)
# --------- batch: 1 | idx: 16 ---------
# replay#64 (37, 342) (37,)
# n-reward.shape (37,)
# n-input.shape (115, 342)
# final shape (115, 342) (115, 1)
# stream 5
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 19 ---------
# replay#64 (4, 342) (4,)
# n-reward.shape (4,)
# n-input.shape (4, 342)
# --------- batch: 1 | idx: 10 ---------
# replay#64 (28, 342) (28,)
# n-reward.shape (28,)
# n-input.shape (32, 342)
# final shape (32, 342) (32, 1)
# stream 6
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 48 ---------
# replay#64 (71, 342) (71,)
# n-reward.shape (71,)
# n-input.shape (71, 342)
# --------- batch: 1 | idx: 43 ---------
# replay#64 (109, 342) (109,)
# n-reward.shape (109,)
# n-input.shape (180, 342)
# final shape (180, 342) (180, 1)
# stream 7
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 14 ---------
# replay#64 (18, 342) (18,)
# n-reward.shape (18,)
# n-input.shape (18, 342)
# --------- batch: 1 | idx: 34 ---------
# replay#64 (120, 342) (120,)
# n-reward.shape (120,)
# n-input.shape (138, 342)
# final shape (138, 342) (138, 1)
# stream 8
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 70 ---------
# replay#64 (101, 342) (101,)
# n-reward.shape (101,)
# n-input.shape (101, 342)
# --------- batch: 1 | idx: 75 ---------
# replay#64 (105, 342) (105,)
# n-reward.shape (105,)
# n-input.shape (206, 342)
# final shape (206, 342) (206, 1)
# stream 9
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 53 ---------
# replay#64 (74, 342) (74,)
# n-reward.shape (74,)
# n-input.shape (74, 342)
# --------- batch: 1 | idx: 27 ---------
# replay#64 (94, 342) (94,)
# n-reward.shape (94,)
# n-input.shape (168, 342)
# final shape (168, 342) (168, 1)
# stream 10
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 23 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (82, 342)
# --------- batch: 1 | idx: 37 ---------
# replay#64 (71, 342) (71,)
# n-reward.shape (71,)
# n-input.shape (153, 342)
# final shape (153, 342) (153, 1)
# stream 11
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 19 ---------
# replay#64 (4, 342) (4,)
# n-reward.shape (4,)
# n-input.shape (4, 342)
# --------- batch: 1 | idx: 22 ---------
# replay#64 (90, 342) (90,)
# n-reward.shape (90,)
# n-input.shape (94, 342)
# final shape (94, 342) (94, 1)
# stream 12
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 70 ---------
# replay#64 (101, 342) (101,)
# n-reward.shape (101,)
# n-input.shape (101, 342)
# --------- batch: 1 | idx: 44 ---------
# replay#64 (74, 342) (74,)
# n-reward.shape (74,)
# n-input.shape (175, 342)
# final shape (175, 342) (175, 1)
# stream 13
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 53 ---------
# replay#64 (74, 342) (74,)
# n-reward.shape (74,)
# n-input.shape (74, 342)
# --------- batch: 1 | idx: 23 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (156, 342)
# final shape (156, 342) (156, 1)
# stream 14
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 59 ---------
# replay#64 (2, 342) (2,)
# n-reward.shape (2,)
# n-input.shape (2, 342)
# --------- batch: 1 | idx: 42 ---------
# replay#64 (70, 342) (70,)
# n-reward.shape (70,)
# n-input.shape (72, 342)
# final shape (72, 342) (72, 1)
# stream 15
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 37 ---------
# replay#64 (71, 342) (71,)
# n-reward.shape (71,)
# n-input.shape (71, 342)
# --------- batch: 1 | idx: 28 ---------
# replay#64 (75, 342) (75,)
# n-reward.shape (75,)
# n-input.shape (146, 342)
# final shape (146, 342) (146, 1)
# stream 16
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 15 ---------
# replay#64 (15, 342) (15,)
# n-reward.shape (15,)
# n-input.shape (15, 342)
# --------- batch: 1 | idx: 83 ---------
# replay#64 (108, 342) (108,)
# n-reward.shape (108,)
# n-input.shape (123, 342)
# final shape (123, 342) (123, 1)
# stream 17
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 43 ---------
# replay#64 (109, 342) (109,)
# n-reward.shape (109,)
# n-input.shape (109, 342)
# --------- batch: 1 | idx: 67 ---------
# replay#64 (84, 342) (84,)
# g-reward.shape (84,)
# g-input.shape (193, 342)
# final shape (193, 342) (193, 1)
# stream 18
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 35 ---------
# replay#64 (111, 342) (111,)
# n-reward.shape (111,)
# n-input.shape (111, 342)
# --------- batch: 1 | idx: 13 ---------
# replay#64 (23, 342) (23,)
# n-reward.shape (23,)
# n-input.shape (134, 342)
# final shape (134, 342) (134, 1)
# stream 19
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 38 ---------
# replay#64 (48, 342) (48,)
# n-reward.shape (48,)
# n-input.shape (48, 342)
# --------- batch: 1 | idx: 84 ---------
# replay#64 (119, 342) (119,)
# n-reward.shape (119,)
# n-input.shape (167, 342)
# final shape (167, 342) (167, 1)
# stream 20
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 12 ---------
# replay#64 (33, 342) (33,)
# n-reward.shape (33,)
# n-input.shape (33, 342)
# --------- batch: 1 | idx: 0 ---------
# replay#64 (14096, 342) (14096,)
# n-reward.shape (14096,)
# n-input.shape (14129, 342)
# final shape (14129, 342) (14129, 1)
# stream 21
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 55 ---------
# replay#64 (22, 342) (22,)
# n-reward.shape (22,)
# n-input.shape (22, 342)
# --------- batch: 1 | idx: 40 ---------
# replay#64 (78, 342) (78,)
# n-reward.shape (78,)
# n-input.shape (100, 342)
# final shape (100, 342) (100, 1)
# stream 22
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 89 ---------
# replay#64 (170, 342) (170,)
# n-reward.shape (170,)
# n-input.shape (170, 342)
# --------- batch: 1 | idx: 2 ---------
# replay#64 (40, 342) (40,)
# n-reward.shape (40,)
# n-input.shape (210, 342)
# final shape (210, 342) (210, 1)
# stream 23
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 90 ---------
# replay#64 (115, 342) (115,)
# n-reward.shape (115,)
# n-input.shape (115, 342)
# --------- batch: 1 | idx: 77 ---------
# replay#64 (175, 342) (175,)
# n-reward.shape (175,)
# n-input.shape (290, 342)
# final shape (290, 342) (290, 1)
# stream 24
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 31 ---------
# replay#64 (78, 342) (78,)
# n-reward.shape (78,)
# n-input.shape (78, 342)
# --------- batch: 1 | idx: 62 ---------
# replay#64 (86, 342) (86,)
# n-reward.shape (86,)
# n-input.shape (164, 342)
# final shape (164, 342) (164, 1)
# stream 25
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 13 ---------
# replay#64 (23, 342) (23,)
# n-reward.shape (23,)
# n-input.shape (23, 342)
# --------- batch: 1 | idx: 71 ---------
# replay#64 (103, 342) (103,)
# n-reward.shape (103,)
# n-input.shape (126, 342)
# final shape (126, 342) (126, 1)
# stream 26
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 15 ---------
# replay#64 (15, 342) (15,)
# n-reward.shape (15,)
# n-input.shape (15, 342)
# --------- batch: 1 | idx: 63 ---------
# replay#64 (41, 342) (41,)
# n-reward.shape (41,)
# n-input.shape (56, 342)
# final shape (56, 342) (56, 1)
# stream 27
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 43 ---------
# replay#64 (109, 342) (109,)
# n-reward.shape (109,)
# n-input.shape (109, 342)
# --------- batch: 1 | idx: 48 ---------
# replay#64 (71, 342) (71,)
# n-reward.shape (71,)
# n-input.shape (180, 342)
# final shape (180, 342) (180, 1)
# stream 28
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 76 ---------
# replay#64 (118, 342) (118,)
# n-reward.shape (118,)
# n-input.shape (118, 342)
# --------- batch: 1 | idx: 61 ---------
# replay#64 (110, 342) (110,)
# n-reward.shape (110,)
# n-input.shape (228, 342)
# final shape (228, 342) (228, 1)
# stream 29
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 95 ---------
# replay#64 (176, 342) (176,)
# n-reward.shape (176,)
# n-input.shape (176, 342)
# --------- batch: 1 | idx: 35 ---------
# replay#64 (111, 342) (111,)
# n-reward.shape (111,)
# n-input.shape (287, 342)
# final shape (287, 342) (287, 1)
# stream 30
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 76 ---------
# replay#64 (118, 342) (118,)
# n-reward.shape (118,)
# n-input.shape (118, 342)
# --------- batch: 1 | idx: 17 ---------
# replay#64 (23, 342) (23,)
# n-reward.shape (23,)
# n-input.shape (141, 342)
# final shape (141, 342) (141, 1)
# stream 31
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 93 ---------
# replay#64 (120, 342) (120,)
# n-reward.shape (120,)
# n-input.shape (120, 342)
# --------- batch: 1 | idx: 3 ---------
# replay#64 (32, 342) (32,)
# n-reward.shape (32,)
# n-input.shape (152, 342)
# final shape (152, 342) (152, 1)
# stream 32
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 74 ---------
# replay#64 (132, 342) (132,)
# n-reward.shape (132,)
# n-input.shape (132, 342)
# --------- batch: 1 | idx: 51 ---------
# replay#64 (63, 342) (63,)
# n-reward.shape (63,)
# n-input.shape (195, 342)
# final shape (195, 342) (195, 1)
# stream 33
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 61 ---------
# replay#64 (110, 342) (110,)
# n-reward.shape (110,)
# n-input.shape (110, 342)
# --------- batch: 1 | idx: 58 ---------
# replay#64 (111, 342) (111,)
# n-reward.shape (111,)
# n-input.shape (221, 342)
# final shape (221, 342) (221, 1)
# stream 34
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 79 ---------
# replay#64 (1, 342) (1,)
# n-reward.shape (1,)
# n-input.shape (1, 342)
# --------- batch: 1 | idx: 47 ---------
# replay#64 (129, 342) (129,)
# n-reward.shape (129,)
# n-input.shape (130, 342)
# final shape (130, 342) (130, 1)
# stream 35
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 95 ---------
# replay#64 (176, 342) (176,)
# n-reward.shape (176,)
# n-input.shape (176, 342)
# --------- batch: 1 | idx: 74 ---------
# replay#64 (132, 342) (132,)
# n-reward.shape (132,)
# n-input.shape (308, 342)
# final shape (308, 342) (308, 1)
# stream 36
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 70 ---------
# replay#64 (101, 342) (101,)
# n-reward.shape (101,)
# n-input.shape (101, 342)
# --------- batch: 1 | idx: 38 ---------
# replay#64 (48, 342) (48,)
# n-reward.shape (48,)
# n-input.shape (149, 342)
# final shape (149, 342) (149, 1)
# stream 37
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 58 ---------
# replay#64 (111, 342) (111,)
# n-reward.shape (111,)
# n-input.shape (111, 342)
# --------- batch: 1 | idx: 15 ---------
# replay#64 (15, 342) (15,)
# n-reward.shape (15,)
# n-input.shape (126, 342)
# final shape (126, 342) (126, 1)
# stream 38
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 56 ---------
# replay#64 (74, 342) (74,)
# n-reward.shape (74,)
# n-input.shape (74, 342)
# --------- batch: 1 | idx: 101 ---------
# replay#64 (201, 342) (201,)
# n-reward.shape (201,)
# n-input.shape (275, 342)
# final shape (275, 342) (275, 1)
# stream 39
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 0 ---------
# replay#64 (14096, 342) (14096,)
# n-reward.shape (14096,)
# n-input.shape (14096, 342)
# --------- batch: 1 | idx: 106 ---------
# replay#64 (188, 342) (188,)
# n-reward.shape (188,)
# n-input.shape (14284, 342)
# final shape (14284, 342) (14284, 1)
# stream 40
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 107 ---------
# replay#64 (169, 342) (169,)
# n-reward.shape (169,)
# n-input.shape (169, 342)
# --------- batch: 1 | idx: 79 ---------
# replay#64 (1, 342) (1,)
# n-reward.shape (1,)
# n-input.shape (170, 342)
# final shape (170, 342) (170, 1)
# stream 41
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 61 ---------
# replay#64 (110, 342) (110,)
# n-reward.shape (110,)
# n-input.shape (110, 342)
# --------- batch: 1 | idx: 45 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (192, 342)
# final shape (192, 342) (192, 1)
# stream 42
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 47 ---------
# replay#64 (129, 342) (129,)
# n-reward.shape (129,)
# n-input.shape (129, 342)
# --------- batch: 1 | idx: 19 ---------
# replay#64 (4, 342) (4,)
# n-reward.shape (4,)
# n-input.shape (133, 342)
# final shape (133, 342) (133, 1)
# stream 43
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 80 ---------
# replay#64 (176, 342) (176,)
# n-reward.shape (176,)
# n-input.shape (176, 342)
# --------- batch: 1 | idx: 78 ---------
# replay#64 (115, 342) (115,)
# n-reward.shape (115,)
# n-input.shape (291, 342)
# final shape (291, 342) (291, 1)
# stream 44
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 38 ---------
# replay#64 (48, 342) (48,)
# n-reward.shape (48,)
# n-input.shape (48, 342)
# --------- batch: 1 | idx: 110 ---------
# replay#64 (190, 342) (190,)
# n-reward.shape (190,)
# n-input.shape (238, 342)
# final shape (238, 342) (238, 1)
# stream 45
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 35 ---------
# replay#64 (111, 342) (111,)
# n-reward.shape (111,)
# n-input.shape (111, 342)
# --------- batch: 1 | idx: 56 ---------
# replay#64 (74, 342) (74,)
# n-reward.shape (74,)
# n-input.shape (185, 342)
# final shape (185, 342) (185, 1)
# stream 46
# 48 False
# -----start enumerating-----
# --------- batch: 0 | idx: 17 ---------
# replay#64 (23, 342) (23,)
# n-reward.shape (23,)
# n-input.shape (23, 342)
# --------- batch: 1 | idx: 17 ---------
# replay#64 (23, 342) (23,)
# n-reward.shape (23,)
# n-input.shape (46, 342)
# final shape (46, 342) (46, 1)
# stream 47
# 48 True
# -----start enumerating-----
# --------- batch: 0 | idx: 66 ---------
# replay#64 (78, 342) (78,)
# n-reward.shape (78,)
# n-input.shape (78, 342)
# --------- batch: 1 | idx: 30 ---------
# replay#64 (79, 342) (79,)
# n-reward.shape (79,)
# n-input.shape (157, 342)
# final shape (157, 342) (157, 1)
# stream 0
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 7 ---------
# replay#64 (27, 342) (27,)
# n-reward.shape (27,)
# n-input.shape (27, 342)
# --------- batch: 1 | idx: 39 ---------
# replay#64 (99, 342) (99,)
# n-reward.shape (99,)
# n-input.shape (126, 342)
# final shape (126, 342) (126, 1)
# stream 1
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 117 ---------
# replay#64 (112, 342) (112,)
# n-reward.shape (112,)
# n-input.shape (112, 342)
# --------- batch: 1 | idx: 28 ---------
# replay#64 (75, 342) (75,)
# n-reward.shape (75,)
# n-input.shape (187, 342)
# final shape (187, 342) (187, 1)
# stream 2
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 28 ---------
# replay#64 (75, 342) (75,)
# n-reward.shape (75,)
# n-input.shape (75, 342)
# --------- batch: 1 | idx: 65 ---------
# replay#64 (105, 342) (105,)
# n-reward.shape (105,)
# n-input.shape (180, 342)
# final shape (180, 342) (180, 1)
# stream 3
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 2 ---------
# replay#64 (40, 342) (40,)
# n-reward.shape (40,)
# n-input.shape (40, 342)
# --------- batch: 1 | idx: 28 ---------
# replay#64 (75, 342) (75,)
# n-reward.shape (75,)
# n-input.shape (115, 342)
# final shape (115, 342) (115, 1)
# stream 4
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 117 ---------
# replay#64 (112, 342) (112,)
# n-reward.shape (112,)
# n-input.shape (112, 342)
# --------- batch: 1 | idx: 25 ---------
# replay#64 (96, 342) (96,)
# n-reward.shape (96,)
# n-input.shape (208, 342)
# final shape (208, 342) (208, 1)
# stream 5
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 76 ---------
# replay#64 (118, 342) (118,)
# n-reward.shape (118,)
# n-input.shape (118, 342)
# --------- batch: 1 | idx: 120 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (200, 342)
# final shape (200, 342) (200, 1)
# stream 6
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 53 ---------
# replay#64 (74, 342) (74,)
# n-reward.shape (74,)
# n-input.shape (74, 342)
# --------- batch: 1 | idx: 29 ---------
# replay#64 (85, 342) (85,)
# n-reward.shape (85,)
# n-input.shape (159, 342)
# final shape (159, 342) (159, 1)
# stream 7
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 98 ---------
# replay#64 (171, 342) (171,)
# n-reward.shape (171,)
# n-input.shape (171, 342)
# --------- batch: 1 | idx: 10 ---------
# replay#64 (28, 342) (28,)
# n-reward.shape (28,)
# n-input.shape (199, 342)
# final shape (199, 342) (199, 1)
# stream 8
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 11 ---------
# replay#64 (29, 342) (29,)
# n-reward.shape (29,)
# n-input.shape (29, 342)
# --------- batch: 1 | idx: 78 ---------
# replay#64 (115, 342) (115,)
# n-reward.shape (115,)
# n-input.shape (144, 342)
# final shape (144, 342) (144, 1)
# stream 9
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 112 ---------
# replay#64 (194, 342) (194,)
# n-reward.shape (194,)
# n-input.shape (194, 342)
# --------- batch: 1 | idx: 92 ---------
# replay#64 (183, 342) (183,)
# n-reward.shape (183,)
# n-input.shape (377, 342)
# final shape (377, 342) (377, 1)
# stream 10
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 41 ---------
# replay#64 (89, 342) (89,)
# n-reward.shape (89,)
# n-input.shape (89, 342)
# --------- batch: 1 | idx: 96 ---------
# replay#64 (122, 342) (122,)
# n-reward.shape (122,)
# n-input.shape (211, 342)
# final shape (211, 342) (211, 1)
# stream 11
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 2 ---------
# replay#64 (40, 342) (40,)
# n-reward.shape (40,)
# n-input.shape (40, 342)
# --------- batch: 1 | idx: 95 ---------
# replay#64 (176, 342) (176,)
# n-reward.shape (176,)
# n-input.shape (216, 342)
# final shape (216, 342) (216, 1)
# stream 12
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 16 ---------
# replay#64 (37, 342) (37,)
# n-reward.shape (37,)
# n-input.shape (37, 342)
# --------- batch: 1 | idx: 105 ---------
# replay#64 (181, 342) (181,)
# n-reward.shape (181,)
# n-input.shape (218, 342)
# final shape (218, 342) (218, 1)
# stream 13
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 37 ---------
# replay#64 (71, 342) (71,)
# n-reward.shape (71,)
# n-input.shape (71, 342)
# --------- batch: 1 | idx: 64 ---------
# replay#64 (98, 342) (98,)
# n-reward.shape (98,)
# n-input.shape (169, 342)
# final shape (169, 342) (169, 1)
# stream 14
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 26 ---------
# replay#64 (115, 342) (115,)
# n-reward.shape (115,)
# n-input.shape (115, 342)
# --------- batch: 1 | idx: 23 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (197, 342)
# final shape (197, 342) (197, 1)
# stream 15
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 9 ---------
# replay#64 (58, 342) (58,)
# n-reward.shape (58,)
# n-input.shape (58, 342)
# --------- batch: 1 | idx: 43 ---------
# replay#64 (109, 342) (109,)
# n-reward.shape (109,)
# n-input.shape (167, 342)
# final shape (167, 342) (167, 1)
# stream 16
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 81 ---------
# replay#64 (117, 342) (117,)
# n-reward.shape (117,)
# n-input.shape (117, 342)
# --------- batch: 1 | idx: 3 ---------
# replay#64 (32, 342) (32,)
# n-reward.shape (32,)
# n-input.shape (149, 342)
# final shape (149, 342) (149, 1)
# stream 17
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 76 ---------
# replay#64 (118, 342) (118,)
# n-reward.shape (118,)
# n-input.shape (118, 342)
# --------- batch: 1 | idx: 121 ---------
# replay#64 (85, 342) (85,)
# n-reward.shape (85,)
# n-input.shape (203, 342)
# final shape (203, 342) (203, 1)
# stream 18
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 99 ---------
# replay#64 (171, 342) (171,)
# n-reward.shape (171,)
# n-input.shape (171, 342)
# --------- batch: 1 | idx: 90 ---------
# replay#64 (115, 342) (115,)
# n-reward.shape (115,)
# n-input.shape (286, 342)
# final shape (286, 342) (286, 1)
# stream 19
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 72 ---------
# replay#64 (107, 342) (107,)
# n-reward.shape (107,)
# n-input.shape (107, 342)
# --------- batch: 1 | idx: 33 ---------
# replay#64 (84, 342) (84,)
# n-reward.shape (84,)
# n-input.shape (191, 342)
# final shape (191, 342) (191, 1)
# stream 20
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 9 ---------
# replay#64 (58, 342) (58,)
# n-reward.shape (58,)
# n-input.shape (58, 342)
# --------- batch: 1 | idx: 63 ---------
# replay#64 (41, 342) (41,)
# n-reward.shape (41,)
# n-input.shape (99, 342)
# final shape (99, 342) (99, 1)
# stream 21
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 106 ---------
# replay#64 (188, 342) (188,)
# n-reward.shape (188,)
# n-input.shape (188, 342)
# --------- batch: 1 | idx: 77 ---------
# replay#64 (175, 342) (175,)
# n-reward.shape (175,)
# n-input.shape (363, 342)
# final shape (363, 342) (363, 1)
# stream 22
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 56 ---------
# replay#64 (74, 342) (74,)
# n-reward.shape (74,)
# n-input.shape (74, 342)
# --------- batch: 1 | idx: 70 ---------
# replay#64 (101, 342) (101,)
# n-reward.shape (101,)
# n-input.shape (175, 342)
# final shape (175, 342) (175, 1)
# stream 23
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 124 ---------
# replay#64 (84, 342) (84,)
# n-reward.shape (84,)
# n-input.shape (84, 342)
# --------- batch: 1 | idx: 111 ---------
# replay#64 (182, 342) (182,)
# n-reward.shape (182,)
# n-input.shape (266, 342)
# final shape (266, 342) (266, 1)
# stream 24
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 102 ---------
# replay#64 (196, 342) (196,)
# n-reward.shape (196,)
# n-input.shape (196, 342)
# --------- batch: 1 | idx: 92 ---------
# replay#64 (183, 342) (183,)
# n-reward.shape (183,)
# n-input.shape (379, 342)
# final shape (379, 342) (379, 1)
# stream 25
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 8 ---------
# replay#64 (39, 342) (39,)
# n-reward.shape (39,)
# n-input.shape (39, 342)
# --------- batch: 1 | idx: 105 ---------
# replay#64 (181, 342) (181,)
# n-reward.shape (181,)
# n-input.shape (220, 342)
# final shape (220, 342) (220, 1)
# stream 26
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 74 ---------
# replay#64 (132, 342) (132,)
# n-reward.shape (132,)
# n-input.shape (132, 342)
# --------- batch: 1 | idx: 140 ---------
# replay#64 (71, 342) (71,)
# n-reward.shape (71,)
# n-input.shape (203, 342)
# final shape (203, 342) (203, 1)
# stream 27
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 15 ---------
# replay#64 (15, 342) (15,)
# n-reward.shape (15,)
# n-input.shape (15, 342)
# --------- batch: 1 | idx: 120 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (97, 342)
# final shape (97, 342) (97, 1)
# stream 28
# 30 False
# -----start enumerating-----
# --------- batch: 0 | idx: 120 ---------
# replay#64 (82, 342) (82,)
# n-reward.shape (82,)
# n-input.shape (82, 342)
# --------- batch: 1 | idx: 109 ---------
# replay#64 (178, 342) (178,)
# n-reward.shape (178,)
# n-input.shape (260, 342)
# final shape (260, 342) (260, 1)
# stream 29
# 30 True
# -----start enumerating-----
# --------- batch: 0 | idx: 18 ---------
# replay#64 (21, 342) (21,)
# n-reward.shape (21,)
# n-input.shape (21, 342)
# --------- batch: 1 | idx: 92 ---------
# replay#64 (183, 342) (183,)
# n-reward.shape (183,)
# n-input.shape (204, 342)
# final shape (204, 342) (204, 1)
# stream 0
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 21 ---------
# replay#64 (12, 342) (12,)
# g-reward.shape (12,)
# g-input.shape (12, 342)
# --------- batch: 1 | idx: 95 ---------
# replay#64 (176, 342) (176,)
# n-reward.shape (176,)
# n-input.shape (188, 342)
# final shape (188, 342) (188, 1)
# stream 1
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 96 ---------
# replay#64 (122, 342) (122,)
# n-reward.shape (122,)
# n-input.shape (122, 342)
# --------- batch: 1 | idx: 18 ---------
# replay#64 (21, 342) (21,)
# n-reward.shape (21,)
# n-input.shape (143, 342)
# final shape (143, 342) (143, 1)
# stream 2
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 43 ---------
# replay#64 (109, 342) (109,)
# n-reward.shape (109,)
# n-input.shape (109, 342)
# --------- batch: 1 | idx: 114 ---------
# replay#64 (197, 342) (197,)
# n-reward.shape (197,)
# n-input.shape (306, 342)
# final shape (306, 342) (306, 1)
# stream 3
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 20 ---------
# replay#64 (10, 342) (10,)
# n-reward.shape (10,)
# n-input.shape (10, 342)
# --------- batch: 1 | idx: 104 ---------
# replay#64 (176, 342) (176,)
# n-reward.shape (176,)
# n-input.shape (186, 342)
# final shape (186, 342) (186, 1)
# stream 4
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 15 ---------
# replay#64 (15, 342) (15,)
# n-reward.shape (15,)
# n-input.shape (15, 342)
# --------- batch: 1 | idx: 147 ---------
# replay#64 (4043, 342) (4043,)
# n-reward.shape (4043,)
# n-input.shape (4058, 342)
# final shape (4058, 342) (4058, 1)
# stream 5
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 105 ---------
# replay#64 (181, 342) (181,)
# n-reward.shape (181,)
# n-input.shape (181, 342)
# --------- batch: 1 | idx: 92 ---------
# replay#64 (183, 342) (183,)
# n-reward.shape (183,)
# n-input.shape (364, 342)
# final shape (364, 342) (364, 1)
# stream 6
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 79 ---------
# replay#64 (1, 342) (1,)
# n-reward.shape (1,)
# n-input.shape (1, 342)
# --------- batch: 1 | idx: 75 ---------
# replay#64 (105, 342) (105,)
# n-reward.shape (105,)
# n-input.shape (106, 342)
# final shape (106, 342) (106, 1)
# stream 7
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 146 ---------
# replay#64 (58, 342) (58,)
# n-reward.shape (58,)
# n-input.shape (58, 342)
# --------- batch: 1 | idx: 145 ---------
# replay#64 (58, 342) (58,)
# g-reward.shape (58,)
# g-input.shape (116, 342)
# final shape (116, 342) (116, 1)
# stream 8
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 78 ---------
# replay#64 (115, 342) (115,)
# n-reward.shape (115,)
# n-input.shape (115, 342)
# --------- batch: 1 | idx: 32 ---------
# replay#64 (93, 342) (93,)
# n-reward.shape (93,)
# n-input.shape (208, 342)
# final shape (208, 342) (208, 1)
# stream 9
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 68 ---------
# replay#64 (4902, 342) (4902,)
# n-reward.shape (4902,)
# n-input.shape (4902, 342)
# --------- batch: 1 | idx: 81 ---------
# replay#64 (117, 342) (117,)
# n-reward.shape (117,)
# n-input.shape (5019, 342)
# final shape (5019, 342) (5019, 1)
# stream 10
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 146 ---------
# replay#64 (58, 342) (58,)
# n-reward.shape (58,)
# n-input.shape (58, 342)
# --------- batch: 1 | idx: 53 ---------
# replay#64 (74, 342) (74,)
# n-reward.shape (74,)
# n-input.shape (132, 342)
# final shape (132, 342) (132, 1)
# stream 11
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 73 ---------
# replay#64 (120, 342) (120,)
# n-reward.shape (120,)
# n-input.shape (120, 342)
# --------- batch: 1 | idx: 91 ---------
# replay#64 (122, 342) (122,)
# n-reward.shape (122,)
# n-input.shape (242, 342)
# final shape (242, 342) (242, 1)
# stream 12
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 60 ---------
# replay#64 (99, 342) (99,)
# n-reward.shape (99,)
# n-input.shape (99, 342)
# --------- batch: 1 | idx: 55 ---------
# replay#64 (22, 342) (22,)
# n-reward.shape (22,)
# n-input.shape (121, 342)
# final shape (121, 342) (121, 1)
# stream 13
# 121 False
# -----start enumerating-----
# --------- batch: 0 | idx: 26 ---------
# KeyboardInterruptTraceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-26-c3341357a45d> in train(model, exp_replay, epochs, batch_size, num_episode, verbose, reward_set, hist, c_hist, rec_list)
#      70
#      71         # --------------- Load batch of experiences --------------------
# ---> 72         inputs, targets = exp_replay.get_batch(model, batch_size=batch_size)
#      73         # train model on experiences
#      74         batch_loss = model.train_on_batch(inputs, targets)
#
# <ipython-input-11-4b4354bc3c81> in get_batch(self, model, batch_size)
#      63       here should be state_t * all_items
#      64       '''
# ---> 65       state_t = get_input(state_t, current_stream).astype('float32')
#      66       print('replay#64', state_t.shape, reward_t.shape)
#      67       # puts state into input
#
# <ipython-input-6-921c0a3df43c> in get_input(input_state, current_stream)
#      13
#      14   # Create new df
# ---> 15   stream_item_feat = pd.DataFrame(columns=INPUT_DF_COL)
#      16
#      17   # Fill in other context
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      91     axes = [columns, index]
#      92
# ---> 93     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      94
#      95
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1690
#    1691     try:
# -> 1692         blocks = form_blocks(arrays, names, axes)
#    1693         mgr = BlockManager(blocks, axes)
#    1694         mgr._consolidate_inplace()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in form_blocks(arrays, names, axes)
#    1744
#    1745         block_type = get_block_type(v)
# -> 1746         items_dict[block_type.__name__].append((i, k, v))
#    1747
#    1748     blocks: List[Block] = []
#
# KeyboardInterrupt:
