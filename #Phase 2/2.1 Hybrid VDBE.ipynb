# %% [markdown]
# # DDPG
# > Experiment list: Param Noise + VDBE

# %%
import pandas as pd
import numpy as np
import itertools
from tqdm.notebook import tqdm
import pickle

import torch
import torch.utils.data as data
from torch.utils.data import DataLoader
import torch.utils.data.sampler as sampler
import torch.nn as nn
import torch.nn.functional as F

from matplotlib import pyplot as plt
from collections import defaultdict
import warnings
from sklearn.preprocessing import LabelEncoder
import random
from datetime import datetime
import pytz
import line_profiler
from functools import reduce

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Fix Random Seeds

# %%
def same_seeds(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  
  np.random.seed(seed)  
  torch.backends.cudnn.benchmark = False
  torch.backends.cudnn.deterministic = True

same_seeds(0)

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Available Files
#
# ||Title|File Name|
# |---|-----|---------|
# |order|Stream group by streamers|`streamer_stream_dict.pkl`|
# ||Stream list|`stream_list.pkl`|
# |Context|Final user context|`user_context.pkl`|
# ||Streamer context|`streamer.pkl`|
# ||Item context|`item_pca_df.pkl`|
# |Aux|stream: items list|`stream_item_dict.pkl`|
# ||stream: users list|`stream_users_dict.pkl`|
# ||item list the consumer actually bought|`user_bought_dict.pkl`|
# |Explore-Diff|PCA based diff vector|`diff_vectors_pca.pkl`|
# ||SVD based diff vector|`diff_vectors_svd.pkl`|
# ||VAE based diff vector|`diff_vectors_vae.pkl`|
# |Threshold|VAE reconstruction error df|`vae_recons_df.pkl`|

# %%
# STREAMER_STREAM_DICT = pd.read_pickle('../../data/streamer_stream_dict.pkl')
STREAM_LIST = pd.read_pickle('../../data/stream_list.pkl')
USER_CONTEXT = pd.read_pickle('../../data/user_context.pkl')
# STREAMER = pd.read_pickle('../../data/streamer.pkl')
ITEM_PCA_DF = pd.read_pickle('../../data/item_pca_df.pkl')
STREAM_ITEM_DICT = pd.read_pickle('../../data/stream_item_dict.pkl')
USER_BOUGHT_DICT = pd.read_pickle('../../data/user_bought_dict.pkl')
STREAM_USER_DICT = pd.read_pickle('../../data/stream_users_dict.pkl')
# Current used diff
ITEM_DIFF = pd.read_pickle('../../data/item_diff_vectors.pkl')
STREAM_ORDER_CNT = pd.read_pickle('../../data/stream_order_cnt_list.pkl')

# %%
DIFF_PCA = pd.read_pickle('../../data/diff_vectors_pca.pkl')
# DIFF_SVD = pd.read_pickle('../../data/diff_vectors_svd.pkl')
# DIFF_VAE = pd.read_pickle('../../data/diff_vectors_vae.pkl')
# VAE_RECONS_DF = pd.read_pickle('../../data/vae_recons_df.pkl')
# VAE_RECONS64_DF = pd.read_pickle('../../data/vae_recons_64_df.pkl')
# MUL150_PCA = pd.read_pickle('../../data/mul150_pca_diff.pkl')
# MUL150_VAE = pd.read_pickle('../../data/mul150_vae_diff.pkl')
# MUL64_PCA = pd.read_pickle('../../data/mul64_pca_diff.pkl')
# MUL64_VAE = pd.read_pickle('../../data/mul64_vae_diff.pkl')

# %% [markdown]
# ---

# %% [markdown]
# ## Replay

# %%
class RingBuffer(object):
    def __init__(self, maxlen):
        self.maxlen = maxlen
        self.start = 0
        self.length = 0
        self.data = [None for _ in range(maxlen)]

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        if idx < 0 or idx >= self.length:
            raise KeyError()
        return self.data[(self.start + idx) % self.maxlen]

    def append(self, v):
        if self.length < self.maxlen:
            # We have space, simply increase the length.
            self.length += 1
        elif self.length == self.maxlen:
            # No space, "remove" the first item.
            self.start = (self.start + 1) % self.maxlen
        else:
            # This should never happen.
            raise RuntimeError()
        self.data[(self.start + self.length - 1) % self.maxlen] = v

class ReplayBuffer:
  def __init__(self, limit=10000):
    self.limit = limit
    # init 4 RingBuffers: states/actions/rewards/ongoing
    self.states_buffer = RingBuffer(limit)
    self.next_states_buffer = RingBuffer(limit)
    self.actions_buffer = RingBuffer(limit)
    self.rewards_buffer = RingBuffer(limit)
    self.ongoings_buffer = RingBuffer(limit)
    
  def __len__(self):
    assert len(self.states_buffer) == len(self.next_states_buffer) == len(self.actions_buffer) == \
           len(self.rewards_buffer) == len(self.ongoings_buffer)
    return len(self.states_buffer)

  def remember(self, state, actions, reward, next_state, ongoing):
    assert len(self.states_buffer) == len(self.next_states_buffer) == len(self.actions_buffer) == \
           len(self.rewards_buffer) == len(self.ongoings_buffer)
    # append each element separately in different list
    self.states_buffer.append(state)
    self.actions_buffer.append(actions)
    self.rewards_buffer.append(reward)
    self.next_states_buffer.append(next_state)
    self.ongoings_buffer.append(ongoing)
    
  def get_batch(self, batch_size=100):
    assert len(self.states_buffer) == len(self.next_states_buffer) == len(self.actions_buffer) == \
           len(self.rewards_buffer) == len(self.ongoings_buffer)
    # same for sample_and_split
    states0_batch = []
    states1_batch = []
    actions_batch = []
    rewards_batch = []
    ongoings_batch = []
    batch_indexs = np.random.randint(0, len(self.states_buffer), size=min(len(self.states_buffer), batch_size))
    for i in batch_indexs:
      states0_batch.append(USER_CONTEXT.xs(self.states_buffer[i]))
      states1_batch.append(USER_CONTEXT.xs(self.next_states_buffer[i]))
      actions_batch.append(self.actions_buffer[i])
      rewards_batch.append(self.rewards_buffer[i])
      ongoings_batch.append(self.ongoings_buffer[i])
    assert len(states0_batch) == len(states1_batch) == len(actions_batch) == \
           len(rewards_batch) == len(ongoings_batch)
    return np.array(states0_batch), np.array(actions_batch), np.array(rewards_batch), np.array(states1_batch), np.array(ongoings_batch)

# %% [markdown]
# ## Epsilon

# %%
from abc import ABC, abstractmethod
import math

class Epsilon(ABC):

  @abstractmethod
  def get_epsilon(self, key):
    pass
  
  @abstractmethod
  def update_at_step(self, key, data, delta):
    pass
  
  @abstractmethod
  def update_at_epoch(self, data):
    pass

class Decay(Epsilon):
  # Ref: Decay(0.5, 0.85)
  '''
  Epsilon Decay EE method with update/decay at epoch
  '''
  def __init__(self, initial, epoch_decay=1.0, step_decay=1.0):
    self.initial = initial
    self.epoch_decay, self.step_decay = epoch_decay, step_decay
    self.epsilon = self.initial
    
  def clear(self):
    self.epsilon = self.initial # should be 4 for origin setting
    
  def get_epsilon(self, key):
    return self.epsilon
  
  def update_at_step(self, key, data, delta):
    # origin setting
    # pass
    # exponentially
    i = data[1]
    self.epsilon = 4 / ((i + 1) ** (1 / 4))
    
  def update_at_epoch(self, data):
    # origin settings
    # epoch = data
    # self.epsilon = 4 / ((epoch + 1) ** (1 / 2))
    # exponentially
    self.epsilon *= self.epoch_decay


class VDBE(Epsilon):
  # VDBE(0.5, 0.01)
  def __init__(self, initial, sigma):
    self.initial = initial
    self.sigma = sigma
    self.epsilon = defaultdict(lambda: self.initial)

  def get_epsilon(self, key):
    return self.epsilon[key]
  
  def update_at_step(self, key, data, delta):
    td_error = data
    coeff = math.exp(-abs(td_error) / self.sigma)
    f = (1.0 - coeff) / (1.0 + coeff)
    self.epsilon[key] = delta * f + (1.0 - delta) * self.epsilon[key]
  
  def update_at_epoch(self, data):
    pass

# %% [markdown]
# ## Random Process

# %%
class RandomProcess(object):
    def reset_states(self):
        pass

class AnnealedGaussianProcess(RandomProcess):
    def __init__(self, mu, sigma, sigma_min, n_steps_annealing):
        self.mu = mu
        self.sigma = sigma
        self.n_steps = 0

        if sigma_min is not None:
            self.m = -float(sigma - sigma_min) / float(n_steps_annealing)
            self.c = sigma
            self.sigma_min = sigma_min
        else:
            self.m = 0.
            self.c = sigma
            self.sigma_min = sigma

    @property
    def current_sigma(self):
        sigma = max(self.sigma_min, self.m * float(self.n_steps) + self.c)
        return sigma


# Based on http://math.stackexchange.com/questions/1287634/implementing-ornstein-uhlenbeck-in-matlab
class OrnsteinUhlenbeckProcess(AnnealedGaussianProcess):
    def __init__(self, theta, mu=0., sigma=1., dt=1e-2, x0=None, size=1, sigma_min=None, n_steps_annealing=1000):
        super(OrnsteinUhlenbeckProcess, self).__init__(mu=mu, sigma=sigma, sigma_min=sigma_min, n_steps_annealing=n_steps_annealing)
        self.theta = theta
        self.mu = mu
        self.dt = dt
        self.x0 = x0
        self.size = size
        self.reset_states()

    def sample(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + self.current_sigma * np.sqrt(self.dt) * np.random.normal(size=self.size)
        self.x_prev = x
        self.n_steps += 1
        return x

    def reset_states(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros(self.size)

# %% [markdown]
# ## Models

# %%
def fanin_init(size, fanin=None):
    fanin = fanin or size[0]
    v = 1. / np.sqrt(fanin)
    return torch.Tensor(size).uniform_(-v, v)

class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, mode, hidden1=400, hidden2=300, init_w=3e-3):
        super(Actor, self).__init__()
        self.mode = mode
        self.fc1 = nn.Linear(state_dim, hidden1)
        self.fc2 = nn.Linear(hidden1, hidden2)
        self.fc3 = nn.Linear(hidden2, action_dim)
        self.norm1 = nn.LayerNorm(hidden1)
        self.norm2 = nn.LayerNorm(hidden2)
        self.norm3 = nn.LayerNorm(action_dim)
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()
        self.init_weights(init_w)
    
    def init_weights(self, init_w):
        self.fc1.weight.data = fanin_init(self.fc1.weight.data.size())
        self.fc2.weight.data = fanin_init(self.fc2.weight.data.size())
        self.fc3.weight.data.uniform_(-init_w, init_w)
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.norm1(out)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.fc3(out)
        out = self.norm3(out)
        out = self.tanh(out)
        return out

    def add_parameter_noise(self, scalar=.1):
        self.fc1.weight.data += torch.randn_like(self.fc1.weight.data) * scalar
        self.fc2.weight.data += torch.randn_like(self.fc2.weight.data) * scalar
        self.fc3.weight.data += torch.randn_like(self.fc3.weight.data) * scalar


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim, hidden1=400, hidden2=300, init_w=3e-3):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(state_dim, hidden1)
        self.fc2 = nn.Linear(hidden1+action_dim, hidden2)
        self.fc3 = nn.Linear(hidden2, 1)
        self.relu = nn.ReLU()
        self.init_weights(init_w)
    
    def init_weights(self, init_w):
        self.fc1.weight.data = fanin_init(self.fc1.weight.data.size())
        self.fc2.weight.data = fanin_init(self.fc2.weight.data.size())
        self.fc3.weight.data.uniform_(-init_w, init_w)
    
    def forward(self, xs):
        x, a = xs
        out = self.fc1(x)
        out = self.relu(out)
        # debug()
        out = self.fc2(torch.cat([out,a],1))
        out = self.relu(out)
        out = self.fc3(out)
        return out

# %% [markdown]
# ## DDPG

# %%
def to_tensor(input_df):
  return torch.tensor(input_df).to(DEVICE).float()

class DDPG(object):
  def __init__(self, actor_lr, critic_lr, state_dim, action_dim, mode='baseline',
               hidden1=400, hidden2=300, diff_multiplier=5, vdbe_init=.5, vdbe_sigma=.01,
               top_k=10, max_memory=10000, depsilon=50000, discount=0.99,
               tau=0.001, batch_size=100, ou_theta=0.15, ou_mu=0.0, ou_sigma=0.2, 
               param_noise_scalar=.05, param_noise_scalar_alpha=1.01, desired_distance=.7):
    # State & Action dimension
    self.state_dim = state_dim
    self.action_dim = action_dim
    
    # Mode settings
    # baseline
    # diff: diff_pca, diff_svd, diff_vae
    # threshold: thres_vae, thres_vdbe
    # multiplier: MUL150_PCA, MUL150_VAE, MUL64_PCA, MUL64_VAE
    # Parameter noise: PARAM_NOISE
    self.mode = mode
    self.diff_multiplier = diff_multiplier
    
    # for VDBE (0.5, 0.01)
    self.vdbe = VDBE(vdbe_init, vdbe_sigma)
    
    # Param Noise
    self.distances = []
    self.desired_distance = desired_distance
    self.param_noise_scalar = param_noise_scalar
    self.param_noise_scalar_alpha = param_noise_scalar_alpha

    # Init Actor
    self.actor = Actor(state_dim, action_dim, mode, hidden1, hidden2)
    self.actor_noised = Actor(state_dim, action_dim, mode, hidden1, hidden2)
    self.actor_target = Actor(state_dim, action_dim, mode, hidden1, hidden2)
    self.actor_optim = torch.optim.Adam(self.actor.parameters(), lr=actor_lr)
    # Init Critic
    self.critic = Critic(state_dim, action_dim, hidden1, hidden2)
    self.critic_target = Critic(state_dim, action_dim, hidden1, hidden2)
    self.critic_optim = torch.optim.Adam(self.critic.parameters(), lr=critic_lr)

    # Memory
    self.buffer = ReplayBuffer(limit=max_memory)

    # Exploration
    self.epsilon = 1.0
    self.depsilon = 1.0 / depsilon
    self.random_process = OrnsteinUhlenbeckProcess(size=action_dim, theta=ou_theta, mu=ou_mu, sigma=ou_sigma)

    # Reward related
    self.top_k = top_k
    
    # Loss Function
    self.loss_fn = nn.MSELoss()
    
    # Hyperparameters
    self.discount = discount
    self.tau = tau
    self.batch_size = batch_size

    # Network to cuda
    self.actor.to(DEVICE)
    self.actor_noised.to(DEVICE)
    self.critic.to(DEVICE)
    self.actor_target.to(DEVICE)
    self.critic_target.to(DEVICE)
    
  def random_action(self):
    action = np.random.uniform(-1.,1.,self.action_dim).astype('float32')
    self.action = action
    return action
    
  def generate_latent_action(self, state, decay_epsilon=True, vdbe_epsilon=False):
    action = self.actor(to_tensor(state))
    '''
    Param Noise
    '''
    with torch.no_grad():
      # hard copy the actor to actor_noised
      self.actor_noised.load_state_dict(self.actor.state_dict().copy())

      # add noise to the copy
      self.actor_noised.add_parameter_noise(self.param_noise_scalar)

      # get the next action values from the noised actor
      action_noised = self.actor_noised(to_tensor(state))

      # meassure the distance between the action values from the regular and 
      # the noised actor to adjust the amount of noise that will be added next round
      distance = torch.sqrt(torch.mean(torch.square(action - action_noised))).cpu().detach().numpy()

      # adjust the amount of noise given to the actor_noised
      if distance < self.desired_distance:
          self.param_noise_scalar *= self.param_noise_scalar_alpha
      else:
          self.param_noise_scalar /= self.param_noise_scalar_alpha

      # set the noised action as action
      action = action_noised
    '''
    Add the diff vector to action
    '''
    if self.mode != 'baseline':
      current_diff = globals()[self.mode.upper()]

      # if self.mode == 'thres_vae' and state.name in current_diff.index:
      #   if VAE_RECONS_DF.loc[state.name][0] > 0.275:
      #     action += to_tensor(DIFF_VAE.loc[state.name])
      # elif self.mode == 'thres_vae_64' and state.name in current_diff.index:
      #   if VAE_RECONS64_DF.loc[state.name][0] > 0.02:
      #     action += to_tensor(DIFF_VAE.loc[state.name])
      if state.name in current_diff.index:
        # for mode = [diff_pca, diff_svd, diff_vae, MUL150_VAE, MUL64_VAE, ITEM_DIFF]
        vdbe_multiplier = self.vdbe.get_epsilon(self.curr_user)
        action += to_tensor(current_diff.loc[state.name]) * self.diff_multiplier * vdbe_multiplier

    # action +=  * torch.tensor(self.random_process.sample()).to(DEVICE).float()
    action = torch.clamp(action, -1., 1.).cpu().detach().numpy()

    if decay_epsilon:
      self.epsilon -= self.depsilon
        
    self.action = action
    return action
  
  def get_actions_rewards(self):
    true_list = USER_BOUGHT_DICT[self.curr_user]
    hit_list, rewarded_items = [], set()
    self.action_list = ITEM_PCA_DF.iloc[self.curr_stream_items].apply(lambda x: np.dot(x, self.action), axis=1).nlargest(self.top_k).index
    for a in self.action_list:
      if a in true_list:
        hit_list.append(1)
        rewarded_items.add(a)
      else: hit_list.append(0)
    res = sum(hit_list)
    return res, rewarded_items
    
  def update_policy(self):
    # Sample batch
    state_batch, action_batch, reward_batch, \
    next_state_batch, ongoing_batch = self.buffer.get_batch(self.batch_size)
    
    # Prepare for the target q batch
    next_q_values = self.critic_target([
        to_tensor(next_state_batch).detach(),
        self.actor_target(to_tensor(next_state_batch).detach()),
    ])
    
    # 如果 ongoing 為 True(1) 時，乘以 next_q 會有值
    # 但是 ongoing 為 False(0) 時，乘以 next_q 會等於 0
    target_q_batch = to_tensor(reward_batch).view(next_q_values.shape) + \
                       self.discount*to_tensor(ongoing_batch).view(next_q_values.shape)*next_q_values.detach()

    # Critic update
    self.critic_optim.zero_grad()

    q_batch = self.critic([ to_tensor(state_batch), to_tensor(action_batch) ])

    value_loss = self.loss_fn(q_batch, target_q_batch)
    value_loss.backward()
    self.critic_optim.step()

    # Actor update
    self.actor_optim.zero_grad()

    policy_loss = -self.critic([
        to_tensor(state_batch),
        self.actor(to_tensor(state_batch))
    ])

    policy_loss = policy_loss.mean()
    policy_loss.backward()
    self.actor_optim.step()

    # Target update
    self._soft_update(self.actor_target, self.actor)
    self._soft_update(self.critic_target, self.critic)
    return value_loss, policy_loss
    
  def _soft_update(self, target, source):
    for target_param, param in zip(target.parameters(), source.parameters()):
        target_param.data.copy_(
            target_param.data * (1.0 - self.tau) + param.data * self.tau
        )

# %% [markdown]
# ## Main Method

# %%
def train(agent, reward_records=[], avg_rewards=[], hit_ratios=[], regret_list=[], coverage_list=[], diversity_list=[], warmup=100, ep_len=4000):
  agent.actor.train(True)
  agent.critic.train(True)
  batch_value_loss, batch_policy_loss = 0., 0.
  step_value_loss, step_policy_loss = 0., 0.
  step = 0
  # self.epsilon.clear()

  # ------------------- Episode (State) -------------------------------
  for stream in tqdm(STREAM_LIST[:3300]):
    # self.__user_episode_context()
    users = STREAM_USER_DICT[stream]

    agent.curr_stream = stream
    agent.curr_stream_items = STREAM_ITEM_DICT[stream]
    batch_value_loss, batch_policy_loss = 0., 0.
    stream_reward = 0
    false_positive_cnt = 0
    diversity_prod_set = set()
    coverage_rewarded_items = set()

    # ----------------- Runs (User under stream) ---------------------
    for i, user in enumerate(users):
      # update step
      step += 1
      
      # state & ongoing
      agent.curr_user = user
      state = USER_CONTEXT.loc[(user, stream)]
      ongoing = i != len(users) - 1

      # --------------- Actor net choose actions ----------------------
      # make actor to choose action
      # action = latent vector
      if step <= warmup:
        action = agent.random_action()
      else:
        action = agent.generate_latent_action(state)
          
      # --------------- Get next state & info to store ---------------
      # Generate reward
      reward, curr_rewarded_items = agent.get_actions_rewards()

      # next_state: next user's state
      next_user = users[i + 1] if i + 1 < len(users) else None
      
      # update metrics
      reward_records.append(reward)
      stream_reward += reward
      false_positive_cnt += (10 - reward)
      coverage_rewarded_items = coverage_rewarded_items | curr_rewarded_items
      diversity_prod_set = diversity_prod_set | set(agent.action_list)
      
      # Remember only when reward > 0 or the memory is short
      if reward > 0 or len(agent.buffer) < 10:
        storing_state = (user, stream)
        storing_next_state = (next_user, stream) if next_user else storing_state
        agent.buffer.remember(storing_state, action, reward, storing_next_state, ongoing)

        
      # --------------- Train on Actor and Critic --------------------
      # store pre-training value for td_error
      state = to_tensor(state).view(1, 175)
      action = to_tensor(action).view(1, 150)
      old_Q = agent.critic([state, action]).cpu().detach().numpy()
      
      if step > warmup :
        step_value_loss, step_policy_loss = agent.update_policy()
      
      # store post-training value for td_error
      new_Q = agent.critic([state, action]).cpu().detach().numpy()
      
      batch_value_loss += step_value_loss
      batch_policy_loss += step_policy_loss
      
      # --------------- Update with TD error -------------------------
      agent.vdbe.update_at_step(user, (new_Q - old_Q), 1/len(agent.curr_stream_items))

    # --------------- Inspecting result at step -------------------------
    ep_avg_reward = round(sum(reward_records)/step, 2)
    avg_rewards.append(ep_avg_reward)
    
    ground_truth = STREAM_ORDER_CNT.iloc[stream]
    # hit ratio
    hr10 = stream_reward / ground_truth
    hit_ratios.append(hr10)
    # regret
    regret = false_positive_cnt / len(users)
    regret_list.append(regret)
    # coverage
    coverage = len(coverage_rewarded_items) / ground_truth
    coverage_list.append(coverage)
    # diversity
    diversity = len(diversity_prod_set) / len(STREAM_ITEM_DICT[stream])
    diversity_list.append(diversity)
    
    print(f'Stream: {stream}, user_count: {len(users)}, avg_reward@stream: {round(stream_reward/len(users), 2)}, avg_reward: {ep_avg_reward}, \
hr10: {round(hr10, 3)}, regret: {round(regret, 3)}, coverage: {round(coverage, 3)}, diversity: {round(diversity, 3)}, \
batch_value_loss: {round(float(batch_value_loss)/len(users), 3)}')
    
    # if len(reward_records) >= 247581: break

# %%
pd.set_option('mode.chained_assignment', None)

# parameters
actor_lr = 1.0e-3
critic_lr = 1.0e-3
state_dim = USER_CONTEXT.shape[1]
action_dim = ITEM_PCA_DF.shape[1]
hidden1 = 400
hidden2 = 300
diff_multiplier = 4
vdbe_init=.5
vdbe_sigma=.01
top_k = 10
max_memory = 10000
depsilon = 50000
discount = 0.99
tau = 0.001
batch_size = 100
ou_theta = 0.15
ou_mu = .0
ou_sigma = 0.2
param_noise_scalar = 0.05
param_noise_scalar_alpha = 1.01
desired_distance = 0.7


# MODE PARAM
mode = 'diff_pca'
# Mode settings
# baseline
# diff: diff_pca, diff_svd, diff_vae
# threshold: thres_vae, thres_vae_64, thres_vdbe
# multiplier: MUL150_PCA, MUL150_VAE, MUL64_PCA, MUL64_VAE
# item_diff: ITEM_DIFF
# Parameter noise: PARAM_NOISE

warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Execute

# %%
ddpg_agent = DDPG(actor_lr, critic_lr, state_dim, action_dim, mode, hidden1, hidden2, diff_multiplier,
                  vdbe_init, vdbe_sigma,
                  top_k, max_memory, depsilon, discount, tau, batch_size, ou_theta, ou_mu, ou_sigma, 
                  param_noise_scalar, param_noise_scalar_alpha, desired_distance)
reward_records = []
avg_rewards = []
hit_ratios, regret_list, coverage_list, diversity_list = [], [], [], []

# %%
train(ddpg_agent, reward_records, avg_rewards, hit_ratios, regret_list, coverage_list, diversity_list)
# Out:
#   0%|          | 0/3300 [00:00<?, ?it/s]
# Stream: 0, user_count: 56, avg_reward@stream: 0.5, avg_reward: 0.5, hr10: 0.373, regret: 9.5, coverage: 0.28, diversity: 1.0, batch_value_loss: 0.0
# Stream: 1, user_count: 534, avg_reward@stream: 0.51, avg_reward: 0.51, hr10: 0.162, regret: 9.494, coverage: 0.038, diversity: 1.0, batch_value_loss: 0.08
# Stream: 2, user_count: 56, avg_reward@stream: 1.39, avg_reward: 0.58, hr10: 0.772, regret: 8.607, coverage: 0.149, diversity: 1.0, batch_value_loss: 0.044
# Stream: 3, user_count: 29, avg_reward@stream: 1.28, avg_reward: 0.61, hr10: 0.804, regret: 8.724, coverage: 0.304, diversity: 1.0, batch_value_loss: 0.049
# Stream: 4, user_count: 104, avg_reward@stream: 0.34, avg_reward: 0.58, hr10: 0.23, regret: 9.663, coverage: 0.105, diversity: 0.903, batch_value_loss: 0.025
# Stream: 5, user_count: 83, avg_reward@stream: 0.84, avg_reward: 0.6, hr10: 0.778, regret: 9.157, coverage: 0.111, diversity: 1.0, batch_value_loss: 0.011
# Stream: 6, user_count: 37, avg_reward@stream: 0.7, avg_reward: 0.61, hr10: 0.351, regret: 9.297, coverage: 0.216, diversity: 0.919, batch_value_loss: 0.012
# Stream: 7, user_count: 213, avg_reward@stream: 0.32, avg_reward: 0.55, hr10: 0.268, regret: 9.676, coverage: 0.086, diversity: 0.957, batch_value_loss: 0.008
# Stream: 8, user_count: 42, avg_reward@stream: 1.02, avg_reward: 0.57, hr10: 1.024, regret: 8.976, coverage: 0.143, diversity: 1.0, batch_value_loss: 0.009
# Stream: 9, user_count: 2628, avg_reward@stream: 0.53, avg_reward: 0.54, hr10: 0.212, regret: 9.471, coverage: 0.008, diversity: 1.0, batch_value_loss: 0.023
# Stream: 10, user_count: 112, avg_reward@stream: 0.38, avg_reward: 0.54, hr10: 0.344, regret: 9.625, coverage: 0.115, diversity: 1.0, batch_value_loss: 0.109
# Stream: 11, user_count: 343, avg_reward@stream: 0.96, avg_reward: 0.57, hr10: 0.496, regret: 9.041, coverage: 0.032, diversity: 1.0, batch_value_loss: 0.092
# Stream: 12, user_count: 14, avg_reward@stream: 0.86, avg_reward: 0.57, hr10: 0.75, regret: 9.143, coverage: 0.625, diversity: 1.0, batch_value_loss: 0.175
# Stream: 13, user_count: 51, avg_reward@stream: 0.29, avg_reward: 0.57, hr10: 0.214, regret: 9.706, coverage: 0.157, diversity: 0.776, batch_value_loss: 0.162
# Stream: 14, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.57, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 0.106
# Stream: 15, user_count: 115, avg_reward@stream: 1.15, avg_reward: 0.58, hr10: 0.576, regret: 8.852, coverage: 0.074, diversity: 1.0, batch_value_loss: 0.335
# Stream: 16, user_count: 26, avg_reward@stream: 1.38, avg_reward: 0.59, hr10: 0.878, regret: 8.615, coverage: 0.293, diversity: 1.0, batch_value_loss: 0.422
# Stream: 17, user_count: 20, avg_reward@stream: 0.8, avg_reward: 0.59, hr10: 0.444, regret: 9.2, coverage: 0.361, diversity: 1.0, batch_value_loss: 0.356
# Stream: 18, user_count: 40, avg_reward@stream: 0.53, avg_reward: 0.59, hr10: 0.389, regret: 9.475, coverage: 0.222, diversity: 0.872, batch_value_loss: 0.261
# Stream: 19, user_count: 34, avg_reward@stream: 0.71, avg_reward: 0.59, hr10: 0.585, regret: 9.294, coverage: 0.366, diversity: 1.0, batch_value_loss: 0.278
# Stream: 20, user_count: 39, avg_reward@stream: 0.41, avg_reward: 0.59, hr10: 0.296, regret: 9.59, coverage: 0.241, diversity: 0.947, batch_value_loss: 0.203
# Stream: 21, user_count: 23, avg_reward@stream: 0.43, avg_reward: 0.59, hr10: 0.37, regret: 9.565, coverage: 0.296, diversity: 0.87, batch_value_loss: 0.181
# Stream: 22, user_count: 45, avg_reward@stream: 0.73, avg_reward: 0.59, hr10: 0.647, regret: 9.267, coverage: 0.255, diversity: 1.0, batch_value_loss: 0.137
# Stream: 23, user_count: 36, avg_reward@stream: 1.0, avg_reward: 0.59, hr10: 0.973, regret: 9.0, coverage: 0.162, diversity: 1.0, batch_value_loss: 0.194
# Stream: 24, user_count: 28, avg_reward@stream: 1.04, avg_reward: 0.59, hr10: 0.967, regret: 8.964, coverage: 0.333, diversity: 1.0, batch_value_loss: 0.302
# Stream: 25, user_count: 101, avg_reward@stream: 0.59, avg_reward: 0.59, hr10: 0.417, regret: 9.406, coverage: 0.125, diversity: 0.938, batch_value_loss: 0.283
# Stream: 26, user_count: 178, avg_reward@stream: 0.53, avg_reward: 0.59, hr10: 0.516, regret: 9.466, coverage: 0.109, diversity: 1.0, batch_value_loss: 0.286
# Stream: 27, user_count: 1447, avg_reward@stream: 0.49, avg_reward: 0.57, hr10: 0.311, regret: 9.505, coverage: 0.013, diversity: 1.0, batch_value_loss: 0.252
# Stream: 28, user_count: 9, avg_reward@stream: 1.0, avg_reward: 0.57, hr10: 0.9, regret: 9.0, coverage: 0.2, diversity: 1.0, batch_value_loss: 0.324
# Stream: 29, user_count: 43, avg_reward@stream: 0.49, avg_reward: 0.57, hr10: 0.309, regret: 9.512, coverage: 0.162, diversity: 0.789, batch_value_loss: 1.225
# Stream: 30, user_count: 64, avg_reward@stream: 0.52, avg_reward: 0.57, hr10: 0.402, regret: 9.484, coverage: 0.22, diversity: 0.933, batch_value_loss: 0.978
# Stream: 31, user_count: 68, avg_reward@stream: 0.57, avg_reward: 0.57, hr10: 0.361, regret: 9.426, coverage: 0.185, diversity: 0.776, batch_value_loss: 0.981
# Stream: 32, user_count: 56, avg_reward@stream: 0.52, avg_reward: 0.57, hr10: 0.408, regret: 9.482, coverage: 0.197, diversity: 0.824, batch_value_loss: 1.51
# Stream: 33, user_count: 128, avg_reward@stream: 1.3, avg_reward: 0.58, hr10: 0.729, regret: 8.695, coverage: 0.07, diversity: 1.0, batch_value_loss: 1.689
# Stream: 34, user_count: 28, avg_reward@stream: 0.71, avg_reward: 0.58, hr10: 0.556, regret: 9.286, coverage: 0.278, diversity: 1.0, batch_value_loss: 1.604
# Stream: 35, user_count: 28, avg_reward@stream: 1.0, avg_reward: 0.59, hr10: 0.8, regret: 9.0, coverage: 0.257, diversity: 1.0, batch_value_loss: 3.594
# Stream: 36, user_count: 127, avg_reward@stream: 1.07, avg_reward: 0.59, hr10: 0.67, regret: 8.929, coverage: 0.079, diversity: 1.0, batch_value_loss: 1.755
# Stream: 37, user_count: 210, avg_reward@stream: 0.6, avg_reward: 0.59, hr10: 0.472, regret: 9.4, coverage: 0.094, diversity: 1.0, batch_value_loss: 1.749
# Stream: 38, user_count: 6, avg_reward@stream: 1.33, avg_reward: 0.59, hr10: 1.0, regret: 8.667, coverage: 0.75, diversity: 1.0, batch_value_loss: 1.558
# Stream: 39, user_count: 55, avg_reward@stream: 0.56, avg_reward: 0.59, hr10: 0.437, regret: 9.436, coverage: 0.225, diversity: 1.0, batch_value_loss: 2.883
# Stream: 40, user_count: 93, avg_reward@stream: 1.37, avg_reward: 0.6, hr10: 0.506, regret: 8.634, coverage: 0.092, diversity: 0.964, batch_value_loss: 2.094
# Stream: 41, user_count: 42, avg_reward@stream: 1.1, avg_reward: 0.61, hr10: 1.022, regret: 8.905, coverage: 0.2, diversity: 1.0, batch_value_loss: 1.984
# Stream: 42, user_count: 125, avg_reward@stream: 0.36, avg_reward: 0.6, hr10: 0.352, regret: 9.64, coverage: 0.094, diversity: 1.0, batch_value_loss: 1.858
# Stream: 43, user_count: 12, avg_reward@stream: 1.33, avg_reward: 0.6, hr10: 1.231, regret: 8.667, coverage: 0.385, diversity: 1.0, batch_value_loss: 1.562
# Stream: 44, user_count: 126, avg_reward@stream: 1.32, avg_reward: 0.62, hr10: 0.769, regret: 8.683, coverage: 0.079, diversity: 1.0, batch_value_loss: 3.416
# Stream: 45, user_count: 8, avg_reward@stream: 1.25, avg_reward: 0.62, hr10: 1.0, regret: 8.75, coverage: 1.0, diversity: 1.0, batch_value_loss: 2.087
# Stream: 46, user_count: 645, avg_reward@stream: 0.36, avg_reward: 0.6, hr10: 0.265, regret: 9.64, coverage: 0.035, diversity: 1.0, batch_value_loss: 2.978
# Stream: 47, user_count: 698, avg_reward@stream: 0.4, avg_reward: 0.58, hr10: 0.306, regret: 9.599, coverage: 0.032, diversity: 1.0, batch_value_loss: 3.002
# Stream: 48, user_count: 107, avg_reward@stream: 1.11, avg_reward: 0.59, hr10: 0.478, regret: 8.888, coverage: 0.104, diversity: 1.0, batch_value_loss: 5.972
# Stream: 49, user_count: 2, avg_reward@stream: 1.0, avg_reward: 0.59, hr10: 1.0, regret: 9.0, coverage: 0.5, diversity: 1.0, batch_value_loss: 4.806
# Stream: 50, user_count: 29, avg_reward@stream: 0.55, avg_reward: 0.59, hr10: 0.552, regret: 9.448, coverage: 0.276, diversity: 1.0, batch_value_loss: 6.633
# Stream: 51, user_count: 6, avg_reward@stream: 1.0, avg_reward: 0.59, hr10: 1.0, regret: 9.0, coverage: 0.167, diversity: 1.0, batch_value_loss: 6.55
# Stream: 52, user_count: 15, avg_reward@stream: 1.0, avg_reward: 0.59, hr10: 1.0, regret: 9.0, coverage: 0.067, diversity: 1.0, batch_value_loss: 6.063
# Stream: 53, user_count: 5, avg_reward@stream: 1.0, avg_reward: 0.59, hr10: 1.0, regret: 9.0, coverage: 0.4, diversity: 1.0, batch_value_loss: 5.322
# Stream: 54, user_count: 20, avg_reward@stream: 0.7, avg_reward: 0.59, hr10: 0.538, regret: 9.3, coverage: 0.423, diversity: 1.0, batch_value_loss: 9.706
# Stream: 55, user_count: 226, avg_reward@stream: 0.92, avg_reward: 0.6, hr10: 0.437, regret: 9.08, coverage: 0.063, diversity: 1.0, batch_value_loss: 9.685
# Stream: 56, user_count: 18, avg_reward@stream: 1.0, avg_reward: 0.6, hr10: 0.9, regret: 9.0, coverage: 0.45, diversity: 1.0, batch_value_loss: 12.736
# Stream: 57, user_count: 36, avg_reward@stream: 0.47, avg_reward: 0.6, hr10: 0.327, regret: 9.528, coverage: 0.212, diversity: 1.0, batch_value_loss: 13.709
# Stream: 58, user_count: 41, avg_reward@stream: 0.63, avg_reward: 0.6, hr10: 0.441, regret: 9.366, coverage: 0.288, diversity: 0.98, batch_value_loss: 12.873
# Stream: 59, user_count: 52, avg_reward@stream: 0.79, avg_reward: 0.6, hr10: 0.774, regret: 9.212, coverage: 0.208, diversity: 1.0, batch_value_loss: 11.674
# Stream: 60, user_count: 7, avg_reward@stream: 1.29, avg_reward: 0.6, hr10: 1.125, regret: 8.714, coverage: 1.0, diversity: 1.0, batch_value_loss: 10.046
# Stream: 61, user_count: 43, avg_reward@stream: 0.56, avg_reward: 0.6, hr10: 0.558, regret: 9.442, coverage: 0.302, diversity: 1.0, batch_value_loss: 10.803
# Stream: 62, user_count: 33, avg_reward@stream: 0.91, avg_reward: 0.6, hr10: 0.909, regret: 9.091, coverage: 0.333, diversity: 1.0, batch_value_loss: 11.678
# Stream: 63, user_count: 46, avg_reward@stream: 1.0, avg_reward: 0.6, hr10: 0.92, regret: 9.0, coverage: 0.2, diversity: 1.0, batch_value_loss: 20.451
# Stream: 64, user_count: 2, avg_reward@stream: 1.0, avg_reward: 0.6, hr10: 1.0, regret: 9.0, coverage: 0.5, diversity: 1.0, batch_value_loss: 12.528
# Stream: 65, user_count: 45, avg_reward@stream: 0.78, avg_reward: 0.6, hr10: 0.778, regret: 9.222, coverage: 0.244, diversity: 1.0, batch_value_loss: 16.343
# Stream: 66, user_count: 15, avg_reward@stream: 0.47, avg_reward: 0.6, hr10: 0.412, regret: 9.533, coverage: 0.412, diversity: 1.0, batch_value_loss: 26.683
# Stream: 67, user_count: 86, avg_reward@stream: 0.69, avg_reward: 0.6, hr10: 0.648, regret: 9.314, coverage: 0.132, diversity: 1.0, batch_value_loss: 15.04
# Stream: 68, user_count: 33, avg_reward@stream: 1.0, avg_reward: 0.6, hr10: 1.0, regret: 9.0, coverage: 0.182, diversity: 1.0, batch_value_loss: 14.515
# Stream: 69, user_count: 71, avg_reward@stream: 1.2, avg_reward: 0.61, hr10: 0.733, regret: 8.803, coverage: 0.121, diversity: 1.0, batch_value_loss: 16.294
# Stream: 70, user_count: 10, avg_reward@stream: 1.4, avg_reward: 0.61, hr10: 1.167, regret: 8.6, coverage: 0.833, diversity: 1.0, batch_value_loss: 31.469
# Stream: 71, user_count: 20, avg_reward@stream: 0.55, avg_reward: 0.61, hr10: 0.44, regret: 9.45, coverage: 0.36, diversity: 1.0, batch_value_loss: 29.455
# Stream: 72, user_count: 24, avg_reward@stream: 1.17, avg_reward: 0.61, hr10: 0.667, regret: 8.833, coverage: 0.31, diversity: 1.0, batch_value_loss: 23.434
# Stream: 73, user_count: 19, avg_reward@stream: 1.21, avg_reward: 0.61, hr10: 0.697, regret: 8.789, coverage: 0.333, diversity: 1.0, batch_value_loss: 21.015
# Stream: 74, user_count: 45, avg_reward@stream: 1.78, avg_reward: 0.62, hr10: 0.976, regret: 8.222, coverage: 0.159, diversity: 1.0, batch_value_loss: 20.216
# Stream: 75, user_count: 85, avg_reward@stream: 1.28, avg_reward: 0.62, hr10: 0.807, regret: 8.718, coverage: 0.111, diversity: 1.0, batch_value_loss: 21.884
# Stream: 76, user_count: 21, avg_reward@stream: 1.29, avg_reward: 0.62, hr10: 0.711, regret: 8.714, coverage: 0.421, diversity: 0.966, batch_value_loss: 23.56
# Stream: 77, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.62, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 247.08
# Stream: 78, user_count: 12, avg_reward@stream: 1.0, avg_reward: 0.62, hr10: 1.0, regret: 9.0, coverage: 0.083, diversity: 1.0, batch_value_loss: 17.16
# Stream: 79, user_count: 32, avg_reward@stream: 1.34, avg_reward: 0.63, hr10: 0.662, regret: 8.656, coverage: 0.246, diversity: 1.0, batch_value_loss: 30.627
# Stream: 80, user_count: 24, avg_reward@stream: 1.83, avg_reward: 0.63, hr10: 1.333, regret: 8.167, coverage: 0.242, diversity: 1.0, batch_value_loss: 27.106
# Stream: 81, user_count: 24, avg_reward@stream: 1.17, avg_reward: 0.63, hr10: 0.7, regret: 8.833, coverage: 0.35, diversity: 1.0, batch_value_loss: 29.149
# Stream: 82, user_count: 8, avg_reward@stream: 1.12, avg_reward: 0.63, hr10: 1.0, regret: 8.875, coverage: 0.444, diversity: 1.0, batch_value_loss: 44.309
# Stream: 83, user_count: 51, avg_reward@stream: 1.02, avg_reward: 0.63, hr10: 0.571, regret: 8.98, coverage: 0.297, diversity: 1.0, batch_value_loss: 33.253
# Stream: 84, user_count: 15, avg_reward@stream: 1.27, avg_reward: 0.63, hr10: 1.188, regret: 8.733, coverage: 0.562, diversity: 1.0, batch_value_loss: 30.686
# Stream: 85, user_count: 5, avg_reward@stream: 2.4, avg_reward: 0.64, hr10: 2.0, regret: 7.6, coverage: 0.833, diversity: 1.0, batch_value_loss: 30.182
# Stream: 86, user_count: 6, avg_reward@stream: 2.17, avg_reward: 0.64, hr10: 1.3, regret: 7.833, coverage: 0.5, diversity: 1.0, batch_value_loss: 26.684
# Stream: 87, user_count: 8, avg_reward@stream: 1.38, avg_reward: 0.64, hr10: 1.222, regret: 8.625, coverage: 0.667, diversity: 1.0, batch_value_loss: 20.745
# Stream: 88, user_count: 2, avg_reward@stream: 1.5, avg_reward: 0.64, hr10: 1.5, regret: 8.5, coverage: 1.0, diversity: 1.0, batch_value_loss: 18.898
# Stream: 89, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.64, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 16.633
# Stream: 90, user_count: 36, avg_reward@stream: 1.75, avg_reward: 0.64, hr10: 1.312, regret: 8.25, coverage: 0.188, diversity: 1.0, batch_value_loss: 35.715
# Stream: 91, user_count: 18, avg_reward@stream: 2.11, avg_reward: 0.64, hr10: 1.652, regret: 7.889, coverage: 0.435, diversity: 1.0, batch_value_loss: 35.312
# Stream: 92, user_count: 42, avg_reward@stream: 1.24, avg_reward: 0.65, hr10: 0.675, regret: 8.762, coverage: 0.273, diversity: 1.0, batch_value_loss: 38.92
# Stream: 93, user_count: 101, avg_reward@stream: 1.14, avg_reward: 0.65, hr10: 0.364, regret: 8.861, coverage: 0.101, diversity: 1.0, batch_value_loss: 40.129
# Stream: 94, user_count: 58, avg_reward@stream: 0.33, avg_reward: 0.65, hr10: 0.209, regret: 9.672, coverage: 0.143, diversity: 0.914, batch_value_loss: 33.48
# Stream: 95, user_count: 37, avg_reward@stream: 1.54, avg_reward: 0.65, hr10: 1.163, regret: 8.459, coverage: 0.204, diversity: 1.0, batch_value_loss: 28.104
# Stream: 96, user_count: 9, avg_reward@stream: 1.89, avg_reward: 0.65, hr10: 1.417, regret: 8.111, coverage: 0.583, diversity: 1.0, batch_value_loss: 34.211
# Stream: 97, user_count: 13, avg_reward@stream: 2.08, avg_reward: 0.65, hr10: 1.421, regret: 7.923, coverage: 0.579, diversity: 1.0, batch_value_loss: 30.04
# Stream: 98, user_count: 26, avg_reward@stream: 1.88, avg_reward: 0.66, hr10: 1.361, regret: 8.115, coverage: 0.278, diversity: 1.0, batch_value_loss: 38.431
# Stream: 99, user_count: 55, avg_reward@stream: 1.75, avg_reward: 0.66, hr10: 1.116, regret: 8.255, coverage: 0.151, diversity: 1.0, batch_value_loss: 42.933
# Stream: 100, user_count: 3, avg_reward@stream: 1.0, avg_reward: 0.66, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 14.702
# Stream: 101, user_count: 13, avg_reward@stream: 1.69, avg_reward: 0.66, hr10: 1.222, regret: 8.308, coverage: 0.389, diversity: 1.0, batch_value_loss: 44.216
# Stream: 102, user_count: 13, avg_reward@stream: 1.08, avg_reward: 0.66, hr10: 0.7, regret: 8.923, coverage: 0.55, diversity: 1.0, batch_value_loss: 26.5
# Stream: 103, user_count: 126, avg_reward@stream: 1.49, avg_reward: 0.67, hr10: 0.913, regret: 8.508, coverage: 0.068, diversity: 1.0, batch_value_loss: 49.855
# Stream: 104, user_count: 37, avg_reward@stream: 1.51, avg_reward: 0.68, hr10: 0.918, regret: 8.486, coverage: 0.213, diversity: 1.0, batch_value_loss: 46.718
# Stream: 105, user_count: 42, avg_reward@stream: 1.6, avg_reward: 0.68, hr10: 1.015, regret: 8.405, coverage: 0.182, diversity: 1.0, batch_value_loss: 45.613
# Stream: 106, user_count: 56, avg_reward@stream: 1.43, avg_reward: 0.68, hr10: 0.684, regret: 8.571, coverage: 0.111, diversity: 1.0, batch_value_loss: 53.58
# Stream: 107, user_count: 21, avg_reward@stream: 1.76, avg_reward: 0.69, hr10: 0.949, regret: 8.238, coverage: 0.308, diversity: 1.0, batch_value_loss: 48.497
# Stream: 108, user_count: 17, avg_reward@stream: 1.94, avg_reward: 0.69, hr10: 1.179, regret: 8.059, coverage: 0.393, diversity: 1.0, batch_value_loss: 65.226
# Stream: 109, user_count: 58, avg_reward@stream: 1.29, avg_reward: 0.69, hr10: 0.658, regret: 8.707, coverage: 0.149, diversity: 1.0, batch_value_loss: 48.192
# Stream: 110, user_count: 30, avg_reward@stream: 1.13, avg_reward: 0.69, hr10: 0.791, regret: 8.867, coverage: 0.372, diversity: 1.0, batch_value_loss: 60.386
# Stream: 111, user_count: 13, avg_reward@stream: 1.23, avg_reward: 0.69, hr10: 0.667, regret: 8.769, coverage: 0.458, diversity: 1.0, batch_value_loss: 46.968
# Stream: 112, user_count: 34, avg_reward@stream: 1.18, avg_reward: 0.69, hr10: 0.606, regret: 8.824, coverage: 0.303, diversity: 1.0, batch_value_loss: 49.522
# Stream: 113, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.69, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 62.358
# Stream: 114, user_count: 117, avg_reward@stream: 0.79, avg_reward: 0.7, hr10: 0.365, regret: 9.205, coverage: 0.118, diversity: 1.0, batch_value_loss: 65.508
# Stream: 115, user_count: 193, avg_reward@stream: 0.88, avg_reward: 0.7, hr10: 0.567, regret: 9.119, coverage: 0.063, diversity: 1.0, batch_value_loss: 56.999
# Stream: 116, user_count: 16, avg_reward@stream: 1.56, avg_reward: 0.7, hr10: 1.19, regret: 8.438, coverage: 0.381, diversity: 1.0, batch_value_loss: 64.139
# Stream: 117, user_count: 11, avg_reward@stream: 1.64, avg_reward: 0.7, hr10: 1.2, regret: 8.364, coverage: 0.6, diversity: 1.0, batch_value_loss: 44.617
# Stream: 118, user_count: 118, avg_reward@stream: 0.99, avg_reward: 0.7, hr10: 0.498, regret: 9.008, coverage: 0.102, diversity: 1.0, batch_value_loss: 63.426
# Stream: 119, user_count: 47, avg_reward@stream: 1.47, avg_reward: 0.71, hr10: 0.932, regret: 8.532, coverage: 0.162, diversity: 1.0, batch_value_loss: 78.334
# Stream: 120, user_count: 48, avg_reward@stream: 0.98, avg_reward: 0.71, hr10: 0.825, regret: 9.021, coverage: 0.404, diversity: 1.0, batch_value_loss: 66.428
# Stream: 121, user_count: 48, avg_reward@stream: 1.21, avg_reward: 0.71, hr10: 0.795, regret: 8.792, coverage: 0.219, diversity: 1.0, batch_value_loss: 76.253
# Stream: 122, user_count: 11, avg_reward@stream: 1.27, avg_reward: 0.71, hr10: 1.0, regret: 8.727, coverage: 0.5, diversity: 1.0, batch_value_loss: 95.21
# Stream: 123, user_count: 25, avg_reward@stream: 1.08, avg_reward: 0.71, hr10: 0.794, regret: 8.92, coverage: 0.324, diversity: 1.0, batch_value_loss: 59.08
# Stream: 124, user_count: 23, avg_reward@stream: 1.61, avg_reward: 0.71, hr10: 1.088, regret: 8.391, coverage: 0.206, diversity: 1.0, batch_value_loss: 86.971
# Stream: 125, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.71, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 127.538
# Stream: 126, user_count: 41, avg_reward@stream: 1.51, avg_reward: 0.72, hr10: 0.984, regret: 8.488, coverage: 0.19, diversity: 1.0, batch_value_loss: 81.383
# Stream: 127, user_count: 39, avg_reward@stream: 1.69, avg_reward: 0.72, hr10: 1.0, regret: 8.308, coverage: 0.273, diversity: 1.0, batch_value_loss: 65.371
# Stream: 128, user_count: 22, avg_reward@stream: 1.32, avg_reward: 0.72, hr10: 0.784, regret: 8.682, coverage: 0.297, diversity: 1.0, batch_value_loss: 86.786
# Stream: 129, user_count: 11, avg_reward@stream: 1.0, avg_reward: 0.72, hr10: 0.917, regret: 9.0, coverage: 0.083, diversity: 1.0, batch_value_loss: 54.124
# Stream: 130, user_count: 25, avg_reward@stream: 1.8, avg_reward: 0.72, hr10: 0.849, regret: 8.2, coverage: 0.226, diversity: 1.0, batch_value_loss: 129.125
# Stream: 131, user_count: 152, avg_reward@stream: 1.45, avg_reward: 0.73, hr10: 0.815, regret: 8.546, coverage: 0.059, diversity: 1.0, batch_value_loss: 92.335
# Stream: 132, user_count: 1539, avg_reward@stream: 0.77, avg_reward: 0.74, hr10: 0.102, regret: 9.226, coverage: 0.008, diversity: 1.0, batch_value_loss: 110.099
# Stream: 133, user_count: 402, avg_reward@stream: 0.22, avg_reward: 0.72, hr10: 0.175, regret: 9.776, coverage: 0.056, diversity: 1.0, batch_value_loss: 168.628
# Stream: 134, user_count: 16, avg_reward@stream: 1.44, avg_reward: 0.72, hr10: 1.045, regret: 8.562, coverage: 0.5, diversity: 1.0, batch_value_loss: 222.734
# Stream: 135, user_count: 74, avg_reward@stream: 1.51, avg_reward: 0.73, hr10: 1.131, regret: 8.486, coverage: 0.081, diversity: 1.0, batch_value_loss: 306.443
# Stream: 136, user_count: 11, avg_reward@stream: 1.91, avg_reward: 0.73, hr10: 1.312, regret: 8.091, coverage: 0.5, diversity: 1.0, batch_value_loss: 265.963
# Stream: 137, user_count: 17, avg_reward@stream: 0.88, avg_reward: 0.73, hr10: 0.517, regret: 9.118, coverage: 0.276, diversity: 1.0, batch_value_loss: 261.575
# Stream: 138, user_count: 497, avg_reward@stream: 0.52, avg_reward: 0.72, hr10: 0.212, regret: 9.477, coverage: 0.024, diversity: 1.0, batch_value_loss: 309.798
# Stream: 139, user_count: 7, avg_reward@stream: 1.29, avg_reward: 0.72, hr10: 0.9, regret: 8.714, coverage: 0.7, diversity: 1.0, batch_value_loss: 299.373
# Stream: 140, user_count: 49, avg_reward@stream: 0.65, avg_reward: 0.72, hr10: 0.533, regret: 9.347, coverage: 0.317, diversity: 1.0, batch_value_loss: 367.807
# Stream: 141, user_count: 5, avg_reward@stream: 1.0, avg_reward: 0.72, hr10: 0.833, regret: 9.0, coverage: 0.667, diversity: 1.0, batch_value_loss: 351.14
# Stream: 142, user_count: 28, avg_reward@stream: 1.82, avg_reward: 0.72, hr10: 1.062, regret: 8.179, coverage: 0.312, diversity: 1.0, batch_value_loss: 383.678
# Stream: 143, user_count: 94, avg_reward@stream: 1.65, avg_reward: 0.73, hr10: 1.047, regret: 8.351, coverage: 0.034, diversity: 1.0, batch_value_loss: 521.575
# Stream: 144, user_count: 81, avg_reward@stream: 0.93, avg_reward: 0.73, hr10: 0.564, regret: 9.074, coverage: 0.143, diversity: 1.0, batch_value_loss: 452.424
# Stream: 145, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.73, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 527.152
# Stream: 146, user_count: 4, avg_reward@stream: 1.25, avg_reward: 0.73, hr10: 1.25, regret: 8.75, coverage: 1.0, diversity: 1.0, batch_value_loss: 433.268
# Stream: 147, user_count: 18, avg_reward@stream: 0.67, avg_reward: 0.73, hr10: 0.522, regret: 9.333, coverage: 0.435, diversity: 1.0, batch_value_loss: 572.942
# Stream: 148, user_count: 10, avg_reward@stream: 1.7, avg_reward: 0.73, hr10: 1.133, regret: 8.3, coverage: 0.267, diversity: 1.0, batch_value_loss: 512.413
# Stream: 149, user_count: 24, avg_reward@stream: 1.58, avg_reward: 0.73, hr10: 0.884, regret: 8.417, coverage: 0.395, diversity: 1.0, batch_value_loss: 452.694
# Stream: 150, user_count: 14, avg_reward@stream: 1.93, avg_reward: 0.73, hr10: 0.931, regret: 8.071, coverage: 0.414, diversity: 1.0, batch_value_loss: 582.219
# Stream: 151, user_count: 24, avg_reward@stream: 1.71, avg_reward: 0.73, hr10: 0.953, regret: 8.292, coverage: 0.419, diversity: 1.0, batch_value_loss: 547.281
# Stream: 152, user_count: 7, avg_reward@stream: 2.57, avg_reward: 0.74, hr10: 1.636, regret: 7.429, coverage: 0.818, diversity: 1.0, batch_value_loss: 465.422
# Stream: 153, user_count: 289, avg_reward@stream: 0.43, avg_reward: 0.73, hr10: 0.338, regret: 9.574, coverage: 0.06, diversity: 1.0, batch_value_loss: 654.224
# Stream: 154, user_count: 52, avg_reward@stream: 0.63, avg_reward: 0.73, hr10: 0.452, regret: 9.365, coverage: 0.205, diversity: 1.0, batch_value_loss: 806.667
# Stream: 155, user_count: 119, avg_reward@stream: 0.56, avg_reward: 0.73, hr10: 0.496, regret: 9.437, coverage: 0.104, diversity: 1.0, batch_value_loss: 752.101
# Stream: 156, user_count: 22, avg_reward@stream: 1.0, avg_reward: 0.73, hr10: 0.88, regret: 9.0, coverage: 0.08, diversity: 1.0, batch_value_loss: 560.938
# Stream: 157, user_count: 33, avg_reward@stream: 0.52, avg_reward: 0.73, hr10: 0.37, regret: 9.485, coverage: 0.239, diversity: 1.0, batch_value_loss: 768.311
# Stream: 158, user_count: 13, avg_reward@stream: 0.77, avg_reward: 0.73, hr10: 0.588, regret: 9.231, coverage: 0.471, diversity: 1.0, batch_value_loss: 731.69
# Stream: 159, user_count: 7, avg_reward@stream: 1.0, avg_reward: 0.73, hr10: 1.0, regret: 9.0, coverage: 0.143, diversity: 1.0, batch_value_loss: 676.945
# Stream: 160, user_count: 10, avg_reward@stream: 1.5, avg_reward: 0.73, hr10: 0.75, regret: 8.5, coverage: 0.7, diversity: 1.0, batch_value_loss: 600.13
# Stream: 161, user_count: 34, avg_reward@stream: 1.12, avg_reward: 0.73, hr10: 0.717, regret: 8.882, coverage: 0.245, diversity: 1.0, batch_value_loss: 892.258
# Stream: 162, user_count: 97, avg_reward@stream: 0.95, avg_reward: 0.73, hr10: 0.538, regret: 9.052, coverage: 0.111, diversity: 1.0, batch_value_loss: 824.975
# Stream: 163, user_count: 19, avg_reward@stream: 0.95, avg_reward: 0.73, hr10: 0.667, regret: 9.053, coverage: 0.333, diversity: 1.0, batch_value_loss: 995.56
# Stream: 164, user_count: 19, avg_reward@stream: 0.84, avg_reward: 0.73, hr10: 0.696, regret: 9.158, coverage: 0.478, diversity: 1.0, batch_value_loss: 879.606
# Stream: 165, user_count: 35, avg_reward@stream: 1.0, avg_reward: 0.73, hr10: 0.714, regret: 9.0, coverage: 0.02, diversity: 1.0, batch_value_loss: 861.26
# Stream: 166, user_count: 5, avg_reward@stream: 1.2, avg_reward: 0.73, hr10: 1.0, regret: 8.8, coverage: 0.667, diversity: 1.0, batch_value_loss: 1176.682
# Stream: 167, user_count: 29, avg_reward@stream: 1.93, avg_reward: 0.73, hr10: 1.018, regret: 8.069, coverage: 0.182, diversity: 1.0, batch_value_loss: 814.864
# Stream: 168, user_count: 125, avg_reward@stream: 0.93, avg_reward: 0.74, hr10: 0.806, regret: 9.072, coverage: 0.076, diversity: 1.0, batch_value_loss: 1053.926
# Stream: 169, user_count: 17, avg_reward@stream: 1.65, avg_reward: 0.74, hr10: 1.077, regret: 8.353, coverage: 0.269, diversity: 1.0, batch_value_loss: 892.14
# Stream: 170, user_count: 251, avg_reward@stream: 0.94, avg_reward: 0.74, hr10: 0.608, regret: 9.056, coverage: 0.067, diversity: 1.0, batch_value_loss: 1173.527
# Stream: 171, user_count: 21, avg_reward@stream: 1.38, avg_reward: 0.74, hr10: 1.036, regret: 8.619, coverage: 0.286, diversity: 1.0, batch_value_loss: 1338.999
# Stream: 172, user_count: 7, avg_reward@stream: 1.43, avg_reward: 0.74, hr10: 0.769, regret: 8.571, coverage: 0.769, diversity: 1.0, batch_value_loss: 1264.753
# Stream: 173, user_count: 24, avg_reward@stream: 1.58, avg_reward: 0.74, hr10: 0.884, regret: 8.417, coverage: 0.279, diversity: 1.0, batch_value_loss: 1387.166
# Stream: 174, user_count: 84, avg_reward@stream: 0.93, avg_reward: 0.74, hr10: 0.569, regret: 9.071, coverage: 0.153, diversity: 1.0, batch_value_loss: 1624.87
# Stream: 175, user_count: 4, avg_reward@stream: 1.25, avg_reward: 0.74, hr10: 1.0, regret: 8.75, coverage: 1.0, diversity: 1.0, batch_value_loss: 1205.439
# Stream: 176, user_count: 69, avg_reward@stream: 1.41, avg_reward: 0.75, hr10: 0.795, regret: 8.594, coverage: 0.148, diversity: 1.0, batch_value_loss: 1569.0
# Stream: 177, user_count: 20, avg_reward@stream: 1.8, avg_reward: 0.75, hr10: 1.125, regret: 8.2, coverage: 0.25, diversity: 1.0, batch_value_loss: 1458.191
# Stream: 178, user_count: 9, avg_reward@stream: 1.33, avg_reward: 0.75, hr10: 1.0, regret: 8.667, coverage: 0.5, diversity: 1.0, batch_value_loss: 1463.507
# Stream: 179, user_count: 61, avg_reward@stream: 0.62, avg_reward: 0.75, hr10: 0.494, regret: 9.377, coverage: 0.234, diversity: 0.981, batch_value_loss: 2263.049
# Stream: 180, user_count: 37, avg_reward@stream: 1.0, avg_reward: 0.75, hr10: 0.822, regret: 9.0, coverage: 0.022, diversity: 1.0, batch_value_loss: 1792.076
# Stream: 181, user_count: 21, avg_reward@stream: 1.57, avg_reward: 0.75, hr10: 1.031, regret: 8.429, coverage: 0.281, diversity: 1.0, batch_value_loss: 1529.601
# Stream: 182, user_count: 7, avg_reward@stream: 1.57, avg_reward: 0.75, hr10: 1.222, regret: 8.429, coverage: 0.667, diversity: 1.0, batch_value_loss: 1710.527
# Stream: 183, user_count: 19, avg_reward@stream: 1.79, avg_reward: 0.75, hr10: 1.214, regret: 8.211, coverage: 0.321, diversity: 1.0, batch_value_loss: 1671.741
# Stream: 184, user_count: 2637, avg_reward@stream: 0.3, avg_reward: 0.69, hr10: 0.124, regret: 9.703, coverage: 0.01, diversity: 1.0, batch_value_loss: 3039.554
# Stream: 185, user_count: 135, avg_reward@stream: 0.11, avg_reward: 0.68, hr10: 0.087, regret: 9.889, coverage: 0.076, diversity: 0.988, batch_value_loss: 5505.39
# Stream: 186, user_count: 47, avg_reward@stream: 2.02, avg_reward: 0.69, hr10: 1.397, regret: 7.979, coverage: 0.162, diversity: 1.0, batch_value_loss: 7701.647
# Stream: 187, user_count: 57, avg_reward@stream: 1.02, avg_reward: 0.69, hr10: 0.523, regret: 8.982, coverage: 0.144, diversity: 1.0, batch_value_loss: 6856.488
# Stream: 188, user_count: 12, avg_reward@stream: 1.42, avg_reward: 0.69, hr10: 0.895, regret: 8.583, coverage: 0.368, diversity: 1.0, batch_value_loss: 6434.678
# Stream: 189, user_count: 13, avg_reward@stream: 2.54, avg_reward: 0.69, hr10: 1.65, regret: 7.462, coverage: 0.65, diversity: 1.0, batch_value_loss: 7364.362
# Stream: 190, user_count: 4, avg_reward@stream: 1.25, avg_reward: 0.69, hr10: 1.0, regret: 8.75, coverage: 1.0, diversity: 1.0, batch_value_loss: 7557.942
# Stream: 191, user_count: 12, avg_reward@stream: 2.42, avg_reward: 0.69, hr10: 1.45, regret: 7.583, coverage: 0.5, diversity: 1.0, batch_value_loss: 8917.848
# Stream: 192, user_count: 32, avg_reward@stream: 2.06, avg_reward: 0.69, hr10: 1.375, regret: 7.938, coverage: 0.25, diversity: 1.0, batch_value_loss: 7581.583
# Stream: 193, user_count: 9, avg_reward@stream: 2.0, avg_reward: 0.69, hr10: 1.385, regret: 8.0, coverage: 0.462, diversity: 1.0, batch_value_loss: 6102.008
# Stream: 194, user_count: 5, avg_reward@stream: 1.0, avg_reward: 0.69, hr10: 1.0, regret: 9.0, coverage: 0.4, diversity: 1.0, batch_value_loss: 11784.666
# Stream: 195, user_count: 72, avg_reward@stream: 1.24, avg_reward: 0.7, hr10: 0.636, regret: 8.764, coverage: 0.1, diversity: 1.0, batch_value_loss: 8727.527
# Stream: 196, user_count: 30, avg_reward@stream: 2.07, avg_reward: 0.7, hr10: 1.216, regret: 7.933, coverage: 0.196, diversity: 1.0, batch_value_loss: 10835.516
# Stream: 197, user_count: 24, avg_reward@stream: 1.71, avg_reward: 0.7, hr10: 1.139, regret: 8.292, coverage: 0.306, diversity: 1.0, batch_value_loss: 8785.215
# Stream: 198, user_count: 103, avg_reward@stream: 1.01, avg_reward: 0.7, hr10: 0.556, regret: 8.99, coverage: 0.08, diversity: 1.0, batch_value_loss: 10313.977
# Stream: 199, user_count: 25, avg_reward@stream: 1.8, avg_reward: 0.7, hr10: 0.978, regret: 8.2, coverage: 0.261, diversity: 1.0, batch_value_loss: 10361.847
# Stream: 200, user_count: 55, avg_reward@stream: 1.53, avg_reward: 0.71, hr10: 0.84, regret: 8.473, coverage: 0.12, diversity: 1.0, batch_value_loss: 9133.601
# Stream: 201, user_count: 71, avg_reward@stream: 1.0, avg_reward: 0.71, hr10: 0.573, regret: 9.0, coverage: 0.129, diversity: 1.0, batch_value_loss: 9720.955
# Stream: 202, user_count: 11, avg_reward@stream: 1.55, avg_reward: 0.71, hr10: 1.214, regret: 8.455, coverage: 0.357, diversity: 1.0, batch_value_loss: 11459.599
# Stream: 203, user_count: 25, avg_reward@stream: 1.32, avg_reward: 0.71, hr10: 1.138, regret: 8.68, coverage: 0.207, diversity: 1.0, batch_value_loss: 14667.392
# Stream: 204, user_count: 10, avg_reward@stream: 1.5, avg_reward: 0.71, hr10: 1.071, regret: 8.5, coverage: 0.357, diversity: 1.0, batch_value_loss: 7860.738
# Stream: 205, user_count: 10, avg_reward@stream: 2.0, avg_reward: 0.71, hr10: 1.25, regret: 8.0, coverage: 0.375, diversity: 1.0, batch_value_loss: 11839.731
# Stream: 206, user_count: 17, avg_reward@stream: 1.06, avg_reward: 0.71, hr10: 1.0, regret: 8.941, coverage: 0.222, diversity: 1.0, batch_value_loss: 15260.499
# Stream: 207, user_count: 13, avg_reward@stream: 2.08, avg_reward: 0.71, hr10: 1.227, regret: 7.923, coverage: 0.364, diversity: 1.0, batch_value_loss: 16257.746
# Stream: 208, user_count: 14, avg_reward@stream: 1.36, avg_reward: 0.71, hr10: 1.118, regret: 8.643, coverage: 0.412, diversity: 1.0, batch_value_loss: 15274.748
# Stream: 209, user_count: 12, avg_reward@stream: 0.75, avg_reward: 0.71, hr10: 0.643, regret: 9.25, coverage: 0.643, diversity: 1.0, batch_value_loss: 13658.716
# Stream: 210, user_count: 33, avg_reward@stream: 1.85, avg_reward: 0.71, hr10: 0.984, regret: 8.152, coverage: 0.242, diversity: 1.0, batch_value_loss: 13449.453
# Stream: 211, user_count: 8, avg_reward@stream: 2.0, avg_reward: 0.71, hr10: 1.143, regret: 8.0, coverage: 0.786, diversity: 1.0, batch_value_loss: 10097.597
# Stream: 212, user_count: 97, avg_reward@stream: 1.54, avg_reward: 0.72, hr10: 0.654, regret: 8.464, coverage: 0.083, diversity: 1.0, batch_value_loss: 15541.41
# Stream: 213, user_count: 8, avg_reward@stream: 1.0, avg_reward: 0.72, hr10: 1.0, regret: 9.0, coverage: 0.5, diversity: 1.0, batch_value_loss: 14115.932
# Stream: 214, user_count: 57, avg_reward@stream: 1.04, avg_reward: 0.72, hr10: 0.776, regret: 8.965, coverage: 0.224, diversity: 1.0, batch_value_loss: 12912.423
# Stream: 215, user_count: 25, avg_reward@stream: 1.48, avg_reward: 0.72, hr10: 1.0, regret: 8.52, coverage: 0.297, diversity: 1.0, batch_value_loss: 12212.85
# Stream: 216, user_count: 7, avg_reward@stream: 1.29, avg_reward: 0.72, hr10: 1.125, regret: 8.714, coverage: 0.75, diversity: 1.0, batch_value_loss: 16470.873
# Stream: 217, user_count: 9, avg_reward@stream: 1.22, avg_reward: 0.72, hr10: 1.0, regret: 8.778, coverage: 0.545, diversity: 1.0, batch_value_loss: 20098.267
# Stream: 218, user_count: 67, avg_reward@stream: 2.25, avg_reward: 0.72, hr10: 1.606, regret: 7.746, coverage: 0.106, diversity: 1.0, batch_value_loss: 16415.47
# Stream: 219, user_count: 48, avg_reward@stream: 1.9, avg_reward: 0.73, hr10: 0.722, regret: 8.104, coverage: 0.143, diversity: 1.0, batch_value_loss: 16158.582
# Stream: 220, user_count: 34, avg_reward@stream: 0.94, avg_reward: 0.73, hr10: 0.593, regret: 9.059, coverage: 0.259, diversity: 1.0, batch_value_loss: 14756.166
# Stream: 221, user_count: 38, avg_reward@stream: 1.55, avg_reward: 0.73, hr10: 0.967, regret: 8.447, coverage: 0.213, diversity: 1.0, batch_value_loss: 18978.377
# Stream: 222, user_count: 68, avg_reward@stream: 0.56, avg_reward: 0.73, hr10: 0.365, regret: 9.441, coverage: 0.192, diversity: 1.0, batch_value_loss: 18934.502
# Stream: 223, user_count: 8, avg_reward@stream: 2.12, avg_reward: 0.73, hr10: 1.308, regret: 7.875, coverage: 0.692, diversity: 1.0, batch_value_loss: 16429.01
# Stream: 224, user_count: 3, avg_reward@stream: 1.0, avg_reward: 0.73, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 16671.042
# Stream: 225, user_count: 2, avg_reward@stream: 1.0, avg_reward: 0.73, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 15964.47
# Stream: 226, user_count: 7, avg_reward@stream: 1.29, avg_reward: 0.73, hr10: 1.0, regret: 8.714, coverage: 1.0, diversity: 1.0, batch_value_loss: 13287.754
# Stream: 227, user_count: 60, avg_reward@stream: 0.95, avg_reward: 0.73, hr10: 0.564, regret: 9.05, coverage: 0.188, diversity: 1.0, batch_value_loss: 18864.448
# Stream: 228, user_count: 2, avg_reward@stream: 1.0, avg_reward: 0.73, hr10: 0.667, regret: 9.0, coverage: 0.667, diversity: 1.0, batch_value_loss: 29601.961
# Stream: 229, user_count: 20, avg_reward@stream: 1.65, avg_reward: 0.73, hr10: 1.1, regret: 8.35, coverage: 0.5, diversity: 1.0, batch_value_loss: 19955.411
# Stream: 230, user_count: 41, avg_reward@stream: 0.93, avg_reward: 0.73, hr10: 0.528, regret: 9.073, coverage: 0.222, diversity: 1.0, batch_value_loss: 20159.866
# Stream: 231, user_count: 124, avg_reward@stream: 1.31, avg_reward: 0.73, hr10: 0.755, regret: 8.685, coverage: 0.074, diversity: 1.0, batch_value_loss: 22035.704
# Stream: 232, user_count: 13, avg_reward@stream: 1.46, avg_reward: 0.73, hr10: 1.056, regret: 8.538, coverage: 0.444, diversity: 1.0, batch_value_loss: 25094.567
# Stream: 233, user_count: 24, avg_reward@stream: 1.83, avg_reward: 0.74, hr10: 1.333, regret: 8.167, coverage: 0.333, diversity: 1.0, batch_value_loss: 22255.971
# Stream: 234, user_count: 84, avg_reward@stream: 1.57, avg_reward: 0.74, hr10: 0.75, regret: 8.429, coverage: 0.108, diversity: 1.0, batch_value_loss: 20858.749
# Stream: 235, user_count: 22, avg_reward@stream: 1.55, avg_reward: 0.74, hr10: 1.0, regret: 8.455, coverage: 0.412, diversity: 1.0, batch_value_loss: 29218.21
# Stream: 236, user_count: 35, avg_reward@stream: 2.11, avg_reward: 0.74, hr10: 1.423, regret: 7.886, coverage: 0.212, diversity: 1.0, batch_value_loss: 23015.657
# Stream: 237, user_count: 45, avg_reward@stream: 1.16, avg_reward: 0.74, hr10: 0.667, regret: 8.844, coverage: 0.154, diversity: 1.0, batch_value_loss: 25167.731
# Stream: 238, user_count: 39, avg_reward@stream: 1.51, avg_reward: 0.74, hr10: 0.831, regret: 8.487, coverage: 0.183, diversity: 1.0, batch_value_loss: 26383.655
# Stream: 239, user_count: 84, avg_reward@stream: 1.4, avg_reward: 0.75, hr10: 0.742, regret: 8.595, coverage: 0.082, diversity: 1.0, batch_value_loss: 25782.97
# Stream: 240, user_count: 10, avg_reward@stream: 1.7, avg_reward: 0.75, hr10: 1.133, regret: 8.3, coverage: 0.467, diversity: 1.0, batch_value_loss: 26056.606
# Stream: 241, user_count: 8, avg_reward@stream: 1.5, avg_reward: 0.75, hr10: 1.0, regret: 8.5, coverage: 0.333, diversity: 1.0, batch_value_loss: 28979.336
# Stream: 242, user_count: 10, avg_reward@stream: 1.6, avg_reward: 0.75, hr10: 1.0, regret: 8.4, coverage: 0.438, diversity: 1.0, batch_value_loss: 24811.811
# Stream: 243, user_count: 25, avg_reward@stream: 1.36, avg_reward: 0.75, hr10: 1.097, regret: 8.64, coverage: 0.226, diversity: 1.0, batch_value_loss: 28548.333
# Stream: 244, user_count: 6, avg_reward@stream: 1.5, avg_reward: 0.75, hr10: 1.0, regret: 8.5, coverage: 0.556, diversity: 1.0, batch_value_loss: 29960.099
# Stream: 245, user_count: 7, avg_reward@stream: 1.14, avg_reward: 0.75, hr10: 0.8, regret: 8.857, coverage: 0.3, diversity: 1.0, batch_value_loss: 21589.996
# Stream: 246, user_count: 90, avg_reward@stream: 1.1, avg_reward: 0.75, hr10: 0.55, regret: 8.9, coverage: 0.1, diversity: 1.0, batch_value_loss: 30785.433
# Stream: 247, user_count: 25, avg_reward@stream: 1.52, avg_reward: 0.75, hr10: 1.027, regret: 8.48, coverage: 0.216, diversity: 1.0, batch_value_loss: 34948.06
# Stream: 248, user_count: 25, avg_reward@stream: 1.28, avg_reward: 0.75, hr10: 1.0, regret: 8.72, coverage: 0.219, diversity: 1.0, batch_value_loss: 37617.205
# Stream: 249, user_count: 7, avg_reward@stream: 1.29, avg_reward: 0.75, hr10: 1.0, regret: 8.714, coverage: 0.556, diversity: 1.0, batch_value_loss: 26846.862
# Stream: 250, user_count: 10, avg_reward@stream: 1.7, avg_reward: 0.75, hr10: 1.133, regret: 8.3, coverage: 0.4, diversity: 1.0, batch_value_loss: 31703.841
# Stream: 251, user_count: 23, avg_reward@stream: 0.91, avg_reward: 0.75, hr10: 0.875, regret: 9.087, coverage: 0.417, diversity: 1.0, batch_value_loss: 35231.139
# Stream: 252, user_count: 28, avg_reward@stream: 1.71, avg_reward: 0.75, hr10: 0.889, regret: 8.286, coverage: 0.204, diversity: 1.0, batch_value_loss: 34869.855
# Stream: 253, user_count: 4, avg_reward@stream: 1.0, avg_reward: 0.75, hr10: 1.0, regret: 9.0, coverage: 0.75, diversity: 1.0, batch_value_loss: 24779.492
# Stream: 254, user_count: 64, avg_reward@stream: 1.14, avg_reward: 0.76, hr10: 0.658, regret: 8.859, coverage: 0.162, diversity: 1.0, batch_value_loss: 37135.848
# Stream: 255, user_count: 32, avg_reward@stream: 1.47, avg_reward: 0.76, hr10: 1.119, regret: 8.531, coverage: 0.19, diversity: 1.0, batch_value_loss: 33594.742
# Stream: 256, user_count: 1265, avg_reward@stream: 0.77, avg_reward: 0.76, hr10: 0.148, regret: 9.227, coverage: 0.014, diversity: 1.0, batch_value_loss: 42591.962
# Stream: 257, user_count: 14, avg_reward@stream: 1.57, avg_reward: 0.76, hr10: 1.467, regret: 8.429, coverage: 0.6, diversity: 1.0, batch_value_loss: 50514.045
# Stream: 258, user_count: 16, avg_reward@stream: 1.69, avg_reward: 0.76, hr10: 1.08, regret: 8.312, coverage: 0.32, diversity: 1.0, batch_value_loss: 51783.105
# Stream: 259, user_count: 28, avg_reward@stream: 0.29, avg_reward: 0.76, hr10: 0.19, regret: 9.714, coverage: 0.19, diversity: 0.973, batch_value_loss: 53476.125
# Stream: 260, user_count: 8, avg_reward@stream: 1.25, avg_reward: 0.76, hr10: 1.111, regret: 8.75, coverage: 0.667, diversity: 1.0, batch_value_loss: 51741.301
# Stream: 261, user_count: 122, avg_reward@stream: 1.36, avg_reward: 0.76, hr10: 0.664, regret: 8.639, coverage: 0.064, diversity: 1.0, batch_value_loss: 54532.943
# Stream: 262, user_count: 21, avg_reward@stream: 1.19, avg_reward: 0.76, hr10: 0.781, regret: 8.81, coverage: 0.375, diversity: 1.0, batch_value_loss: 55453.738
# Stream: 263, user_count: 34, avg_reward@stream: 0.65, avg_reward: 0.76, hr10: 0.431, regret: 9.353, coverage: 0.294, diversity: 1.0, batch_value_loss: 58235.147
# Stream: 264, user_count: 6, avg_reward@stream: 1.67, avg_reward: 0.76, hr10: 0.833, regret: 8.333, coverage: 0.5, diversity: 1.0, batch_value_loss: 64638.984
# Stream: 265, user_count: 23, avg_reward@stream: 1.78, avg_reward: 0.76, hr10: 0.976, regret: 8.217, coverage: 0.333, diversity: 1.0, batch_value_loss: 56448.516
# Stream: 266, user_count: 1335, avg_reward@stream: 0.81, avg_reward: 0.77, hr10: 0.205, regret: 9.193, coverage: 0.018, diversity: 1.0, batch_value_loss: 69321.876
# Stream: 267, user_count: 62, avg_reward@stream: 0.68, avg_reward: 0.77, hr10: 0.433, regret: 9.323, coverage: 0.206, diversity: 1.0, batch_value_loss: 92792.968
# Stream: 268, user_count: 29, avg_reward@stream: 0.86, avg_reward: 0.77, hr10: 0.658, regret: 9.138, coverage: 0.395, diversity: 1.0, batch_value_loss: 87569.836
# Stream: 269, user_count: 75, avg_reward@stream: 0.8, avg_reward: 0.77, hr10: 0.55, regret: 9.2, coverage: 0.284, diversity: 0.969, batch_value_loss: 91751.893
# Stream: 270, user_count: 16, avg_reward@stream: 1.75, avg_reward: 0.77, hr10: 1.474, regret: 8.25, coverage: 0.316, diversity: 1.0, batch_value_loss: 101392.305
# Stream: 271, user_count: 84, avg_reward@stream: 1.54, avg_reward: 0.77, hr10: 0.86, regret: 8.464, coverage: 0.113, diversity: 1.0, batch_value_loss: 102632.274
# Stream: 272, user_count: 24, avg_reward@stream: 1.62, avg_reward: 0.77, hr10: 1.054, regret: 8.375, coverage: 0.324, diversity: 1.0, batch_value_loss: 109478.594
# Stream: 273, user_count: 70, avg_reward@stream: 1.89, avg_reward: 0.77, hr10: 1.347, regret: 8.114, coverage: 0.133, diversity: 1.0, batch_value_loss: 106489.779
# Stream: 274, user_count: 13, avg_reward@stream: 2.15, avg_reward: 0.77, hr10: 1.474, regret: 7.846, coverage: 0.579, diversity: 1.0, batch_value_loss: 99014.856
# Stream: 275, user_count: 14, avg_reward@stream: 1.43, avg_reward: 0.77, hr10: 1.053, regret: 8.571, coverage: 0.158, diversity: 1.0, batch_value_loss: 115208.429
# Stream: 276, user_count: 48, avg_reward@stream: 1.06, avg_reward: 0.77, hr10: 0.367, regret: 8.938, coverage: 0.173, diversity: 1.0, batch_value_loss: 115351.833
# Stream: 277, user_count: 14, avg_reward@stream: 1.5, avg_reward: 0.77, hr10: 1.235, regret: 8.5, coverage: 0.412, diversity: 1.0, batch_value_loss: 88318.357
# Stream: 278, user_count: 159, avg_reward@stream: 1.6, avg_reward: 0.78, hr10: 1.204, regret: 8.403, coverage: 0.047, diversity: 1.0, batch_value_loss: 113786.767
# Stream: 279, user_count: 36, avg_reward@stream: 1.36, avg_reward: 0.78, hr10: 1.256, regret: 8.639, coverage: 0.154, diversity: 1.0, batch_value_loss: 118154.306
# Stream: 280, user_count: 4087, avg_reward@stream: 0.54, avg_reward: 0.75, hr10: 0.202, regret: 9.457, coverage: 0.005, diversity: 1.0, batch_value_loss: 221680.121
# Stream: 281, user_count: 77, avg_reward@stream: 1.6, avg_reward: 0.75, hr10: 1.367, regret: 8.403, coverage: 0.1, diversity: 1.0, batch_value_loss: 381609.506
# Stream: 282, user_count: 21, avg_reward@stream: 1.76, avg_reward: 0.75, hr10: 1.37, regret: 8.238, coverage: 0.296, diversity: 1.0, batch_value_loss: 396478.024
# Stream: 283, user_count: 4, avg_reward@stream: 1.0, avg_reward: 0.75, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 655661.938
# Stream: 284, user_count: 397, avg_reward@stream: 0.46, avg_reward: 0.75, hr10: 0.211, regret: 9.539, coverage: 0.03, diversity: 1.0, batch_value_loss: 432029.34
# Stream: 285, user_count: 10, avg_reward@stream: 1.0, avg_reward: 0.75, hr10: 0.5, regret: 9.0, coverage: 0.5, diversity: 1.0, batch_value_loss: 477748.0
# Stream: 286, user_count: 105, avg_reward@stream: 1.01, avg_reward: 0.75, hr10: 0.883, regret: 8.99, coverage: 0.017, diversity: 1.0, batch_value_loss: 507461.6
# Stream: 287, user_count: 42, avg_reward@stream: 0.33, avg_reward: 0.75, hr10: 0.255, regret: 9.667, coverage: 0.182, diversity: 1.0, batch_value_loss: 434370.762
# Stream: 288, user_count: 38, avg_reward@stream: 0.29, avg_reward: 0.75, hr10: 0.22, regret: 9.711, coverage: 0.18, diversity: 1.0, batch_value_loss: 600036.474
# Stream: 289, user_count: 8, avg_reward@stream: 1.5, avg_reward: 0.75, hr10: 1.2, regret: 8.5, coverage: 0.7, diversity: 1.0, batch_value_loss: 405239.969
# Stream: 290, user_count: 28, avg_reward@stream: 1.64, avg_reward: 0.75, hr10: 1.022, regret: 8.357, coverage: 0.289, diversity: 1.0, batch_value_loss: 620259.786
# Stream: 291, user_count: 3, avg_reward@stream: 1.0, avg_reward: 0.75, hr10: 1.0, regret: 9.0, coverage: 0.667, diversity: 1.0, batch_value_loss: 541020.5
# Stream: 292, user_count: 19, avg_reward@stream: 1.95, avg_reward: 0.75, hr10: 1.37, regret: 8.053, coverage: 0.37, diversity: 1.0, batch_value_loss: 466274.105
# Stream: 293, user_count: 29, avg_reward@stream: 1.66, avg_reward: 0.75, hr10: 0.941, regret: 8.345, coverage: 0.235, diversity: 1.0, batch_value_loss: 470436.0
# Stream: 294, user_count: 69, avg_reward@stream: 1.04, avg_reward: 0.75, hr10: 0.497, regret: 8.957, coverage: 0.145, diversity: 1.0, batch_value_loss: 495530.435
# Stream: 295, user_count: 45, avg_reward@stream: 1.58, avg_reward: 0.75, hr10: 1.315, regret: 8.422, coverage: 0.167, diversity: 1.0, batch_value_loss: 585350.444
# Stream: 296, user_count: 5, avg_reward@stream: 2.2, avg_reward: 0.75, hr10: 1.1, regret: 7.8, coverage: 0.6, diversity: 1.0, batch_value_loss: 585785.7
# Stream: 297, user_count: 761, avg_reward@stream: 0.29, avg_reward: 0.74, hr10: 0.201, regret: 9.71, coverage: 0.025, diversity: 1.0, batch_value_loss: 633995.438
# Stream: 298, user_count: 55, avg_reward@stream: 0.44, avg_reward: 0.74, hr10: 0.308, regret: 9.564, coverage: 0.167, diversity: 0.981, batch_value_loss: 613516.291
# Stream: 299, user_count: 19, avg_reward@stream: 1.47, avg_reward: 0.74, hr10: 1.037, regret: 8.526, coverage: 0.444, diversity: 1.0, batch_value_loss: 611427.684
# Stream: 300, user_count: 57, avg_reward@stream: 0.67, avg_reward: 0.74, hr10: 0.384, regret: 9.333, coverage: 0.182, diversity: 1.0, batch_value_loss: 627739.93
# Stream: 301, user_count: 13, avg_reward@stream: 1.54, avg_reward: 0.74, hr10: 1.333, regret: 8.462, coverage: 0.467, diversity: 1.0, batch_value_loss: 657839.077
# Stream: 302, user_count: 269, avg_reward@stream: 0.59, avg_reward: 0.74, hr10: 0.4, regret: 9.413, coverage: 0.084, diversity: 1.0, batch_value_loss: 739694.037
# Stream: 303, user_count: 13, avg_reward@stream: 0.85, avg_reward: 0.74, hr10: 0.786, regret: 9.154, coverage: 0.714, diversity: 1.0, batch_value_loss: 535706.923
# Stream: 304, user_count: 28, avg_reward@stream: 1.25, avg_reward: 0.74, hr10: 1.061, regret: 8.75, coverage: 0.182, diversity: 1.0, batch_value_loss: 699025.357
# ...
# Stream: 1414, user_count: 46, avg_reward@stream: 1.28, avg_reward: 1.01, hr10: 0.881, regret: 8.717, coverage: 0.179, diversity: 1.0, batch_value_loss: 1108136826.435
# Stream: 1415, user_count: 100, avg_reward@stream: 0.88, avg_reward: 1.01, hr10: 0.484, regret: 9.12, coverage: 0.082, diversity: 0.955, batch_value_loss: 1170870681.6
# Stream: 1416, user_count: 118, avg_reward@stream: 0.99, avg_reward: 1.01, hr10: 0.555, regret: 9.008, coverage: 0.09, diversity: 1.0, batch_value_loss: 1110163178.305
# Stream: 1417, user_count: 46, avg_reward@stream: 1.09, avg_reward: 1.01, hr10: 0.568, regret: 8.913, coverage: 0.205, diversity: 1.0, batch_value_loss: 1213356655.304
# Stream: 1418, user_count: 51, avg_reward@stream: 1.65, avg_reward: 1.01, hr10: 1.105, regret: 8.353, coverage: 0.197, diversity: 1.0, batch_value_loss: 1108316481.255
# Stream: 1419, user_count: 139, avg_reward@stream: 0.99, avg_reward: 1.01, hr10: 0.506, regret: 9.014, coverage: 0.07, diversity: 1.0, batch_value_loss: 1112880606.849
# Stream: 1420, user_count: 41, avg_reward@stream: 1.93, avg_reward: 1.01, hr10: 1.097, regret: 8.073, coverage: 0.208, diversity: 1.0, batch_value_loss: 1102749496.195
# Stream: 1421, user_count: 38, avg_reward@stream: 1.13, avg_reward: 1.01, hr10: 0.652, regret: 8.868, coverage: 0.212, diversity: 1.0, batch_value_loss: 1040937283.368
# Stream: 1422, user_count: 24, avg_reward@stream: 1.29, avg_reward: 1.01, hr10: 0.912, regret: 8.708, coverage: 0.382, diversity: 1.0, batch_value_loss: 1057701802.667
# Stream: 1423, user_count: 119, avg_reward@stream: 1.9, avg_reward: 1.02, hr10: 1.306, regret: 8.101, coverage: 0.058, diversity: 1.0, batch_value_loss: 1120330622.924
# Stream: 1424, user_count: 61, avg_reward@stream: 0.64, avg_reward: 1.02, hr10: 0.394, regret: 9.361, coverage: 0.182, diversity: 0.97, batch_value_loss: 995466995.41
# Stream: 1425, user_count: 426, avg_reward@stream: 1.0, avg_reward: 1.02, hr10: 0.626, regret: 8.998, coverage: 0.023, diversity: 1.0, batch_value_loss: 1173689223.812
# Stream: 1426, user_count: 61, avg_reward@stream: 0.75, avg_reward: 1.02, hr10: 0.561, regret: 9.246, coverage: 0.244, diversity: 0.643, batch_value_loss: 1087548231.344
# Stream: 1427, user_count: 18, avg_reward@stream: 1.28, avg_reward: 1.02, hr10: 0.92, regret: 8.722, coverage: 0.48, diversity: 1.0, batch_value_loss: 1047170616.889
# Stream: 1428, user_count: 152, avg_reward@stream: 1.19, avg_reward: 1.02, hr10: 0.67, regret: 8.809, coverage: 0.056, diversity: 1.0, batch_value_loss: 1130292277.895
# Stream: 1429, user_count: 48, avg_reward@stream: 1.23, avg_reward: 1.02, hr10: 0.766, regret: 8.771, coverage: 0.13, diversity: 1.0, batch_value_loss: 1031785557.333
# Stream: 1430, user_count: 70, avg_reward@stream: 0.36, avg_reward: 1.02, hr10: 0.263, regret: 9.643, coverage: 0.126, diversity: 0.852, batch_value_loss: 1054774301.257
# Stream: 1431, user_count: 35, avg_reward@stream: 1.71, avg_reward: 1.02, hr10: 1.176, regret: 8.286, coverage: 0.275, diversity: 1.0, batch_value_loss: 1142153216.0
# Stream: 1432, user_count: 42, avg_reward@stream: 1.26, avg_reward: 1.02, hr10: 0.855, regret: 8.738, coverage: 0.177, diversity: 0.957, batch_value_loss: 1215872243.81
# Stream: 1433, user_count: 142, avg_reward@stream: 1.29, avg_reward: 1.02, hr10: 0.759, regret: 8.711, coverage: 0.091, diversity: 0.971, batch_value_loss: 1240951505.127
# Stream: 1434, user_count: 61, avg_reward@stream: 1.03, avg_reward: 1.02, hr10: 0.926, regret: 8.967, coverage: 0.029, diversity: 1.0, batch_value_loss: 1057258647.082
# Stream: 1435, user_count: 35, avg_reward@stream: 1.77, avg_reward: 1.02, hr10: 0.838, regret: 8.229, coverage: 0.23, diversity: 0.92, batch_value_loss: 1055450726.4
# Stream: 1436, user_count: 40, avg_reward@stream: 1.23, avg_reward: 1.02, hr10: 1.114, regret: 8.775, coverage: 0.114, diversity: 1.0, batch_value_loss: 1068583936.0
# Stream: 1437, user_count: 47, avg_reward@stream: 1.23, avg_reward: 1.02, hr10: 1.055, regret: 8.766, coverage: 0.091, diversity: 1.0, batch_value_loss: 1218127131.234
# Stream: 1438, user_count: 3, avg_reward@stream: 1.67, avg_reward: 1.02, hr10: 1.25, regret: 8.333, coverage: 0.75, diversity: 1.0, batch_value_loss: 1342210389.333
# Stream: 1439, user_count: 3, avg_reward@stream: 1.33, avg_reward: 1.02, hr10: 1.0, regret: 8.667, coverage: 0.75, diversity: 1.0, batch_value_loss: 2192105130.667
# Stream: 1440, user_count: 28, avg_reward@stream: 1.21, avg_reward: 1.02, hr10: 0.81, regret: 8.786, coverage: 0.286, diversity: 0.933, batch_value_loss: 1046950473.143
# Stream: 1441, user_count: 26, avg_reward@stream: 2.23, avg_reward: 1.02, hr10: 1.45, regret: 7.769, coverage: 0.2, diversity: 1.0, batch_value_loss: 1299884032.0
# Stream: 1442, user_count: 231, avg_reward@stream: 0.86, avg_reward: 1.02, hr10: 0.573, regret: 9.139, coverage: 0.049, diversity: 1.0, batch_value_loss: 1217023663.1
# Stream: 1443, user_count: 1610, avg_reward@stream: 0.65, avg_reward: 1.01, hr10: 0.087, regret: 9.353, coverage: 0.007, diversity: 0.948, batch_value_loss: 1157359084.283
# Stream: 1444, user_count: 123, avg_reward@stream: 1.41, avg_reward: 1.01, hr10: 0.73, regret: 8.593, coverage: 0.072, diversity: 1.0, batch_value_loss: 1073174711.154
# Stream: 1445, user_count: 14, avg_reward@stream: 1.79, avg_reward: 1.01, hr10: 1.389, regret: 8.214, coverage: 0.667, diversity: 1.0, batch_value_loss: 1205924278.857
# Stream: 1446, user_count: 86, avg_reward@stream: 1.35, avg_reward: 1.01, hr10: 0.872, regret: 8.651, coverage: 0.098, diversity: 1.0, batch_value_loss: 1156107906.977
# Stream: 1447, user_count: 13, avg_reward@stream: 3.08, avg_reward: 1.01, hr10: 2.105, regret: 6.923, coverage: 0.526, diversity: 1.0, batch_value_loss: 880211968.0
# Stream: 1448, user_count: 67, avg_reward@stream: 1.31, avg_reward: 1.01, hr10: 0.615, regret: 8.687, coverage: 0.154, diversity: 1.0, batch_value_loss: 1300344893.134
# Stream: 1449, user_count: 42, avg_reward@stream: 1.52, avg_reward: 1.01, hr10: 0.853, regret: 8.476, coverage: 0.173, diversity: 0.905, batch_value_loss: 1257558406.095
# Stream: 1450, user_count: 27, avg_reward@stream: 2.41, avg_reward: 1.01, hr10: 1.327, regret: 7.593, coverage: 0.286, diversity: 0.947, batch_value_loss: 1097301181.63
# Stream: 1451, user_count: 36, avg_reward@stream: 1.78, avg_reward: 1.01, hr10: 0.889, regret: 8.222, coverage: 0.194, diversity: 0.917, batch_value_loss: 1076765923.556
# Stream: 1452, user_count: 111, avg_reward@stream: 1.56, avg_reward: 1.01, hr10: 0.797, regret: 8.441, coverage: 0.088, diversity: 0.92, batch_value_loss: 1210523795.604
# Stream: 1453, user_count: 12, avg_reward@stream: 2.83, avg_reward: 1.01, hr10: 1.36, regret: 7.167, coverage: 0.44, diversity: 0.929, batch_value_loss: 1413472853.333
# Stream: 1454, user_count: 14, avg_reward@stream: 2.07, avg_reward: 1.01, hr10: 0.967, regret: 7.929, coverage: 0.4, diversity: 1.0, batch_value_loss: 1164694308.571
# Stream: 1455, user_count: 37, avg_reward@stream: 1.41, avg_reward: 1.01, hr10: 0.881, regret: 8.595, coverage: 0.254, diversity: 0.826, batch_value_loss: 1077923950.703
# Stream: 1456, user_count: 14, avg_reward@stream: 1.36, avg_reward: 1.01, hr10: 0.792, regret: 8.643, coverage: 0.5, diversity: 1.0, batch_value_loss: 1178667885.714
# Stream: 1457, user_count: 14, avg_reward@stream: 1.64, avg_reward: 1.01, hr10: 1.0, regret: 8.357, coverage: 0.522, diversity: 1.0, batch_value_loss: 1253549641.143
# Stream: 1458, user_count: 188, avg_reward@stream: 0.41, avg_reward: 1.01, hr10: 0.326, regret: 9.59, coverage: 0.059, diversity: 1.0, batch_value_loss: 1314970515.064
# Stream: 1459, user_count: 89, avg_reward@stream: 0.85, avg_reward: 1.01, hr10: 0.507, regret: 9.146, coverage: 0.093, diversity: 1.0, batch_value_loss: 1235453008.539
# Stream: 1460, user_count: 28, avg_reward@stream: 1.04, avg_reward: 1.01, hr10: 0.659, regret: 8.964, coverage: 0.25, diversity: 1.0, batch_value_loss: 1277936201.143
# Stream: 1461, user_count: 24, avg_reward@stream: 1.62, avg_reward: 1.01, hr10: 1.219, regret: 8.375, coverage: 0.312, diversity: 1.0, batch_value_loss: 1197813504.0
# Stream: 1462, user_count: 114, avg_reward@stream: 1.92, avg_reward: 1.01, hr10: 1.296, regret: 8.079, coverage: 0.059, diversity: 1.0, batch_value_loss: 1299478276.491
# Stream: 1463, user_count: 46, avg_reward@stream: 1.15, avg_reward: 1.01, hr10: 0.616, regret: 8.848, coverage: 0.174, diversity: 1.0, batch_value_loss: 1329864882.087
# Stream: 1464, user_count: 9, avg_reward@stream: 1.11, avg_reward: 1.01, hr10: 1.111, regret: 8.889, coverage: 0.444, diversity: 1.0, batch_value_loss: 1527683982.222
# Stream: 1465, user_count: 12, avg_reward@stream: 1.42, avg_reward: 1.01, hr10: 1.0, regret: 8.583, coverage: 0.294, diversity: 1.0, batch_value_loss: 1173516970.667
# Stream: 1466, user_count: 47, avg_reward@stream: 0.79, avg_reward: 1.01, hr10: 0.607, regret: 9.213, coverage: 0.23, diversity: 0.767, batch_value_loss: 1308062218.894
# Stream: 1467, user_count: 628, avg_reward@stream: 0.88, avg_reward: 1.01, hr10: 0.4, regret: 9.116, coverage: 0.023, diversity: 0.975, batch_value_loss: 1271635707.108
# Stream: 1468, user_count: 48, avg_reward@stream: 1.46, avg_reward: 1.01, hr10: 0.833, regret: 8.542, coverage: 0.202, diversity: 0.963, batch_value_loss: 1316718677.333
# Stream: 1469, user_count: 23, avg_reward@stream: 1.7, avg_reward: 1.01, hr10: 1.3, regret: 8.304, coverage: 0.3, diversity: 1.0, batch_value_loss: 1258426813.217
# Stream: 1470, user_count: 8, avg_reward@stream: 1.5, avg_reward: 1.01, hr10: 1.2, regret: 8.5, coverage: 0.5, diversity: 1.0, batch_value_loss: 1520328704.0
# Stream: 1471, user_count: 125, avg_reward@stream: 0.84, avg_reward: 1.01, hr10: 0.541, regret: 9.16, coverage: 0.088, diversity: 1.0, batch_value_loss: 1248644169.728
# Stream: 1472, user_count: 1, avg_reward@stream: 1.0, avg_reward: 1.01, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 902069696.0
# Stream: 1473, user_count: 17, avg_reward@stream: 1.65, avg_reward: 1.01, hr10: 1.077, regret: 8.353, coverage: 0.346, diversity: 1.0, batch_value_loss: 1358959917.176
# Stream: 1474, user_count: 479, avg_reward@stream: 1.19, avg_reward: 1.01, hr10: 0.732, regret: 8.812, coverage: 0.015, diversity: 1.0, batch_value_loss: 1383775127.248
# Stream: 1475, user_count: 3, avg_reward@stream: 1.0, avg_reward: 1.01, hr10: 1.0, regret: 9.0, coverage: 0.667, diversity: 1.0, batch_value_loss: 1243505664.0
# Stream: 1476, user_count: 29, avg_reward@stream: 1.41, avg_reward: 1.01, hr10: 0.976, regret: 8.586, coverage: 0.31, diversity: 1.0, batch_value_loss: 1489875226.483
# Stream: 1477, user_count: 27, avg_reward@stream: 1.41, avg_reward: 1.01, hr10: 1.086, regret: 8.593, coverage: 0.257, diversity: 1.0, batch_value_loss: 1455682142.815
# Stream: 1478, user_count: 96, avg_reward@stream: 1.11, avg_reward: 1.01, hr10: 0.787, regret: 8.885, coverage: 0.103, diversity: 0.947, batch_value_loss: 1361489322.667
# Stream: 1479, user_count: 6, avg_reward@stream: 1.17, avg_reward: 1.01, hr10: 1.0, regret: 8.833, coverage: 0.714, diversity: 1.0, batch_value_loss: 1783978154.667
# Stream: 1480, user_count: 27, avg_reward@stream: 1.04, avg_reward: 1.01, hr10: 0.778, regret: 8.963, coverage: 0.306, diversity: 1.0, batch_value_loss: 1435694573.037
# Stream: 1481, user_count: 174, avg_reward@stream: 0.82, avg_reward: 1.01, hr10: 0.548, regret: 9.184, coverage: 0.085, diversity: 0.971, batch_value_loss: 1586747274.299
# Stream: 1482, user_count: 50, avg_reward@stream: 0.86, avg_reward: 1.01, hr10: 0.614, regret: 9.14, coverage: 0.229, diversity: 1.0, batch_value_loss: 1779154452.48
# Stream: 1483, user_count: 28, avg_reward@stream: 0.86, avg_reward: 1.01, hr10: 0.8, regret: 9.143, coverage: 0.367, diversity: 1.0, batch_value_loss: 1525034861.714
# Stream: 1484, user_count: 86, avg_reward@stream: 1.09, avg_reward: 1.01, hr10: 0.879, regret: 8.907, coverage: 0.121, diversity: 1.0, batch_value_loss: 1407557060.465
# Stream: 1485, user_count: 68, avg_reward@stream: 1.22, avg_reward: 1.01, hr10: 0.883, regret: 8.779, coverage: 0.138, diversity: 1.0, batch_value_loss: 1342281487.059
# Stream: 1486, user_count: 15, avg_reward@stream: 1.27, avg_reward: 1.01, hr10: 1.0, regret: 8.733, coverage: 0.211, diversity: 1.0, batch_value_loss: 1825764966.4
# Stream: 1487, user_count: 23, avg_reward@stream: 1.61, avg_reward: 1.01, hr10: 1.088, regret: 8.391, coverage: 0.324, diversity: 1.0, batch_value_loss: 1340989796.174
# Stream: 1488, user_count: 4, avg_reward@stream: 1.0, avg_reward: 1.01, hr10: 1.0, regret: 9.0, coverage: 0.5, diversity: 1.0, batch_value_loss: 1241692672.0
# Stream: 1489, user_count: 14, avg_reward@stream: 1.14, avg_reward: 1.01, hr10: 0.842, regret: 8.857, coverage: 0.474, diversity: 1.0, batch_value_loss: 1660745581.714
# Stream: 1490, user_count: 120, avg_reward@stream: 1.17, avg_reward: 1.01, hr10: 0.725, regret: 8.833, coverage: 0.083, diversity: 1.0, batch_value_loss: 1536602794.667
# Stream: 1491, user_count: 216, avg_reward@stream: 1.14, avg_reward: 1.01, hr10: 0.766, regret: 8.861, coverage: 0.072, diversity: 1.0, batch_value_loss: 1525728597.333
# Stream: 1492, user_count: 62, avg_reward@stream: 0.56, avg_reward: 1.01, hr10: 0.412, regret: 9.435, coverage: 0.141, diversity: 1.0, batch_value_loss: 1514493357.419
# Stream: 1493, user_count: 40, avg_reward@stream: 0.88, avg_reward: 1.01, hr10: 0.648, regret: 9.125, coverage: 0.222, diversity: 1.0, batch_value_loss: 1551757107.2
# Stream: 1494, user_count: 29, avg_reward@stream: 1.76, avg_reward: 1.01, hr10: 1.308, regret: 8.241, coverage: 0.333, diversity: 1.0, batch_value_loss: 1817149157.517
# Stream: 1495, user_count: 233, avg_reward@stream: 0.92, avg_reward: 1.01, hr10: 0.54, regret: 9.077, coverage: 0.05, diversity: 1.0, batch_value_loss: 1527743870.352
# Stream: 1496, user_count: 135, avg_reward@stream: 0.93, avg_reward: 1.01, hr10: 0.543, regret: 9.067, coverage: 0.078, diversity: 1.0, batch_value_loss: 1644365596.444
# Stream: 1497, user_count: 173, avg_reward@stream: 0.28, avg_reward: 1.01, hr10: 0.195, regret: 9.717, coverage: 0.108, diversity: 0.725, batch_value_loss: 1645761814.197
# Stream: 1498, user_count: 46, avg_reward@stream: 0.8, avg_reward: 1.01, hr10: 0.569, regret: 9.196, coverage: 0.308, diversity: 0.792, batch_value_loss: 1304912139.13
# Stream: 1499, user_count: 14, avg_reward@stream: 1.14, avg_reward: 1.01, hr10: 1.143, regret: 8.857, coverage: 0.286, diversity: 1.0, batch_value_loss: 1751678098.286
# Stream: 1500, user_count: 22, avg_reward@stream: 2.14, avg_reward: 1.01, hr10: 1.205, regret: 7.864, coverage: 0.308, diversity: 1.0, batch_value_loss: 1452746565.818
# Stream: 1501, user_count: 60, avg_reward@stream: 1.98, avg_reward: 1.01, hr10: 1.202, regret: 8.017, coverage: 0.172, diversity: 1.0, batch_value_loss: 1674763332.267
# Stream: 1502, user_count: 166, avg_reward@stream: 0.83, avg_reward: 1.01, hr10: 0.623, regret: 9.175, coverage: 0.095, diversity: 1.0, batch_value_loss: 1418085832.482
# Stream: 1503, user_count: 74, avg_reward@stream: 2.07, avg_reward: 1.01, hr10: 1.195, regret: 7.932, coverage: 0.133, diversity: 1.0, batch_value_loss: 1551087228.541
# Stream: 1504, user_count: 136, avg_reward@stream: 1.54, avg_reward: 1.01, hr10: 0.879, regret: 8.456, coverage: 0.079, diversity: 1.0, batch_value_loss: 1420653869.176
# Stream: 1505, user_count: 88, avg_reward@stream: 1.19, avg_reward: 1.02, hr10: 0.739, regret: 8.807, coverage: 0.134, diversity: 1.0, batch_value_loss: 1620747915.636
# Stream: 1506, user_count: 85, avg_reward@stream: 1.13, avg_reward: 1.02, hr10: 0.667, regret: 8.871, coverage: 0.125, diversity: 0.971, batch_value_loss: 1464021811.2
# Stream: 1507, user_count: 560, avg_reward@stream: 0.54, avg_reward: 1.01, hr10: 0.302, regret: 9.461, coverage: 0.031, diversity: 0.976, batch_value_loss: 1442541685.029
# Stream: 1508, user_count: 32, avg_reward@stream: 1.94, avg_reward: 1.01, hr10: 1.148, regret: 8.062, coverage: 0.296, diversity: 1.0, batch_value_loss: 1451899648.0
# Stream: 1509, user_count: 34, avg_reward@stream: 0.44, avg_reward: 1.01, hr10: 0.319, regret: 9.559, coverage: 0.191, diversity: 0.917, batch_value_loss: 1545996649.412

# %%
diff_items = {'mode': f'hybrid_vdbe_pca', 
              'reward_records': reward_records, 
              'avg_rewards': avg_rewards,
              'hit_ratios': hit_ratios,
              'regret_list': regret_list,
              'coverage_list': coverage_list,
              'diversity_list': diversity_list}

with open(f'results/hybrid_vdbe_pca.pkl', 'wb') as handle:
    pickle.dump(diff_items, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ---
# Previous Version of Training Methods

# %%
# def train(agent, reward_records=[], avg_rewards=[], warmup=100, episode_len=5000):
#   agent.actor.train(True)
#   agent.critic.train(True)
#   batch_value_loss, batch_policy_loss = 0., 0.
#   step_value_loss, step_policy_loss = 0., 0.
#   step = 0

#   # ------------------- Episode (State) -------------------------------
#   for stream in tqdm(STREAM_LIST[:episode_len]):
#     # self.__user_episode_context()
#     users = STREAM_USER_DICT[stream]
#     agent.curr_stream = stream
#     agent.curr_stream_items = STREAM_ITEM_DICT[stream]
#     stream_reward = 0
#     batch_value_loss, batch_policy_loss = 0., 0.

#     # ----------------- Runs (User under stream) ---------------------
#     for i, user in enumerate(users):
#       # update step
#       step += 1
      
#       # state & ongoing
#       agent.curr_user = user
#       state = USER_CONTEXT.loc[(user, stream)]
#       ongoing = i != len(users) - 1

#       # --------------- Actor net choose actions ----------------------
#       # make actor to choose action
#       # action = latent vector
#       if step <= warmup:
#         action = agent.random_action()
#       else:
#         action = agent.generate_latent_action(state)
          
#       # --------------- Get next state & info to store ---------------
#       # Generate reward
#       reward = agent.get_actions_rewards()

#       # next_state: next user's state
#       next_user = users[i + 1] if i + 1 < len(users) else None
#       # Remember only when reward > 0 or the memory is short
#       reward_records.append(reward)
#       stream_reward += reward
#       if reward > 0 or len(agent.buffer) < 10:
#         storing_state = (user, stream)
#         storing_next_state = (next_user, stream) if next_user else storing_state
#         agent.buffer.remember(storing_state, action, reward, storing_next_state, ongoing)

#       # --------------- Train on Actor and Critic --------------------
#       # store pre-training value for td_error
#       state = to_tensor(state).view(1, 175)
#       action = to_tensor(action).view(1, 150)
#       old_Q = agent.critic([state, action]).cpu().detach().numpy()
      
#       if step > warmup :
#         step_value_loss, step_policy_loss = agent.update_policy()
      
#       # store post-training value for td_error
#       new_Q = agent.critic([state, action]).cpu().detach().numpy()
      
#       batch_value_loss += step_value_loss
#       batch_policy_loss += step_policy_loss

#       # --------------- Update with TD error -------------------------
#       agent.vdbe.update_at_step(user, (new_Q - old_Q), 1/len(agent.curr_stream_items))

#       # --------------- Inspecting result at step -------------------------
#     ep_avg_reward = round(sum(reward_records)/step, 2)
#     avg_rewards.append(ep_avg_reward)
#     print(f'Stream: {stream}, user_count: {len(users)}, \
# sum_rewards: {round(sum(reward_records), 2)},avg_reward@stream: {round(stream_reward/len(users), 2)}, avg_reward: {ep_avg_reward}, \
# batch_value_loss: {round(float(batch_value_loss), 3)}, batch_policy_loss: {round(float(batch_policy_loss), 3)} | reward_len: {len(reward_records)}')
    
#     if len(reward_records) >= 247581: break

# %% [markdown]
# ## Profiler

# %%
# %load_ext line_profiler
# %lprun -f train train(ddpg_agent, reward_records, avg_rewards, episode_len=1)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# torch.Size([175]) torch.Size([150])
# IndexErrorTraceback (most recent call last)
# <ipython-input-27-e55d4c31160a> in <module>
#       1 get_ipython().run_line_magic('load_ext', 'line_profiler')
# ----> 2 get_ipython().run_line_magic('lprun', '-f train train(ddpg_agent, reward_records, avg_rewards, episode_len=1)')
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2324                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2325             with self.builtin_trap:
# -> 2326                 result = fn(*args, **kwargs)
#    2327             return result
#    2328
#
# <decorator-gen-126> in lprun(self, parameter_s)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.6/dist-packages/line_profiler/ipython_extension.py in lprun(self, parameter_s)
#     102         try:
#     103             try:
# --> 104                 profile.runctx(arg_str, global_ns, local_ns)
#     105                 message = ""
#     106             except SystemExit:
#
# /usr/local/lib/python3.6/dist-packages/line_profiler/line_profiler.py in runctx(self, cmd, globals, locals)
#     158         self.enable_by_count()
#     159         try:
# --> 160             exec(cmd, globals, locals)
#     161         finally:
#     162             self.disable_by_count()
#
# <string> in <module>
#
# <ipython-input-23-6402a3949665> in train(agent, reward_records, avg_rewards, warmup, episode_len)
#      53       action = to_tensor(action)
#      54       print(f'{state.shape} {action.shape}')
# ---> 55       old_Q = agent.critic([state, action])
#      56
#      57       if step > warmup :
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-16-938025ee5561> in forward(self, xs)
#      57     def forward(self, xs):
#      58         x, a = xs
# ---> 59         out = self.fc1(torch.cat([x,a],1))
#      60         out = self.relu(out)
#      61         out = self.fc2(out)
#
# IndexError: Dimension out of range (expected to be in range of [-1, 0], but got 1)

# %%
# %lprun -f ddpg_agent.get_actions_rewards ddpg_agent.get_actions_rewards()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.00384858 s
# File: <ipython-input-29-bfe39c297bb8>
# Function: get_actions_rewards at line 123
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    123                                             def get_actions_rewards(self):
#    124         1       1871.0   1871.0      0.0      true_list = USER_BOUGHT_DICT[self.curr_user]
#    125                                               # self.curr_stream_items: candidate items in current stream
#    126         1    3830714.0 3830714.0     99.5      actions = ITEM_PCA_DF.iloc[self.curr_stream_items].apply(lambda x: np.dot(x, self.action), axis=1).nlargest(self.top_k).index
#    127         1      15861.0  15861.0      0.4      res = sum([1 if a in true_list else 0 for a in actions])
#    128         1        131.0    131.0      0.0      return res

# %%
np.dot(ddpg_agent.curr_stream_items, b)

# %%
ITEM_PCA_DF.iloc[ddpg_agent.curr_stream_items].apply(lambda x: np.dot(x, ddpg_agent.action), axis=1).nlargest(10).index
# Out:
# Int64Index([20721, 20792, 20732, 20755, 20785, 20752], dtype='int64')

# %%
ddpg_agent.curr_stream_items = [20732,
 20792,
 20755,
 20785,
 20721,
 20752]
