# %% [markdown]
# # DDPG
# > Experiment list: Param Noise + Param Multiplier

# %%
import pandas as pd
import numpy as np
import itertools
from tqdm.notebook import tqdm
import pickle

import torch
import torch.utils.data as data
from torch.utils.data import DataLoader
import torch.utils.data.sampler as sampler
import torch.nn as nn
import torch.nn.functional as F

from matplotlib import pyplot as plt
from collections import defaultdict
import warnings
from sklearn.preprocessing import LabelEncoder
import random
from datetime import datetime
import pytz
import line_profiler
from functools import reduce

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Fix Random Seeds

# %%
def same_seeds(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  
  np.random.seed(seed)  
  torch.backends.cudnn.benchmark = False
  torch.backends.cudnn.deterministic = True

same_seeds(0)

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Available Files
#
# ||Title|File Name|
# |---|-----|---------|
# |order|Stream group by streamers|`streamer_stream_dict.pkl`|
# ||Stream list|`stream_list.pkl`|
# |Context|Final user context|`user_context.pkl`|
# ||Streamer context|`streamer.pkl`|
# ||Item context|`item_pca_df.pkl`|
# |Aux|stream: items list|`stream_item_dict.pkl`|
# ||stream: users list|`stream_users_dict.pkl`|
# ||item list the consumer actually bought|`user_bought_dict.pkl`|
# |Explore-Diff|PCA based diff vector|`diff_vectors_pca.pkl`|
# ||SVD based diff vector|`diff_vectors_svd.pkl`|
# ||VAE based diff vector|`diff_vectors_vae.pkl`|
# |Threshold|VAE reconstruction error df|`vae_recons_df.pkl`|

# %%
# STREAMER_STREAM_DICT = pd.read_pickle('../../data/streamer_stream_dict.pkl')
STREAM_LIST = pd.read_pickle('../../data/stream_list.pkl')
USER_CONTEXT = pd.read_pickle('../../data/user_context.pkl')
# STREAMER = pd.read_pickle('../../data/streamer.pkl')
ITEM_PCA_DF = pd.read_pickle('../../data/item_pca_df.pkl')
STREAM_ITEM_DICT = pd.read_pickle('../../data/stream_item_dict.pkl')
USER_BOUGHT_DICT = pd.read_pickle('../../data/user_bought_dict.pkl')
STREAM_USER_DICT = pd.read_pickle('../../data/stream_users_dict.pkl')
# Current used diff
ITEM_DIFF = pd.read_pickle('../../data/item_diff_vectors.pkl')
STREAM_ORDER_CNT = pd.read_pickle('../../data/stream_order_cnt_list.pkl')

# %%
MULTIPLIER = pd.read_pickle('../../data/dot_multiplier_scaled.pkl').astype('float32')
DIFF_PCA = pd.read_pickle('../../data/diff_vectors_pca.pkl')
# DIFF_SVD = pd.read_pickle('../../data/diff_vectors_svd.pkl')
# DIFF_VAE = pd.read_pickle('../../data/diff_vectors_vae.pkl')
# VAE_RECONS_DF = pd.read_pickle('../../data/vae_recons_df.pkl')
# VAE_RECONS64_DF = pd.read_pickle('../../data/vae_recons_64_df.pkl')
# MUL150_PCA = pd.read_pickle('../../data/mul150_pca_diff.pkl')
# MUL150_VAE = pd.read_pickle('../../data/mul150_vae_diff.pkl')
# MUL64_PCA = pd.read_pickle('../../data/mul64_pca_diff.pkl')
# MUL64_VAE = pd.read_pickle('../../data/mul64_vae_diff.pkl')

# %% [markdown]
# ---

# %% [markdown]
# ## Replay

# %%
class RingBuffer(object):
    def __init__(self, maxlen):
        self.maxlen = maxlen
        self.start = 0
        self.length = 0
        self.data = [None for _ in range(maxlen)]

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        if idx < 0 or idx >= self.length:
            raise KeyError()
        return self.data[(self.start + idx) % self.maxlen]

    def append(self, v):
        if self.length < self.maxlen:
            # We have space, simply increase the length.
            self.length += 1
        elif self.length == self.maxlen:
            # No space, "remove" the first item.
            self.start = (self.start + 1) % self.maxlen
        else:
            # This should never happen.
            raise RuntimeError()
        self.data[(self.start + self.length - 1) % self.maxlen] = v

class ReplayBuffer:
  def __init__(self, limit=10000):
    self.limit = limit
    # init 4 RingBuffers: states/actions/rewards/ongoing
    self.states_buffer = RingBuffer(limit)
    self.next_states_buffer = RingBuffer(limit)
    self.actions_buffer = RingBuffer(limit)
    self.rewards_buffer = RingBuffer(limit)
    self.ongoings_buffer = RingBuffer(limit)
    
  def __len__(self):
    assert len(self.states_buffer) == len(self.next_states_buffer) == len(self.actions_buffer) == \
           len(self.rewards_buffer) == len(self.ongoings_buffer)
    return len(self.states_buffer)

  def remember(self, state, actions, reward, next_state, ongoing):
    assert len(self.states_buffer) == len(self.next_states_buffer) == len(self.actions_buffer) == \
           len(self.rewards_buffer) == len(self.ongoings_buffer)
    # append each element separately in different list
    self.states_buffer.append(state)
    self.actions_buffer.append(actions)
    self.rewards_buffer.append(reward)
    self.next_states_buffer.append(next_state)
    self.ongoings_buffer.append(ongoing)
    
  def get_batch(self, batch_size=100):
    assert len(self.states_buffer) == len(self.next_states_buffer) == len(self.actions_buffer) == \
           len(self.rewards_buffer) == len(self.ongoings_buffer)
    # same for sample_and_split
    states0_batch = []
    states1_batch = []
    actions_batch = []
    rewards_batch = []
    ongoings_batch = []
    batch_indexs = np.random.randint(0, len(self.states_buffer), size=min(len(self.states_buffer), batch_size))
    for i in batch_indexs:
      states0_batch.append(USER_CONTEXT.xs(self.states_buffer[i]))
      states1_batch.append(USER_CONTEXT.xs(self.next_states_buffer[i]))
      actions_batch.append(self.actions_buffer[i])
      rewards_batch.append(self.rewards_buffer[i])
      ongoings_batch.append(self.ongoings_buffer[i])
    assert len(states0_batch) == len(states1_batch) == len(actions_batch) == \
           len(rewards_batch) == len(ongoings_batch)
    return np.array(states0_batch), np.array(actions_batch), np.array(rewards_batch), np.array(states1_batch), np.array(ongoings_batch)

# %% [markdown]
# ## Random Process

# %%
class RandomProcess(object):
    def reset_states(self):
        pass

class AnnealedGaussianProcess(RandomProcess):
    def __init__(self, mu, sigma, sigma_min, n_steps_annealing):
        self.mu = mu
        self.sigma = sigma
        self.n_steps = 0

        if sigma_min is not None:
            self.m = -float(sigma - sigma_min) / float(n_steps_annealing)
            self.c = sigma
            self.sigma_min = sigma_min
        else:
            self.m = 0.
            self.c = sigma
            self.sigma_min = sigma

    @property
    def current_sigma(self):
        sigma = max(self.sigma_min, self.m * float(self.n_steps) + self.c)
        return sigma


# Based on http://math.stackexchange.com/questions/1287634/implementing-ornstein-uhlenbeck-in-matlab
class OrnsteinUhlenbeckProcess(AnnealedGaussianProcess):
    def __init__(self, theta, mu=0., sigma=1., dt=1e-2, x0=None, size=1, sigma_min=None, n_steps_annealing=1000):
        super(OrnsteinUhlenbeckProcess, self).__init__(mu=mu, sigma=sigma, sigma_min=sigma_min, n_steps_annealing=n_steps_annealing)
        self.theta = theta
        self.mu = mu
        self.dt = dt
        self.x0 = x0
        self.size = size
        self.reset_states()

    def sample(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + self.current_sigma * np.sqrt(self.dt) * np.random.normal(size=self.size)
        self.x_prev = x
        self.n_steps += 1
        return x

    def reset_states(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros(self.size)

# %% [markdown]
# ## Models

# %%
def fanin_init(size, fanin=None):
    fanin = fanin or size[0]
    v = 1. / np.sqrt(fanin)
    return torch.Tensor(size).uniform_(-v, v)

class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, mode, hidden1=400, hidden2=300, init_w=3e-3):
        super(Actor, self).__init__()
        self.mode = mode
        self.fc1 = nn.Linear(state_dim, hidden1)
        self.fc2 = nn.Linear(hidden1, hidden2)
        self.fc3 = nn.Linear(hidden2, action_dim)
        self.norm1 = nn.LayerNorm(hidden1)
        self.norm2 = nn.LayerNorm(hidden2)
        self.norm3 = nn.LayerNorm(action_dim)
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()
        self.init_weights(init_w)
    
    def init_weights(self, init_w):
        self.fc1.weight.data = fanin_init(self.fc1.weight.data.size())
        self.fc2.weight.data = fanin_init(self.fc2.weight.data.size())
        self.fc3.weight.data.uniform_(-init_w, init_w)
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.norm1(out)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.fc3(out)
        out = self.norm3(out)
        out = self.tanh(out)
        return out

    def add_parameter_noise(self, scalar=.1):
        self.fc1.weight.data += torch.randn_like(self.fc1.weight.data) * scalar
        self.fc2.weight.data += torch.randn_like(self.fc2.weight.data) * scalar
        self.fc3.weight.data += torch.randn_like(self.fc3.weight.data) * scalar


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim, hidden1=400, hidden2=300, init_w=3e-3):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(state_dim, hidden1)
        self.fc2 = nn.Linear(hidden1+action_dim, hidden2)
        self.fc3 = nn.Linear(hidden2, 1)
        self.relu = nn.ReLU()
        self.init_weights(init_w)
    
    def init_weights(self, init_w):
        self.fc1.weight.data = fanin_init(self.fc1.weight.data.size())
        self.fc2.weight.data = fanin_init(self.fc2.weight.data.size())
        self.fc3.weight.data.uniform_(-init_w, init_w)
    
    def forward(self, xs):
        x, a = xs
        out = self.fc1(x)
        out = self.relu(out)
        # debug()
        out = self.fc2(torch.cat([out,a],1))
        out = self.relu(out)
        out = self.fc3(out)
        return out

# %% [markdown]
# ## DDPG

# %%
def to_tensor(input_df):
  return torch.tensor(input_df).to(DEVICE).float()

class DDPG(object):
  def __init__(self, actor_lr, critic_lr, state_dim, action_dim, mode='baseline',
               hidden1=400, hidden2=300, diff_multiplier=1,
               top_k=10, max_memory=10000, depsilon=50000, discount=0.99,
               tau=0.001, batch_size=100, ou_theta=0.15, ou_mu=0.0, ou_sigma=0.2, 
               param_noise_scalar=.05, param_noise_scalar_alpha=1.01, desired_distance=.7):
    # State & Action dimension
    self.state_dim = state_dim
    self.action_dim = action_dim
    
    # Mode settings
    # baseline
    # diff: diff_pca, diff_svd, diff_vae
    # threshold: thres_vae, thres_vdbe
    # multiplier: MUL150_PCA, MUL150_VAE, MUL64_PCA, MUL64_VAE
    # Parameter noise: PARAM_NOISE
    self.mode = mode
    self.diff_multiplier = diff_multiplier
    
    # Param Noise
    self.distances = []
    self.desired_distance = desired_distance
    self.param_noise_scalar = param_noise_scalar
    self.param_noise_scalar_alpha = param_noise_scalar_alpha

    # Init Actor
    self.actor = Actor(state_dim, action_dim, mode, hidden1, hidden2)
    self.actor_noised = Actor(state_dim, action_dim, mode, hidden1, hidden2)
    self.actor_target = Actor(state_dim, action_dim, mode, hidden1, hidden2)
    self.actor_optim = torch.optim.Adam(self.actor.parameters(), lr=actor_lr)
    # Init Critic
    self.critic = Critic(state_dim, action_dim, hidden1, hidden2)
    self.critic_target = Critic(state_dim, action_dim, hidden1, hidden2)
    self.critic_optim = torch.optim.Adam(self.critic.parameters(), lr=critic_lr)

    # Memory
    self.buffer = ReplayBuffer(limit=max_memory)

    # Exploration
    self.epsilon = 1.0
    self.depsilon = 1.0 / depsilon
    self.random_process = OrnsteinUhlenbeckProcess(size=action_dim, theta=ou_theta, mu=ou_mu, sigma=ou_sigma)

    # Reward related
    self.top_k = top_k
    
    # Loss Function
    self.loss_fn = nn.MSELoss()
    
    # Hyperparameters
    self.discount = discount
    self.tau = tau
    self.batch_size = batch_size

    # Network to cuda
    self.actor.to(DEVICE)
    self.actor_noised.to(DEVICE)
    self.critic.to(DEVICE)
    self.actor_target.to(DEVICE)
    self.critic_target.to(DEVICE)
    
  def random_action(self):
    action = np.random.uniform(-1.,1.,self.action_dim).astype('float32')
    self.action = action
    return action
    
  def generate_latent_action(self, state, decay_epsilon=True, vdbe_epsilon=False):
    action = self.actor(to_tensor(state))
    '''
    Param Noise
    '''
    with torch.no_grad():
      # hard copy the actor to actor_noised
      self.actor_noised.load_state_dict(self.actor.state_dict().copy())

      # add noise to the copy
      self.actor_noised.add_parameter_noise(self.param_noise_scalar)

      # get the next action values from the noised actor
      action_noised = self.actor_noised(to_tensor(state))

      # meassure the distance between the action values from the regular and 
      # the noised actor to adjust the amount of noise that will be added next round
      distance = torch.sqrt(torch.mean(torch.square(action - action_noised))).cpu().detach().numpy()

      # adjust the amount of noise given to the actor_noised
      if distance < self.desired_distance:
          self.param_noise_scalar *= self.param_noise_scalar_alpha
      else:
          self.param_noise_scalar /= self.param_noise_scalar_alpha

      # set the noised action as action
      action = action_noised
    '''
    Add the diff vector to action
    '''
    if self.mode != 'baseline':
      current_diff = globals()[self.mode.upper()]

      if self.mode == 'thres_vae' and state.name in current_diff.index:
        if VAE_RECONS_DF.loc[state.name][0] > 0.275:
          action += to_tensor(DIFF_VAE.loc[state.name])
      elif self.mode == 'thres_vae_64' and state.name in current_diff.index:
        if VAE_RECONS64_DF.loc[state.name][0] > 0.02:
          action += to_tensor(DIFF_VAE.loc[state.name])
      elif state.name in current_diff.index:
        # for mode = [diff_pca, diff_svd, diff_vae, MUL150_VAE, MUL64_VAE, ITEM_DIFF]
        param_mul = to_tensor(MULTIPLIER.loc[state.name])
        action += to_tensor(current_diff.loc[state.name]) * param_mul

    # else: action += max(self.epsilon, 0) * torch.tensor(self.random_process.sample()).to(DEVICE).float()
    action = torch.clamp(action, -1., 1.).cpu().detach().numpy()

    if decay_epsilon:
      self.epsilon -= self.depsilon
    # if vdbe_epsilon:
        
    self.action = action
    return action
  
  def get_actions_rewards(self):
    true_list = USER_BOUGHT_DICT[self.curr_user]
    hit_list, rewarded_items = [], set()
    self.action_list = ITEM_PCA_DF.iloc[self.curr_stream_items].apply(lambda x: np.dot(x, self.action), axis=1).nlargest(self.top_k).index
    for a in self.action_list:
      if a in true_list:
        hit_list.append(1)
        rewarded_items.add(a)
      else: hit_list.append(0)
    res = sum(hit_list)
    return res, rewarded_items
    
  def update_policy(self):
    # Sample batch
    state_batch, action_batch, reward_batch, \
    next_state_batch, ongoing_batch = self.buffer.get_batch(self.batch_size)
    
    # Prepare for the target q batch
    next_q_values = self.critic_target([
        to_tensor(next_state_batch).detach(),
        self.actor_target(to_tensor(next_state_batch).detach()),
    ])
    
    # 如果 ongoing 為 True(1) 時，乘以 next_q 會有值
    # 但是 ongoing 為 False(0) 時，乘以 next_q 會等於 0
    target_q_batch = to_tensor(reward_batch).view(next_q_values.shape) + \
                       self.discount*to_tensor(ongoing_batch).view(next_q_values.shape)*next_q_values.detach()

    # Critic update
    self.critic_optim.zero_grad()

    q_batch = self.critic([ to_tensor(state_batch), to_tensor(action_batch) ])

    value_loss = self.loss_fn(q_batch, target_q_batch)
    value_loss.backward()
    self.critic_optim.step()

    # Actor update
    self.actor_optim.zero_grad()

    policy_loss = -self.critic([
        to_tensor(state_batch),
        self.actor(to_tensor(state_batch))
    ])

    policy_loss = policy_loss.mean()
    policy_loss.backward()
    self.actor_optim.step()

    # Target update
    self._soft_update(self.actor_target, self.actor)
    self._soft_update(self.critic_target, self.critic)
    return value_loss, policy_loss
    
  def _soft_update(self, target, source):
    for target_param, param in zip(target.parameters(), source.parameters()):
        target_param.data.copy_(
            target_param.data * (1.0 - self.tau) + param.data * self.tau
        )

# %% [markdown]
# ## Main Method

# %%
def train(agent, reward_records=[], avg_rewards=[], hit_ratios=[], regret_list=[], coverage_list=[], diversity_list=[], warmup=100, ep_len=4000):
  agent.actor.train(True)
  agent.critic.train(True)
  batch_value_loss, batch_policy_loss = 0., 0.
  step_value_loss, step_policy_loss = 0., 0.
  step = 0
  # self.epsilon.clear()

  # ------------------- Episode (State) -------------------------------
  for stream in tqdm(STREAM_LIST[:3300]):
    # self.__user_episode_context()
    users = STREAM_USER_DICT[stream]

    agent.curr_stream = stream
    agent.curr_stream_items = STREAM_ITEM_DICT[stream]
    batch_value_loss, batch_policy_loss = 0., 0.
    stream_reward = 0
    false_positive_cnt = 0
    diversity_prod_set = set()
    coverage_rewarded_items = set()

    # ----------------- Runs (User under stream) ---------------------
    for i, user in enumerate(users):
      # update step
      step += 1
      
      # state & ongoing
      agent.curr_user = user
      state = USER_CONTEXT.loc[(user, stream)]
      ongoing = i != len(users) - 1

      # --------------- Actor net choose actions ----------------------
      # make actor to choose action
      # action = latent vector
      if step <= warmup:
        action = agent.random_action()
      else:
        action = agent.generate_latent_action(state)
          
      # --------------- Get next state & info to store ---------------
      # Generate reward
      reward, curr_rewarded_items = agent.get_actions_rewards()

      # next_state: next user's state
      next_user = users[i + 1] if i + 1 < len(users) else None
      
      # update metrics
      reward_records.append(reward)
      stream_reward += reward
      false_positive_cnt += (10 - reward)
      coverage_rewarded_items = coverage_rewarded_items | curr_rewarded_items
      diversity_prod_set = diversity_prod_set | set(agent.action_list)
      
      # Remember only when reward > 0 or the memory is short
      if reward > 0 or len(agent.buffer) < 10:
        storing_state = (user, stream)
        storing_next_state = (next_user, stream) if next_user else storing_state
        agent.buffer.remember(storing_state, action, reward, storing_next_state, ongoing)

      # --------------- Train on Actor and Critic --------------------
      # store pre-training value for td_error
      # old_Q = self.q_value()
      if step > warmup :
        step_value_loss, step_policy_loss = agent.update_policy()
      # store post-training value for td_error
      # new_Q = self.q_value()
      batch_value_loss += step_value_loss
      batch_policy_loss += step_policy_loss

      # --------------- Update with TD error -------------------------
      # self.epsilon.update_at_step(self.asid, [(new_Q - old_Q), self.learn_step_counter], 1/len(self.stream_items))

    # --------------- Inspecting result at step -------------------------
    ep_avg_reward = round(sum(reward_records)/step, 2)
    avg_rewards.append(ep_avg_reward)
    
    ground_truth = STREAM_ORDER_CNT.iloc[stream]
    # hit ratio
    hr10 = stream_reward / ground_truth
    hit_ratios.append(hr10)
    # regret
    regret = false_positive_cnt / len(users)
    regret_list.append(regret)
    # coverage
    coverage = len(coverage_rewarded_items) / ground_truth
    coverage_list.append(coverage)
    # diversity
    diversity = len(diversity_prod_set) / len(STREAM_ITEM_DICT[stream])
    diversity_list.append(diversity)
    
    print(f'Stream: {stream}, user_count: {len(users)}, avg_reward@stream: {round(stream_reward/len(users), 2)}, avg_reward: {ep_avg_reward}, \
hr10: {round(hr10, 3)}, regret: {round(regret, 3)}, coverage: {round(coverage, 3)}, diversity: {round(diversity, 3)}, \
batch_value_loss: {round(float(batch_value_loss)/len(users), 3)}')
    
    # if len(reward_records) >= 247581: break

# %%
pd.set_option('mode.chained_assignment', None)

actor_lr = 1.0e-3
critic_lr = 1.0e-3
state_dim = USER_CONTEXT.shape[1]
action_dim = ITEM_PCA_DF.shape[1]
hidden1 = 400
hidden2 = 300
diff_multiplier = 1
top_k = 10
max_memory = 10000
depsilon = 50000
discount = 0.99
tau = 0.001
batch_size = 100
ou_theta = 0.15
ou_mu = 0.0
ou_sigma = 0.2
param_noise_scalar = 0.05
param_noise_scalar_alpha = 1.01
desired_distance = 0.7

mode = 'diff_pca'

warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Execute

# %%
ddpg_agent = DDPG(actor_lr, critic_lr, state_dim, action_dim, mode, hidden1, hidden2, diff_multiplier,
                  top_k, max_memory, depsilon, discount, tau, batch_size, ou_theta, ou_mu, ou_sigma, 
                  param_noise_scalar, param_noise_scalar_alpha, desired_distance)
reward_records = []
avg_rewards = []
hit_ratios, regret_list, coverage_list, diversity_list = [], [], [], []
train(ddpg_agent, reward_records, avg_rewards, hit_ratios, regret_list, coverage_list, diversity_list)
# Out:
#   0%|          | 0/3300 [00:00<?, ?it/s]
# Stream: 0, user_count: 56, avg_reward@stream: 0.32, avg_reward: 0.32, hr10: 0.24, regret: 9.679, coverage: 0.2, diversity: 1.0, batch_value_loss: 0.0
# Stream: 1, user_count: 534, avg_reward@stream: 0.44, avg_reward: 0.43, hr10: 0.141, regret: 9.558, coverage: 0.035, diversity: 1.0, batch_value_loss: 0.054
# Stream: 2, user_count: 56, avg_reward@stream: 1.29, avg_reward: 0.5, hr10: 0.713, regret: 8.714, coverage: 0.158, diversity: 1.0, batch_value_loss: 0.046
# Stream: 3, user_count: 29, avg_reward@stream: 1.38, avg_reward: 0.54, hr10: 0.87, regret: 8.621, coverage: 0.283, diversity: 1.0, batch_value_loss: 0.071
# Stream: 4, user_count: 104, avg_reward@stream: 0.17, avg_reward: 0.49, hr10: 0.118, regret: 9.827, coverage: 0.099, diversity: 0.887, batch_value_loss: 0.021
# Stream: 5, user_count: 83, avg_reward@stream: 0.75, avg_reward: 0.52, hr10: 0.689, regret: 9.253, coverage: 0.111, diversity: 1.0, batch_value_loss: 0.011
# Stream: 6, user_count: 37, avg_reward@stream: 0.81, avg_reward: 0.53, hr10: 0.405, regret: 9.189, coverage: 0.216, diversity: 0.892, batch_value_loss: 0.024
# Stream: 7, user_count: 213, avg_reward@stream: 0.18, avg_reward: 0.46, hr10: 0.152, regret: 9.817, coverage: 0.082, diversity: 0.947, batch_value_loss: 0.006
# Stream: 8, user_count: 42, avg_reward@stream: 1.02, avg_reward: 0.48, hr10: 1.024, regret: 8.976, coverage: 0.143, diversity: 1.0, batch_value_loss: 0.005
# Stream: 9, user_count: 2628, avg_reward@stream: 0.66, avg_reward: 0.61, hr10: 0.266, regret: 9.336, coverage: 0.009, diversity: 1.0, batch_value_loss: 0.03
# Stream: 10, user_count: 112, avg_reward@stream: 0.29, avg_reward: 0.6, hr10: 0.27, regret: 9.705, coverage: 0.107, diversity: 1.0, batch_value_loss: 0.099
# Stream: 11, user_count: 343, avg_reward@stream: 1.05, avg_reward: 0.64, hr10: 0.543, regret: 8.95, coverage: 0.03, diversity: 1.0, batch_value_loss: 0.189
# Stream: 12, user_count: 14, avg_reward@stream: 0.79, avg_reward: 0.64, hr10: 0.688, regret: 9.214, coverage: 0.562, diversity: 1.0, batch_value_loss: 0.182
# Stream: 13, user_count: 51, avg_reward@stream: 0.51, avg_reward: 0.64, hr10: 0.371, regret: 9.49, coverage: 0.2, diversity: 0.776, batch_value_loss: 0.3
# Stream: 14, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.64, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 0.186
# Stream: 15, user_count: 115, avg_reward@stream: 1.24, avg_reward: 0.65, hr10: 0.624, regret: 8.757, coverage: 0.066, diversity: 1.0, batch_value_loss: 0.307
# Stream: 16, user_count: 26, avg_reward@stream: 1.31, avg_reward: 0.65, hr10: 0.829, regret: 8.692, coverage: 0.268, diversity: 1.0, batch_value_loss: 0.361
# Stream: 17, user_count: 20, avg_reward@stream: 0.7, avg_reward: 0.66, hr10: 0.389, regret: 9.3, coverage: 0.306, diversity: 1.0, batch_value_loss: 0.442
# Stream: 18, user_count: 40, avg_reward@stream: 0.5, avg_reward: 0.65, hr10: 0.37, regret: 9.5, coverage: 0.296, diversity: 0.974, batch_value_loss: 0.332
# Stream: 19, user_count: 34, avg_reward@stream: 0.53, avg_reward: 0.65, hr10: 0.439, regret: 9.471, coverage: 0.268, diversity: 1.0, batch_value_loss: 0.306
# Stream: 20, user_count: 39, avg_reward@stream: 0.64, avg_reward: 0.65, hr10: 0.463, regret: 9.359, coverage: 0.296, diversity: 0.974, batch_value_loss: 0.334
# Stream: 21, user_count: 23, avg_reward@stream: 0.7, avg_reward: 0.65, hr10: 0.593, regret: 9.304, coverage: 0.481, diversity: 0.913, batch_value_loss: 0.236
# Stream: 22, user_count: 45, avg_reward@stream: 0.58, avg_reward: 0.65, hr10: 0.51, regret: 9.422, coverage: 0.216, diversity: 1.0, batch_value_loss: 0.428
# Stream: 23, user_count: 36, avg_reward@stream: 1.0, avg_reward: 0.65, hr10: 0.973, regret: 9.0, coverage: 0.162, diversity: 1.0, batch_value_loss: 0.265
# Stream: 24, user_count: 28, avg_reward@stream: 1.04, avg_reward: 0.66, hr10: 0.967, regret: 8.964, coverage: 0.333, diversity: 1.0, batch_value_loss: 0.262
# Stream: 25, user_count: 101, avg_reward@stream: 0.6, avg_reward: 0.66, hr10: 0.424, regret: 9.396, coverage: 0.125, diversity: 0.815, batch_value_loss: 0.257
# Stream: 26, user_count: 178, avg_reward@stream: 0.34, avg_reward: 0.64, hr10: 0.326, regret: 9.663, coverage: 0.098, diversity: 0.962, batch_value_loss: 0.233
# Stream: 27, user_count: 1447, avg_reward@stream: 0.43, avg_reward: 0.6, hr10: 0.27, regret: 9.57, coverage: 0.013, diversity: 1.0, batch_value_loss: 0.174
# Stream: 28, user_count: 9, avg_reward@stream: 1.0, avg_reward: 0.6, hr10: 0.9, regret: 9.0, coverage: 0.2, diversity: 1.0, batch_value_loss: 0.216
# Stream: 29, user_count: 43, avg_reward@stream: 0.42, avg_reward: 0.6, hr10: 0.265, regret: 9.581, coverage: 0.221, diversity: 0.754, batch_value_loss: 0.235
# Stream: 30, user_count: 64, avg_reward@stream: 0.3, avg_reward: 0.59, hr10: 0.232, regret: 9.703, coverage: 0.195, diversity: 0.733, batch_value_loss: 0.803
# Stream: 31, user_count: 68, avg_reward@stream: 0.49, avg_reward: 0.59, hr10: 0.306, regret: 9.515, coverage: 0.167, diversity: 0.791, batch_value_loss: 0.52
# Stream: 32, user_count: 56, avg_reward@stream: 0.43, avg_reward: 0.59, hr10: 0.338, regret: 9.571, coverage: 0.239, diversity: 0.863, batch_value_loss: 0.751
# Stream: 33, user_count: 128, avg_reward@stream: 1.39, avg_reward: 0.61, hr10: 0.777, regret: 8.609, coverage: 0.07, diversity: 1.0, batch_value_loss: 0.73
# Stream: 34, user_count: 28, avg_reward@stream: 0.96, avg_reward: 0.61, hr10: 0.75, regret: 9.036, coverage: 0.361, diversity: 0.947, batch_value_loss: 0.82
# Stream: 35, user_count: 28, avg_reward@stream: 1.0, avg_reward: 0.61, hr10: 0.8, regret: 9.0, coverage: 0.257, diversity: 1.0, batch_value_loss: 1.32
# Stream: 36, user_count: 127, avg_reward@stream: 0.91, avg_reward: 0.61, hr10: 0.567, regret: 9.094, coverage: 0.084, diversity: 1.0, batch_value_loss: 1.177
# Stream: 37, user_count: 210, avg_reward@stream: 0.7, avg_reward: 0.62, hr10: 0.551, regret: 9.3, coverage: 0.086, diversity: 1.0, batch_value_loss: 1.079
# Stream: 38, user_count: 6, avg_reward@stream: 1.33, avg_reward: 0.62, hr10: 1.0, regret: 8.667, coverage: 0.75, diversity: 1.0, batch_value_loss: 1.079
# Stream: 39, user_count: 55, avg_reward@stream: 0.64, avg_reward: 0.62, hr10: 0.493, regret: 9.364, coverage: 0.169, diversity: 0.903, batch_value_loss: 1.644
# Stream: 40, user_count: 93, avg_reward@stream: 1.59, avg_reward: 0.63, hr10: 0.59, regret: 8.409, coverage: 0.08, diversity: 0.929, batch_value_loss: 1.486
# Stream: 41, user_count: 42, avg_reward@stream: 1.1, avg_reward: 0.63, hr10: 1.022, regret: 8.905, coverage: 0.2, diversity: 1.0, batch_value_loss: 1.089
# Stream: 42, user_count: 125, avg_reward@stream: 0.51, avg_reward: 0.63, hr10: 0.5, regret: 9.488, coverage: 0.117, diversity: 1.0, batch_value_loss: 1.23
# Stream: 43, user_count: 12, avg_reward@stream: 1.33, avg_reward: 0.63, hr10: 1.231, regret: 8.667, coverage: 0.385, diversity: 1.0, batch_value_loss: 0.924
# Stream: 44, user_count: 126, avg_reward@stream: 1.24, avg_reward: 0.64, hr10: 0.722, regret: 8.762, coverage: 0.079, diversity: 1.0, batch_value_loss: 1.406
# Stream: 45, user_count: 8, avg_reward@stream: 1.25, avg_reward: 0.64, hr10: 1.0, regret: 8.75, coverage: 1.0, diversity: 1.0, batch_value_loss: 1.271
# Stream: 46, user_count: 645, avg_reward@stream: 0.57, avg_reward: 0.64, hr10: 0.42, regret: 9.429, coverage: 0.031, diversity: 1.0, batch_value_loss: 1.367
# Stream: 47, user_count: 698, avg_reward@stream: 0.34, avg_reward: 0.61, hr10: 0.259, regret: 9.66, coverage: 0.033, diversity: 1.0, batch_value_loss: 1.364
# Stream: 48, user_count: 107, avg_reward@stream: 0.97, avg_reward: 0.62, hr10: 0.418, regret: 9.028, coverage: 0.08, diversity: 0.927, batch_value_loss: 3.989
# Stream: 49, user_count: 2, avg_reward@stream: 1.0, avg_reward: 0.62, hr10: 1.0, regret: 9.0, coverage: 0.5, diversity: 1.0, batch_value_loss: 4.183
# Stream: 50, user_count: 29, avg_reward@stream: 0.79, avg_reward: 0.62, hr10: 0.793, regret: 9.207, coverage: 0.414, diversity: 1.0, batch_value_loss: 4.745
# Stream: 51, user_count: 6, avg_reward@stream: 1.0, avg_reward: 0.62, hr10: 1.0, regret: 9.0, coverage: 0.167, diversity: 1.0, batch_value_loss: 5.112
# Stream: 52, user_count: 15, avg_reward@stream: 1.0, avg_reward: 0.62, hr10: 1.0, regret: 9.0, coverage: 0.067, diversity: 1.0, batch_value_loss: 4.183
# Stream: 53, user_count: 5, avg_reward@stream: 1.0, avg_reward: 0.62, hr10: 1.0, regret: 9.0, coverage: 0.4, diversity: 1.0, batch_value_loss: 4.804
# Stream: 54, user_count: 20, avg_reward@stream: 0.65, avg_reward: 0.62, hr10: 0.5, regret: 9.35, coverage: 0.385, diversity: 1.0, batch_value_loss: 8.474
# Stream: 55, user_count: 226, avg_reward@stream: 0.94, avg_reward: 0.63, hr10: 0.445, regret: 9.062, coverage: 0.065, diversity: 1.0, batch_value_loss: 7.336
# Stream: 56, user_count: 18, avg_reward@stream: 1.0, avg_reward: 0.63, hr10: 0.9, regret: 9.0, coverage: 0.45, diversity: 1.0, batch_value_loss: 5.331
# Stream: 57, user_count: 36, avg_reward@stream: 0.42, avg_reward: 0.63, hr10: 0.288, regret: 9.583, coverage: 0.192, diversity: 1.0, batch_value_loss: 7.199
# Stream: 58, user_count: 41, avg_reward@stream: 0.34, avg_reward: 0.63, hr10: 0.237, regret: 9.659, coverage: 0.203, diversity: 0.84, batch_value_loss: 7.251
# Stream: 59, user_count: 52, avg_reward@stream: 0.63, avg_reward: 0.63, hr10: 0.623, regret: 9.365, coverage: 0.208, diversity: 1.0, batch_value_loss: 6.485
# Stream: 60, user_count: 7, avg_reward@stream: 1.29, avg_reward: 0.63, hr10: 1.125, regret: 8.714, coverage: 1.0, diversity: 1.0, batch_value_loss: 5.87
# Stream: 61, user_count: 43, avg_reward@stream: 0.47, avg_reward: 0.63, hr10: 0.465, regret: 9.535, coverage: 0.279, diversity: 1.0, batch_value_loss: 7.414
# Stream: 62, user_count: 33, avg_reward@stream: 0.91, avg_reward: 0.63, hr10: 0.909, regret: 9.091, coverage: 0.333, diversity: 1.0, batch_value_loss: 5.999
# Stream: 63, user_count: 46, avg_reward@stream: 1.0, avg_reward: 0.63, hr10: 0.92, regret: 9.0, coverage: 0.2, diversity: 1.0, batch_value_loss: 9.444
# Stream: 64, user_count: 2, avg_reward@stream: 1.0, avg_reward: 0.63, hr10: 1.0, regret: 9.0, coverage: 0.5, diversity: 1.0, batch_value_loss: 6.521
# Stream: 65, user_count: 45, avg_reward@stream: 0.93, avg_reward: 0.63, hr10: 0.933, regret: 9.067, coverage: 0.244, diversity: 1.0, batch_value_loss: 9.213
# Stream: 66, user_count: 15, avg_reward@stream: 0.67, avg_reward: 0.63, hr10: 0.588, regret: 9.333, coverage: 0.529, diversity: 1.0, batch_value_loss: 7.778
# Stream: 67, user_count: 86, avg_reward@stream: 0.58, avg_reward: 0.63, hr10: 0.549, regret: 9.419, coverage: 0.143, diversity: 1.0, batch_value_loss: 9.159
# Stream: 68, user_count: 33, avg_reward@stream: 1.0, avg_reward: 0.63, hr10: 1.0, regret: 9.0, coverage: 0.182, diversity: 1.0, batch_value_loss: 10.944
# Stream: 69, user_count: 71, avg_reward@stream: 1.44, avg_reward: 0.64, hr10: 0.879, regret: 8.563, coverage: 0.112, diversity: 1.0, batch_value_loss: 10.597
# Stream: 70, user_count: 10, avg_reward@stream: 1.4, avg_reward: 0.64, hr10: 1.167, regret: 8.6, coverage: 0.833, diversity: 1.0, batch_value_loss: 7.184
# Stream: 71, user_count: 20, avg_reward@stream: 0.75, avg_reward: 0.64, hr10: 0.6, regret: 9.25, coverage: 0.36, diversity: 0.9, batch_value_loss: 18.559
# Stream: 72, user_count: 24, avg_reward@stream: 1.21, avg_reward: 0.64, hr10: 0.69, regret: 8.792, coverage: 0.333, diversity: 0.947, batch_value_loss: 10.597
# Stream: 73, user_count: 19, avg_reward@stream: 1.0, avg_reward: 0.64, hr10: 0.576, regret: 9.0, coverage: 0.364, diversity: 0.905, batch_value_loss: 12.581
# Stream: 74, user_count: 45, avg_reward@stream: 1.82, avg_reward: 0.64, hr10: 1.0, regret: 8.178, coverage: 0.159, diversity: 1.0, batch_value_loss: 11.512
# Stream: 75, user_count: 85, avg_reward@stream: 1.38, avg_reward: 0.65, hr10: 0.867, regret: 8.624, coverage: 0.104, diversity: 1.0, batch_value_loss: 9.653
# Stream: 76, user_count: 21, avg_reward@stream: 1.0, avg_reward: 0.65, hr10: 0.553, regret: 9.0, coverage: 0.447, diversity: 0.897, batch_value_loss: 8.128
# Stream: 77, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.65, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 11.467
# Stream: 78, user_count: 12, avg_reward@stream: 1.0, avg_reward: 0.65, hr10: 1.0, regret: 9.0, coverage: 0.083, diversity: 1.0, batch_value_loss: 16.834
# Stream: 79, user_count: 32, avg_reward@stream: 1.38, avg_reward: 0.65, hr10: 0.677, regret: 8.625, coverage: 0.231, diversity: 0.923, batch_value_loss: 12.718
# Stream: 80, user_count: 24, avg_reward@stream: 1.83, avg_reward: 0.66, hr10: 1.333, regret: 8.167, coverage: 0.242, diversity: 1.0, batch_value_loss: 12.576
# Stream: 81, user_count: 24, avg_reward@stream: 1.12, avg_reward: 0.66, hr10: 0.675, regret: 8.875, coverage: 0.325, diversity: 1.0, batch_value_loss: 13.671
# Stream: 82, user_count: 8, avg_reward@stream: 1.12, avg_reward: 0.66, hr10: 1.0, regret: 8.875, coverage: 0.444, diversity: 1.0, batch_value_loss: 11.445
# Stream: 83, user_count: 51, avg_reward@stream: 0.76, avg_reward: 0.66, hr10: 0.429, regret: 9.235, coverage: 0.198, diversity: 1.0, batch_value_loss: 12.053
# Stream: 84, user_count: 15, avg_reward@stream: 1.27, avg_reward: 0.66, hr10: 1.188, regret: 8.733, coverage: 0.562, diversity: 1.0, batch_value_loss: 18.272
# Stream: 85, user_count: 5, avg_reward@stream: 2.4, avg_reward: 0.66, hr10: 2.0, regret: 7.6, coverage: 0.833, diversity: 1.0, batch_value_loss: 10.923
# Stream: 86, user_count: 6, avg_reward@stream: 2.17, avg_reward: 0.66, hr10: 1.3, regret: 7.833, coverage: 0.5, diversity: 1.0, batch_value_loss: 10.23
# Stream: 87, user_count: 8, avg_reward@stream: 1.38, avg_reward: 0.66, hr10: 1.222, regret: 8.625, coverage: 0.667, diversity: 1.0, batch_value_loss: 18.282
# Stream: 88, user_count: 2, avg_reward@stream: 1.5, avg_reward: 0.66, hr10: 1.5, regret: 8.5, coverage: 1.0, diversity: 1.0, batch_value_loss: 8.47
# Stream: 89, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.66, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 9.969
# Stream: 90, user_count: 36, avg_reward@stream: 1.75, avg_reward: 0.67, hr10: 1.312, regret: 8.25, coverage: 0.188, diversity: 1.0, batch_value_loss: 15.531
# Stream: 91, user_count: 18, avg_reward@stream: 2.11, avg_reward: 0.67, hr10: 1.652, regret: 7.889, coverage: 0.435, diversity: 1.0, batch_value_loss: 19.638
# Stream: 92, user_count: 42, avg_reward@stream: 1.38, avg_reward: 0.67, hr10: 0.753, regret: 8.619, coverage: 0.234, diversity: 1.0, batch_value_loss: 23.614
# Stream: 93, user_count: 101, avg_reward@stream: 0.85, avg_reward: 0.67, hr10: 0.272, regret: 9.149, coverage: 0.082, diversity: 0.872, batch_value_loss: 17.159
# Stream: 94, user_count: 58, avg_reward@stream: 0.33, avg_reward: 0.67, hr10: 0.209, regret: 9.672, coverage: 0.176, diversity: 0.862, batch_value_loss: 17.842
# Stream: 95, user_count: 37, avg_reward@stream: 1.54, avg_reward: 0.67, hr10: 1.163, regret: 8.459, coverage: 0.204, diversity: 1.0, batch_value_loss: 16.177
# Stream: 96, user_count: 9, avg_reward@stream: 1.89, avg_reward: 0.68, hr10: 1.417, regret: 8.111, coverage: 0.583, diversity: 1.0, batch_value_loss: 21.703
# Stream: 97, user_count: 13, avg_reward@stream: 1.92, avg_reward: 0.68, hr10: 1.316, regret: 8.077, coverage: 0.526, diversity: 1.0, batch_value_loss: 28.411
# Stream: 98, user_count: 26, avg_reward@stream: 1.69, avg_reward: 0.68, hr10: 1.222, regret: 8.308, coverage: 0.306, diversity: 1.0, batch_value_loss: 17.865
# Stream: 99, user_count: 55, avg_reward@stream: 1.85, avg_reward: 0.69, hr10: 1.186, regret: 8.145, coverage: 0.151, diversity: 1.0, batch_value_loss: 18.106
# Stream: 100, user_count: 3, avg_reward@stream: 1.0, avg_reward: 0.69, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 24.456
# Stream: 101, user_count: 13, avg_reward@stream: 1.69, avg_reward: 0.69, hr10: 1.222, regret: 8.308, coverage: 0.389, diversity: 1.0, batch_value_loss: 30.445
# Stream: 102, user_count: 13, avg_reward@stream: 0.85, avg_reward: 0.69, hr10: 0.55, regret: 9.154, coverage: 0.45, diversity: 0.867, batch_value_loss: 21.522
# Stream: 103, user_count: 126, avg_reward@stream: 1.25, avg_reward: 0.69, hr10: 0.767, regret: 8.746, coverage: 0.068, diversity: 1.0, batch_value_loss: 26.41
# Stream: 104, user_count: 37, avg_reward@stream: 1.41, avg_reward: 0.7, hr10: 0.852, regret: 8.595, coverage: 0.213, diversity: 1.0, batch_value_loss: 32.427
# Stream: 105, user_count: 42, avg_reward@stream: 1.43, avg_reward: 0.7, hr10: 0.909, regret: 8.571, coverage: 0.182, diversity: 1.0, batch_value_loss: 25.776
# Stream: 106, user_count: 56, avg_reward@stream: 1.32, avg_reward: 0.7, hr10: 0.632, regret: 8.679, coverage: 0.128, diversity: 1.0, batch_value_loss: 29.501
# Stream: 107, user_count: 21, avg_reward@stream: 1.86, avg_reward: 0.7, hr10: 1.0, regret: 8.143, coverage: 0.308, diversity: 1.0, batch_value_loss: 26.874
# Stream: 108, user_count: 17, avg_reward@stream: 1.76, avg_reward: 0.71, hr10: 1.071, regret: 8.235, coverage: 0.357, diversity: 1.0, batch_value_loss: 26.67
# Stream: 109, user_count: 58, avg_reward@stream: 1.19, avg_reward: 0.71, hr10: 0.605, regret: 8.81, coverage: 0.14, diversity: 1.0, batch_value_loss: 31.779
# Stream: 110, user_count: 30, avg_reward@stream: 1.1, avg_reward: 0.71, hr10: 0.767, regret: 8.9, coverage: 0.372, diversity: 0.87, batch_value_loss: 25.499
# Stream: 111, user_count: 13, avg_reward@stream: 1.46, avg_reward: 0.71, hr10: 0.792, regret: 8.538, coverage: 0.458, diversity: 0.882, batch_value_loss: 34.532
# Stream: 112, user_count: 34, avg_reward@stream: 0.85, avg_reward: 0.71, hr10: 0.439, regret: 9.147, coverage: 0.197, diversity: 0.871, batch_value_loss: 31.709
# Stream: 113, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.71, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 20.162
# Stream: 114, user_count: 117, avg_reward@stream: 0.9, avg_reward: 0.71, hr10: 0.412, regret: 9.103, coverage: 0.094, diversity: 0.891, batch_value_loss: 30.793
# Stream: 115, user_count: 193, avg_reward@stream: 0.52, avg_reward: 0.71, hr10: 0.333, regret: 9.482, coverage: 0.067, diversity: 1.0, batch_value_loss: 27.136
# Stream: 116, user_count: 16, avg_reward@stream: 1.56, avg_reward: 0.71, hr10: 1.19, regret: 8.438, coverage: 0.381, diversity: 1.0, batch_value_loss: 30.787
# Stream: 117, user_count: 11, avg_reward@stream: 1.64, avg_reward: 0.71, hr10: 1.2, regret: 8.364, coverage: 0.6, diversity: 1.0, batch_value_loss: 32.235
# Stream: 118, user_count: 118, avg_reward@stream: 0.92, avg_reward: 0.71, hr10: 0.46, regret: 9.085, coverage: 0.094, diversity: 1.0, batch_value_loss: 34.732
# Stream: 119, user_count: 47, avg_reward@stream: 1.45, avg_reward: 0.72, hr10: 0.919, regret: 8.553, coverage: 0.149, diversity: 1.0, batch_value_loss: 32.555
# Stream: 120, user_count: 48, avg_reward@stream: 0.69, avg_reward: 0.72, hr10: 0.579, regret: 9.312, coverage: 0.263, diversity: 0.895, batch_value_loss: 35.355
# Stream: 121, user_count: 48, avg_reward@stream: 0.92, avg_reward: 0.72, hr10: 0.603, regret: 9.083, coverage: 0.192, diversity: 1.0, batch_value_loss: 40.367
# Stream: 122, user_count: 11, avg_reward@stream: 1.27, avg_reward: 0.72, hr10: 1.0, regret: 8.727, coverage: 0.5, diversity: 1.0, batch_value_loss: 39.994
# Stream: 123, user_count: 25, avg_reward@stream: 1.12, avg_reward: 0.72, hr10: 0.824, regret: 8.88, coverage: 0.382, diversity: 1.0, batch_value_loss: 55.606
# Stream: 124, user_count: 23, avg_reward@stream: 1.61, avg_reward: 0.72, hr10: 1.088, regret: 8.391, coverage: 0.206, diversity: 1.0, batch_value_loss: 50.095
# Stream: 125, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.72, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 42.833
# Stream: 126, user_count: 41, avg_reward@stream: 1.41, avg_reward: 0.72, hr10: 0.921, regret: 8.585, coverage: 0.19, diversity: 1.0, batch_value_loss: 50.259
# Stream: 127, user_count: 39, avg_reward@stream: 1.51, avg_reward: 0.72, hr10: 0.894, regret: 8.487, coverage: 0.242, diversity: 1.0, batch_value_loss: 47.461
# Stream: 128, user_count: 22, avg_reward@stream: 1.36, avg_reward: 0.73, hr10: 0.811, regret: 8.636, coverage: 0.351, diversity: 1.0, batch_value_loss: 66.438
# Stream: 129, user_count: 11, avg_reward@stream: 1.0, avg_reward: 0.73, hr10: 0.917, regret: 9.0, coverage: 0.083, diversity: 1.0, batch_value_loss: 85.323
# Stream: 130, user_count: 25, avg_reward@stream: 1.56, avg_reward: 0.73, hr10: 0.736, regret: 8.44, coverage: 0.208, diversity: 1.0, batch_value_loss: 61.838
# Stream: 131, user_count: 152, avg_reward@stream: 1.51, avg_reward: 0.74, hr10: 0.845, regret: 8.493, coverage: 0.059, diversity: 1.0, batch_value_loss: 50.467
# Stream: 132, user_count: 1539, avg_reward@stream: 0.79, avg_reward: 0.74, hr10: 0.104, regret: 9.209, coverage: 0.008, diversity: 1.0, batch_value_loss: 60.852
# Stream: 133, user_count: 402, avg_reward@stream: 0.34, avg_reward: 0.73, hr10: 0.265, regret: 9.662, coverage: 0.056, diversity: 1.0, batch_value_loss: 114.636
# Stream: 134, user_count: 16, avg_reward@stream: 1.75, avg_reward: 0.73, hr10: 1.273, regret: 8.25, coverage: 0.5, diversity: 1.0, batch_value_loss: 135.441
# Stream: 135, user_count: 74, avg_reward@stream: 1.51, avg_reward: 0.74, hr10: 1.131, regret: 8.486, coverage: 0.081, diversity: 1.0, batch_value_loss: 168.28
# Stream: 136, user_count: 11, avg_reward@stream: 1.91, avg_reward: 0.74, hr10: 1.312, regret: 8.091, coverage: 0.5, diversity: 1.0, batch_value_loss: 183.628
# Stream: 137, user_count: 17, avg_reward@stream: 0.76, avg_reward: 0.74, hr10: 0.448, regret: 9.235, coverage: 0.31, diversity: 1.0, batch_value_loss: 205.933
# Stream: 138, user_count: 497, avg_reward@stream: 0.35, avg_reward: 0.73, hr10: 0.143, regret: 9.646, coverage: 0.027, diversity: 1.0, batch_value_loss: 189.718
# Stream: 139, user_count: 7, avg_reward@stream: 1.29, avg_reward: 0.73, hr10: 0.9, regret: 8.714, coverage: 0.7, diversity: 1.0, batch_value_loss: 190.649
# Stream: 140, user_count: 49, avg_reward@stream: 0.8, avg_reward: 0.73, hr10: 0.65, regret: 9.204, coverage: 0.267, diversity: 1.0, batch_value_loss: 249.562
# Stream: 141, user_count: 5, avg_reward@stream: 1.0, avg_reward: 0.73, hr10: 0.833, regret: 9.0, coverage: 0.667, diversity: 1.0, batch_value_loss: 257.613
# Stream: 142, user_count: 28, avg_reward@stream: 1.68, avg_reward: 0.73, hr10: 0.979, regret: 8.321, coverage: 0.25, diversity: 1.0, batch_value_loss: 245.483
# Stream: 143, user_count: 94, avg_reward@stream: 1.65, avg_reward: 0.73, hr10: 1.047, regret: 8.351, coverage: 0.034, diversity: 1.0, batch_value_loss: 302.585
# Stream: 144, user_count: 81, avg_reward@stream: 1.02, avg_reward: 0.74, hr10: 0.624, regret: 8.975, coverage: 0.135, diversity: 1.0, batch_value_loss: 427.368
# Stream: 145, user_count: 1, avg_reward@stream: 1.0, avg_reward: 0.74, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 159.137
# Stream: 146, user_count: 4, avg_reward@stream: 1.25, avg_reward: 0.74, hr10: 1.25, regret: 8.75, coverage: 1.0, diversity: 1.0, batch_value_loss: 296.692
# Stream: 147, user_count: 18, avg_reward@stream: 0.78, avg_reward: 0.74, hr10: 0.609, regret: 9.222, coverage: 0.478, diversity: 1.0, batch_value_loss: 375.104
# Stream: 148, user_count: 10, avg_reward@stream: 1.7, avg_reward: 0.74, hr10: 1.133, regret: 8.3, coverage: 0.267, diversity: 1.0, batch_value_loss: 503.414
# Stream: 149, user_count: 24, avg_reward@stream: 1.25, avg_reward: 0.74, hr10: 0.698, regret: 8.75, coverage: 0.326, diversity: 1.0, batch_value_loss: 380.476
# Stream: 150, user_count: 14, avg_reward@stream: 2.21, avg_reward: 0.74, hr10: 1.069, regret: 7.786, coverage: 0.414, diversity: 1.0, batch_value_loss: 498.987
# Stream: 151, user_count: 24, avg_reward@stream: 1.33, avg_reward: 0.74, hr10: 0.744, regret: 8.667, coverage: 0.395, diversity: 1.0, batch_value_loss: 421.299
# Stream: 152, user_count: 7, avg_reward@stream: 2.57, avg_reward: 0.74, hr10: 1.636, regret: 7.429, coverage: 0.818, diversity: 1.0, batch_value_loss: 389.757
# Stream: 153, user_count: 289, avg_reward@stream: 0.73, avg_reward: 0.74, hr10: 0.58, regret: 9.27, coverage: 0.052, diversity: 1.0, batch_value_loss: 475.468
# Stream: 154, user_count: 52, avg_reward@stream: 0.94, avg_reward: 0.74, hr10: 0.671, regret: 9.058, coverage: 0.26, diversity: 1.0, batch_value_loss: 578.095
# Stream: 155, user_count: 119, avg_reward@stream: 0.5, avg_reward: 0.74, hr10: 0.437, regret: 9.504, coverage: 0.133, diversity: 1.0, batch_value_loss: 506.059
# Stream: 156, user_count: 22, avg_reward@stream: 1.0, avg_reward: 0.74, hr10: 0.88, regret: 9.0, coverage: 0.08, diversity: 1.0, batch_value_loss: 698.651
# Stream: 157, user_count: 33, avg_reward@stream: 0.58, avg_reward: 0.74, hr10: 0.413, regret: 9.424, coverage: 0.261, diversity: 0.968, batch_value_loss: 557.014
# Stream: 158, user_count: 13, avg_reward@stream: 0.92, avg_reward: 0.74, hr10: 0.706, regret: 9.077, coverage: 0.647, diversity: 1.0, batch_value_loss: 607.658
# Stream: 159, user_count: 7, avg_reward@stream: 1.0, avg_reward: 0.74, hr10: 1.0, regret: 9.0, coverage: 0.143, diversity: 1.0, batch_value_loss: 483.861
# Stream: 160, user_count: 10, avg_reward@stream: 0.6, avg_reward: 0.74, hr10: 0.3, regret: 9.4, coverage: 0.25, diversity: 1.0, batch_value_loss: 523.736
# Stream: 161, user_count: 34, avg_reward@stream: 0.91, avg_reward: 0.74, hr10: 0.585, regret: 9.088, coverage: 0.208, diversity: 1.0, batch_value_loss: 721.445
# Stream: 162, user_count: 97, avg_reward@stream: 0.9, avg_reward: 0.74, hr10: 0.509, regret: 9.103, coverage: 0.117, diversity: 1.0, batch_value_loss: 798.679
# Stream: 163, user_count: 19, avg_reward@stream: 1.0, avg_reward: 0.74, hr10: 0.704, regret: 9.0, coverage: 0.444, diversity: 1.0, batch_value_loss: 638.304
# Stream: 164, user_count: 19, avg_reward@stream: 0.63, avg_reward: 0.74, hr10: 0.522, regret: 9.368, coverage: 0.391, diversity: 1.0, batch_value_loss: 743.974
# Stream: 165, user_count: 35, avg_reward@stream: 1.0, avg_reward: 0.74, hr10: 0.714, regret: 9.0, coverage: 0.02, diversity: 1.0, batch_value_loss: 695.497
# Stream: 166, user_count: 5, avg_reward@stream: 1.2, avg_reward: 0.74, hr10: 1.0, regret: 8.8, coverage: 0.667, diversity: 1.0, batch_value_loss: 532.568
# Stream: 167, user_count: 29, avg_reward@stream: 1.93, avg_reward: 0.74, hr10: 1.018, regret: 8.069, coverage: 0.182, diversity: 1.0, batch_value_loss: 627.385
# Stream: 168, user_count: 125, avg_reward@stream: 1.05, avg_reward: 0.75, hr10: 0.91, regret: 8.952, coverage: 0.076, diversity: 1.0, batch_value_loss: 812.84
# Stream: 169, user_count: 17, avg_reward@stream: 1.65, avg_reward: 0.75, hr10: 1.077, regret: 8.353, coverage: 0.269, diversity: 1.0, batch_value_loss: 1046.825
# Stream: 170, user_count: 251, avg_reward@stream: 0.82, avg_reward: 0.75, hr10: 0.526, regret: 9.183, coverage: 0.072, diversity: 1.0, batch_value_loss: 987.936
# Stream: 171, user_count: 21, avg_reward@stream: 1.38, avg_reward: 0.75, hr10: 1.036, regret: 8.619, coverage: 0.286, diversity: 1.0, batch_value_loss: 895.822
# Stream: 172, user_count: 7, avg_reward@stream: 1.43, avg_reward: 0.75, hr10: 0.769, regret: 8.571, coverage: 0.769, diversity: 1.0, batch_value_loss: 1048.38
# Stream: 173, user_count: 24, avg_reward@stream: 1.54, avg_reward: 0.75, hr10: 0.86, regret: 8.458, coverage: 0.279, diversity: 1.0, batch_value_loss: 1296.339
# Stream: 174, user_count: 84, avg_reward@stream: 0.98, avg_reward: 0.75, hr10: 0.599, regret: 9.024, coverage: 0.161, diversity: 1.0, batch_value_loss: 1099.672
# Stream: 175, user_count: 4, avg_reward@stream: 1.25, avg_reward: 0.75, hr10: 1.0, regret: 8.75, coverage: 1.0, diversity: 1.0, batch_value_loss: 971.903
# Stream: 176, user_count: 69, avg_reward@stream: 1.55, avg_reward: 0.75, hr10: 0.877, regret: 8.449, coverage: 0.172, diversity: 1.0, batch_value_loss: 1320.381
# Stream: 177, user_count: 20, avg_reward@stream: 1.8, avg_reward: 0.76, hr10: 1.125, regret: 8.2, coverage: 0.25, diversity: 1.0, batch_value_loss: 954.13
# Stream: 178, user_count: 9, avg_reward@stream: 1.33, avg_reward: 0.76, hr10: 1.0, regret: 8.667, coverage: 0.5, diversity: 1.0, batch_value_loss: 966.124
# Stream: 179, user_count: 61, avg_reward@stream: 0.61, avg_reward: 0.76, hr10: 0.481, regret: 9.393, coverage: 0.338, diversity: 0.981, batch_value_loss: 1425.751
# Stream: 180, user_count: 37, avg_reward@stream: 1.0, avg_reward: 0.76, hr10: 0.822, regret: 9.0, coverage: 0.022, diversity: 1.0, batch_value_loss: 1381.544
# Stream: 181, user_count: 21, avg_reward@stream: 1.57, avg_reward: 0.76, hr10: 1.031, regret: 8.429, coverage: 0.281, diversity: 1.0, batch_value_loss: 1216.571
# Stream: 182, user_count: 7, avg_reward@stream: 1.57, avg_reward: 0.76, hr10: 1.222, regret: 8.429, coverage: 0.667, diversity: 1.0, batch_value_loss: 1254.015
# Stream: 183, user_count: 19, avg_reward@stream: 1.79, avg_reward: 0.76, hr10: 1.214, regret: 8.211, coverage: 0.321, diversity: 1.0, batch_value_loss: 1215.638
# Stream: 184, user_count: 2637, avg_reward@stream: 0.34, avg_reward: 0.7, hr10: 0.142, regret: 9.661, coverage: 0.011, diversity: 1.0, batch_value_loss: 2623.206
# Stream: 185, user_count: 135, avg_reward@stream: 0.18, avg_reward: 0.7, hr10: 0.14, regret: 9.822, coverage: 0.099, diversity: 1.0, batch_value_loss: 4730.575
# Stream: 186, user_count: 47, avg_reward@stream: 2.0, avg_reward: 0.7, hr10: 1.382, regret: 8.0, coverage: 0.162, diversity: 1.0, batch_value_loss: 5357.774
# Stream: 187, user_count: 57, avg_reward@stream: 0.54, avg_reward: 0.7, hr10: 0.279, regret: 9.456, coverage: 0.144, diversity: 1.0, batch_value_loss: 5945.693
# Stream: 188, user_count: 12, avg_reward@stream: 1.42, avg_reward: 0.7, hr10: 0.895, regret: 8.583, coverage: 0.368, diversity: 1.0, batch_value_loss: 5395.243
# Stream: 189, user_count: 13, avg_reward@stream: 2.85, avg_reward: 0.7, hr10: 1.85, regret: 7.154, coverage: 0.7, diversity: 1.0, batch_value_loss: 6192.82
# Stream: 190, user_count: 4, avg_reward@stream: 1.25, avg_reward: 0.7, hr10: 1.0, regret: 8.75, coverage: 1.0, diversity: 1.0, batch_value_loss: 5240.101
# Stream: 191, user_count: 12, avg_reward@stream: 2.42, avg_reward: 0.7, hr10: 1.45, regret: 7.583, coverage: 0.5, diversity: 1.0, batch_value_loss: 6443.261
# Stream: 192, user_count: 32, avg_reward@stream: 2.09, avg_reward: 0.71, hr10: 1.396, regret: 7.906, coverage: 0.25, diversity: 1.0, batch_value_loss: 7586.496
# Stream: 193, user_count: 9, avg_reward@stream: 2.0, avg_reward: 0.71, hr10: 1.385, regret: 8.0, coverage: 0.462, diversity: 1.0, batch_value_loss: 5887.906
# Stream: 194, user_count: 5, avg_reward@stream: 1.0, avg_reward: 0.71, hr10: 1.0, regret: 9.0, coverage: 0.4, diversity: 1.0, batch_value_loss: 9576.305
# Stream: 195, user_count: 72, avg_reward@stream: 1.81, avg_reward: 0.71, hr10: 0.929, regret: 8.194, coverage: 0.1, diversity: 1.0, batch_value_loss: 7930.99
# Stream: 196, user_count: 30, avg_reward@stream: 1.97, avg_reward: 0.71, hr10: 1.157, regret: 8.033, coverage: 0.216, diversity: 1.0, batch_value_loss: 6711.144
# Stream: 197, user_count: 24, avg_reward@stream: 1.58, avg_reward: 0.71, hr10: 1.056, regret: 8.417, coverage: 0.333, diversity: 1.0, batch_value_loss: 9226.934
# Stream: 198, user_count: 103, avg_reward@stream: 1.17, avg_reward: 0.72, hr10: 0.642, regret: 8.835, coverage: 0.08, diversity: 1.0, batch_value_loss: 8665.982
# Stream: 199, user_count: 25, avg_reward@stream: 1.88, avg_reward: 0.72, hr10: 1.022, regret: 8.12, coverage: 0.261, diversity: 1.0, batch_value_loss: 8982.573
# Stream: 200, user_count: 55, avg_reward@stream: 1.98, avg_reward: 0.72, hr10: 1.09, regret: 8.018, coverage: 0.11, diversity: 1.0, batch_value_loss: 11401.836
# Stream: 201, user_count: 71, avg_reward@stream: 1.23, avg_reward: 0.72, hr10: 0.702, regret: 8.775, coverage: 0.129, diversity: 1.0, batch_value_loss: 10468.968
# Stream: 202, user_count: 11, avg_reward@stream: 1.55, avg_reward: 0.72, hr10: 1.214, regret: 8.455, coverage: 0.357, diversity: 1.0, batch_value_loss: 11097.266
# Stream: 203, user_count: 25, avg_reward@stream: 1.32, avg_reward: 0.72, hr10: 1.138, regret: 8.68, coverage: 0.207, diversity: 1.0, batch_value_loss: 12203.029
# Stream: 204, user_count: 10, avg_reward@stream: 1.5, avg_reward: 0.72, hr10: 1.071, regret: 8.5, coverage: 0.357, diversity: 1.0, batch_value_loss: 13135.133
# Stream: 205, user_count: 10, avg_reward@stream: 2.0, avg_reward: 0.72, hr10: 1.25, regret: 8.0, coverage: 0.375, diversity: 1.0, batch_value_loss: 12933.377
# Stream: 206, user_count: 17, avg_reward@stream: 1.06, avg_reward: 0.73, hr10: 1.0, regret: 8.941, coverage: 0.222, diversity: 1.0, batch_value_loss: 12146.926
# Stream: 207, user_count: 13, avg_reward@stream: 2.08, avg_reward: 0.73, hr10: 1.227, regret: 7.923, coverage: 0.364, diversity: 1.0, batch_value_loss: 10358.994
# Stream: 208, user_count: 14, avg_reward@stream: 1.36, avg_reward: 0.73, hr10: 1.118, regret: 8.643, coverage: 0.412, diversity: 1.0, batch_value_loss: 14095.956
# Stream: 209, user_count: 12, avg_reward@stream: 0.83, avg_reward: 0.73, hr10: 0.714, regret: 9.167, coverage: 0.714, diversity: 1.0, batch_value_loss: 10345.861
# Stream: 210, user_count: 33, avg_reward@stream: 1.82, avg_reward: 0.73, hr10: 0.968, regret: 8.182, coverage: 0.242, diversity: 1.0, batch_value_loss: 13920.05
# Stream: 211, user_count: 8, avg_reward@stream: 2.12, avg_reward: 0.73, hr10: 1.214, regret: 7.875, coverage: 0.786, diversity: 1.0, batch_value_loss: 11021.521
# Stream: 212, user_count: 97, avg_reward@stream: 1.36, avg_reward: 0.73, hr10: 0.579, regret: 8.639, coverage: 0.079, diversity: 1.0, batch_value_loss: 14869.576
# Stream: 213, user_count: 8, avg_reward@stream: 1.0, avg_reward: 0.73, hr10: 1.0, regret: 9.0, coverage: 0.5, diversity: 1.0, batch_value_loss: 15347.658
# Stream: 214, user_count: 57, avg_reward@stream: 0.84, avg_reward: 0.73, hr10: 0.632, regret: 9.158, coverage: 0.211, diversity: 1.0, batch_value_loss: 11997.714
# Stream: 215, user_count: 25, avg_reward@stream: 1.6, avg_reward: 0.73, hr10: 1.081, regret: 8.4, coverage: 0.297, diversity: 1.0, batch_value_loss: 14776.128
# Stream: 216, user_count: 7, avg_reward@stream: 1.29, avg_reward: 0.73, hr10: 1.125, regret: 8.714, coverage: 0.75, diversity: 1.0, batch_value_loss: 13857.695
# Stream: 217, user_count: 9, avg_reward@stream: 1.22, avg_reward: 0.73, hr10: 1.0, regret: 8.778, coverage: 0.545, diversity: 1.0, batch_value_loss: 17610.262
# Stream: 218, user_count: 67, avg_reward@stream: 2.25, avg_reward: 0.74, hr10: 1.606, regret: 7.746, coverage: 0.106, diversity: 1.0, batch_value_loss: 15030.035
# Stream: 219, user_count: 48, avg_reward@stream: 1.6, avg_reward: 0.74, hr10: 0.611, regret: 8.396, coverage: 0.127, diversity: 1.0, batch_value_loss: 14713.712
# Stream: 220, user_count: 34, avg_reward@stream: 0.68, avg_reward: 0.74, hr10: 0.426, regret: 9.324, coverage: 0.241, diversity: 1.0, batch_value_loss: 16857.075
# Stream: 221, user_count: 38, avg_reward@stream: 1.45, avg_reward: 0.74, hr10: 0.902, regret: 8.553, coverage: 0.197, diversity: 1.0, batch_value_loss: 15112.22
# Stream: 222, user_count: 68, avg_reward@stream: 0.57, avg_reward: 0.74, hr10: 0.375, regret: 9.426, coverage: 0.163, diversity: 1.0, batch_value_loss: 17433.34
# Stream: 223, user_count: 8, avg_reward@stream: 2.12, avg_reward: 0.74, hr10: 1.308, regret: 7.875, coverage: 0.692, diversity: 1.0, batch_value_loss: 15169.161
# Stream: 224, user_count: 3, avg_reward@stream: 1.0, avg_reward: 0.74, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 32916.854
# Stream: 225, user_count: 2, avg_reward@stream: 1.0, avg_reward: 0.74, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 26189.227
# Stream: 226, user_count: 7, avg_reward@stream: 1.29, avg_reward: 0.74, hr10: 1.0, regret: 8.714, coverage: 1.0, diversity: 1.0, batch_value_loss: 15124.208
# Stream: 227, user_count: 60, avg_reward@stream: 1.22, avg_reward: 0.74, hr10: 0.723, regret: 8.783, coverage: 0.218, diversity: 1.0, batch_value_loss: 19523.69
# Stream: 228, user_count: 2, avg_reward@stream: 1.0, avg_reward: 0.74, hr10: 0.667, regret: 9.0, coverage: 0.667, diversity: 1.0, batch_value_loss: 30371.406
# Stream: 229, user_count: 20, avg_reward@stream: 1.8, avg_reward: 0.74, hr10: 1.2, regret: 8.2, coverage: 0.5, diversity: 1.0, batch_value_loss: 13507.325
# Stream: 230, user_count: 41, avg_reward@stream: 0.83, avg_reward: 0.74, hr10: 0.472, regret: 9.171, coverage: 0.222, diversity: 1.0, batch_value_loss: 21630.053
# Stream: 231, user_count: 124, avg_reward@stream: 1.07, avg_reward: 0.75, hr10: 0.616, regret: 8.927, coverage: 0.074, diversity: 1.0, batch_value_loss: 19844.083
# Stream: 232, user_count: 13, avg_reward@stream: 1.46, avg_reward: 0.75, hr10: 1.056, regret: 8.538, coverage: 0.444, diversity: 1.0, batch_value_loss: 30146.55
# Stream: 233, user_count: 24, avg_reward@stream: 1.71, avg_reward: 0.75, hr10: 1.242, regret: 8.292, coverage: 0.303, diversity: 1.0, batch_value_loss: 24077.029
# Stream: 234, user_count: 84, avg_reward@stream: 1.25, avg_reward: 0.75, hr10: 0.597, regret: 8.75, coverage: 0.108, diversity: 1.0, batch_value_loss: 23448.717
# Stream: 235, user_count: 22, avg_reward@stream: 1.36, avg_reward: 0.75, hr10: 0.882, regret: 8.636, coverage: 0.382, diversity: 1.0, batch_value_loss: 30782.216
# Stream: 236, user_count: 35, avg_reward@stream: 2.06, avg_reward: 0.75, hr10: 1.385, regret: 7.943, coverage: 0.212, diversity: 1.0, batch_value_loss: 25609.475
# Stream: 237, user_count: 45, avg_reward@stream: 1.31, avg_reward: 0.75, hr10: 0.756, regret: 8.689, coverage: 0.179, diversity: 1.0, batch_value_loss: 24048.378
# Stream: 238, user_count: 39, avg_reward@stream: 1.64, avg_reward: 0.76, hr10: 0.901, regret: 8.359, coverage: 0.169, diversity: 1.0, batch_value_loss: 28489.41
# Stream: 239, user_count: 84, avg_reward@stream: 1.6, avg_reward: 0.76, hr10: 0.843, regret: 8.405, coverage: 0.082, diversity: 1.0, batch_value_loss: 24697.949
# Stream: 240, user_count: 10, avg_reward@stream: 1.7, avg_reward: 0.76, hr10: 1.133, regret: 8.3, coverage: 0.467, diversity: 1.0, batch_value_loss: 28964.941
# Stream: 241, user_count: 8, avg_reward@stream: 1.5, avg_reward: 0.76, hr10: 1.0, regret: 8.5, coverage: 0.333, diversity: 1.0, batch_value_loss: 33139.934
# Stream: 242, user_count: 10, avg_reward@stream: 1.6, avg_reward: 0.76, hr10: 1.0, regret: 8.4, coverage: 0.438, diversity: 1.0, batch_value_loss: 25981.537
# Stream: 243, user_count: 25, avg_reward@stream: 1.36, avg_reward: 0.76, hr10: 1.097, regret: 8.64, coverage: 0.226, diversity: 1.0, batch_value_loss: 22448.822
# Stream: 244, user_count: 6, avg_reward@stream: 1.5, avg_reward: 0.76, hr10: 1.0, regret: 8.5, coverage: 0.556, diversity: 1.0, batch_value_loss: 17426.788
# Stream: 245, user_count: 7, avg_reward@stream: 1.14, avg_reward: 0.76, hr10: 0.8, regret: 8.857, coverage: 0.3, diversity: 1.0, batch_value_loss: 26044.862
# Stream: 246, user_count: 90, avg_reward@stream: 0.78, avg_reward: 0.76, hr10: 0.389, regret: 9.222, coverage: 0.111, diversity: 1.0, batch_value_loss: 26546.581
# Stream: 247, user_count: 25, avg_reward@stream: 1.52, avg_reward: 0.76, hr10: 1.027, regret: 8.48, coverage: 0.216, diversity: 1.0, batch_value_loss: 32783.787
# Stream: 248, user_count: 25, avg_reward@stream: 1.28, avg_reward: 0.76, hr10: 1.0, regret: 8.72, coverage: 0.219, diversity: 1.0, batch_value_loss: 25853.56
# Stream: 249, user_count: 7, avg_reward@stream: 1.29, avg_reward: 0.76, hr10: 1.0, regret: 8.714, coverage: 0.556, diversity: 1.0, batch_value_loss: 43832.129
# Stream: 250, user_count: 10, avg_reward@stream: 1.7, avg_reward: 0.76, hr10: 1.133, regret: 8.3, coverage: 0.4, diversity: 1.0, batch_value_loss: 46372.488
# Stream: 251, user_count: 23, avg_reward@stream: 0.91, avg_reward: 0.76, hr10: 0.875, regret: 9.087, coverage: 0.417, diversity: 1.0, batch_value_loss: 29605.783
# Stream: 252, user_count: 28, avg_reward@stream: 1.86, avg_reward: 0.77, hr10: 0.963, regret: 8.143, coverage: 0.222, diversity: 1.0, batch_value_loss: 28515.989
# Stream: 253, user_count: 4, avg_reward@stream: 1.0, avg_reward: 0.77, hr10: 1.0, regret: 9.0, coverage: 0.75, diversity: 1.0, batch_value_loss: 18549.775
# Stream: 254, user_count: 64, avg_reward@stream: 1.3, avg_reward: 0.77, hr10: 0.748, regret: 8.703, coverage: 0.171, diversity: 1.0, batch_value_loss: 31395.352
# Stream: 255, user_count: 32, avg_reward@stream: 1.47, avg_reward: 0.77, hr10: 1.119, regret: 8.531, coverage: 0.19, diversity: 1.0, batch_value_loss: 27358.146
# Stream: 256, user_count: 1265, avg_reward@stream: 0.88, avg_reward: 0.77, hr10: 0.169, regret: 9.118, coverage: 0.014, diversity: 1.0, batch_value_loss: 38848.171
# Stream: 257, user_count: 14, avg_reward@stream: 1.57, avg_reward: 0.77, hr10: 1.467, regret: 8.429, coverage: 0.6, diversity: 1.0, batch_value_loss: 57283.21
# Stream: 258, user_count: 16, avg_reward@stream: 1.69, avg_reward: 0.78, hr10: 1.08, regret: 8.312, coverage: 0.32, diversity: 1.0, batch_value_loss: 63495.367
# Stream: 259, user_count: 28, avg_reward@stream: 0.54, avg_reward: 0.77, hr10: 0.357, regret: 9.464, coverage: 0.286, diversity: 1.0, batch_value_loss: 47849.286
# Stream: 260, user_count: 8, avg_reward@stream: 1.25, avg_reward: 0.78, hr10: 1.111, regret: 8.75, coverage: 0.667, diversity: 1.0, batch_value_loss: 34272.188
# Stream: 261, user_count: 122, avg_reward@stream: 1.26, avg_reward: 0.78, hr10: 0.616, regret: 8.738, coverage: 0.068, diversity: 1.0, batch_value_loss: 47022.025
# Stream: 262, user_count: 21, avg_reward@stream: 1.1, avg_reward: 0.78, hr10: 0.719, regret: 8.905, coverage: 0.375, diversity: 1.0, batch_value_loss: 58915.702
# Stream: 263, user_count: 34, avg_reward@stream: 0.85, avg_reward: 0.78, hr10: 0.569, regret: 9.147, coverage: 0.392, diversity: 1.0, batch_value_loss: 54602.901
# Stream: 264, user_count: 6, avg_reward@stream: 1.67, avg_reward: 0.78, hr10: 0.833, regret: 8.333, coverage: 0.5, diversity: 1.0, batch_value_loss: 70339.62
# Stream: 265, user_count: 23, avg_reward@stream: 1.74, avg_reward: 0.78, hr10: 0.952, regret: 8.261, coverage: 0.333, diversity: 1.0, batch_value_loss: 52162.853
# Stream: 266, user_count: 1335, avg_reward@stream: 0.89, avg_reward: 0.79, hr10: 0.225, regret: 9.112, coverage: 0.018, diversity: 1.0, batch_value_loss: 63954.619
# Stream: 267, user_count: 62, avg_reward@stream: 0.85, avg_reward: 0.79, hr10: 0.546, regret: 9.145, coverage: 0.237, diversity: 1.0, batch_value_loss: 83858.403
# Stream: 268, user_count: 29, avg_reward@stream: 1.28, avg_reward: 0.79, hr10: 0.974, regret: 8.724, coverage: 0.474, diversity: 1.0, batch_value_loss: 91629.948
# Stream: 269, user_count: 75, avg_reward@stream: 0.83, avg_reward: 0.79, hr10: 0.569, regret: 9.173, coverage: 0.294, diversity: 0.985, batch_value_loss: 89537.307
# Stream: 270, user_count: 16, avg_reward@stream: 1.75, avg_reward: 0.79, hr10: 1.474, regret: 8.25, coverage: 0.316, diversity: 1.0, batch_value_loss: 73976.273
# Stream: 271, user_count: 84, avg_reward@stream: 1.39, avg_reward: 0.79, hr10: 0.78, regret: 8.607, coverage: 0.113, diversity: 1.0, batch_value_loss: 91768.815
# Stream: 272, user_count: 24, avg_reward@stream: 1.75, avg_reward: 0.79, hr10: 1.135, regret: 8.25, coverage: 0.324, diversity: 1.0, batch_value_loss: 85251.339
# Stream: 273, user_count: 70, avg_reward@stream: 2.0, avg_reward: 0.79, hr10: 1.429, regret: 8.0, coverage: 0.133, diversity: 1.0, batch_value_loss: 98435.193
# Stream: 274, user_count: 13, avg_reward@stream: 2.31, avg_reward: 0.79, hr10: 1.579, regret: 7.692, coverage: 0.579, diversity: 1.0, batch_value_loss: 94669.202
# Stream: 275, user_count: 14, avg_reward@stream: 1.43, avg_reward: 0.79, hr10: 1.053, regret: 8.571, coverage: 0.158, diversity: 1.0, batch_value_loss: 85587.125
# Stream: 276, user_count: 48, avg_reward@stream: 1.1, avg_reward: 0.79, hr10: 0.381, regret: 8.896, coverage: 0.18, diversity: 1.0, batch_value_loss: 115601.75
# Stream: 277, user_count: 14, avg_reward@stream: 1.5, avg_reward: 0.8, hr10: 1.235, regret: 8.5, coverage: 0.412, diversity: 1.0, batch_value_loss: 126792.062
# Stream: 278, user_count: 159, avg_reward@stream: 1.6, avg_reward: 0.8, hr10: 1.204, regret: 8.403, coverage: 0.047, diversity: 1.0, batch_value_loss: 110240.126
# Stream: 279, user_count: 36, avg_reward@stream: 1.36, avg_reward: 0.8, hr10: 1.256, regret: 8.639, coverage: 0.154, diversity: 1.0, batch_value_loss: 112658.41
# Stream: 280, user_count: 4087, avg_reward@stream: 0.44, avg_reward: 0.75, hr10: 0.164, regret: 9.56, coverage: 0.005, diversity: 1.0, batch_value_loss: 206895.385
# Stream: 281, user_count: 77, avg_reward@stream: 1.6, avg_reward: 0.75, hr10: 1.367, regret: 8.403, coverage: 0.1, diversity: 1.0, batch_value_loss: 351795.351
# Stream: 282, user_count: 21, avg_reward@stream: 1.76, avg_reward: 0.75, hr10: 1.37, regret: 8.238, coverage: 0.296, diversity: 1.0, batch_value_loss: 358022.095
# Stream: 283, user_count: 4, avg_reward@stream: 1.0, avg_reward: 0.75, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 408300.031
# Stream: 284, user_count: 397, avg_reward@stream: 0.53, avg_reward: 0.75, hr10: 0.241, regret: 9.474, coverage: 0.036, diversity: 1.0, batch_value_loss: 406621.179
# Stream: 285, user_count: 10, avg_reward@stream: 0.6, avg_reward: 0.75, hr10: 0.3, regret: 9.4, coverage: 0.3, diversity: 1.0, batch_value_loss: 357631.8
# Stream: 286, user_count: 105, avg_reward@stream: 1.01, avg_reward: 0.75, hr10: 0.883, regret: 8.99, coverage: 0.017, diversity: 1.0, batch_value_loss: 435125.143
# Stream: 287, user_count: 42, avg_reward@stream: 0.29, avg_reward: 0.75, hr10: 0.218, regret: 9.714, coverage: 0.182, diversity: 1.0, batch_value_loss: 437919.762
# Stream: 288, user_count: 38, avg_reward@stream: 0.45, avg_reward: 0.75, hr10: 0.34, regret: 9.553, coverage: 0.26, diversity: 1.0, batch_value_loss: 431554.237
# Stream: 289, user_count: 8, avg_reward@stream: 1.5, avg_reward: 0.75, hr10: 1.2, regret: 8.5, coverage: 0.7, diversity: 1.0, batch_value_loss: 393541.219
# Stream: 290, user_count: 28, avg_reward@stream: 1.54, avg_reward: 0.75, hr10: 0.956, regret: 8.464, coverage: 0.267, diversity: 1.0, batch_value_loss: 478009.857
# Stream: 291, user_count: 3, avg_reward@stream: 1.0, avg_reward: 0.75, hr10: 1.0, regret: 9.0, coverage: 0.667, diversity: 1.0, batch_value_loss: 379700.75
# Stream: 292, user_count: 19, avg_reward@stream: 2.05, avg_reward: 0.75, hr10: 1.444, regret: 7.947, coverage: 0.407, diversity: 1.0, batch_value_loss: 461857.737
# Stream: 293, user_count: 29, avg_reward@stream: 1.76, avg_reward: 0.75, hr10: 1.0, regret: 8.241, coverage: 0.235, diversity: 1.0, batch_value_loss: 433251.379
# Stream: 294, user_count: 69, avg_reward@stream: 1.41, avg_reward: 0.75, hr10: 0.669, regret: 8.594, coverage: 0.159, diversity: 1.0, batch_value_loss: 541465.333
# Stream: 295, user_count: 45, avg_reward@stream: 1.58, avg_reward: 0.76, hr10: 1.315, regret: 8.422, coverage: 0.167, diversity: 1.0, batch_value_loss: 530775.422
# Stream: 296, user_count: 5, avg_reward@stream: 2.2, avg_reward: 0.76, hr10: 1.1, regret: 7.8, coverage: 0.6, diversity: 1.0, batch_value_loss: 490410.1
# Stream: 297, user_count: 761, avg_reward@stream: 0.41, avg_reward: 0.75, hr10: 0.282, regret: 9.591, coverage: 0.028, diversity: 1.0, batch_value_loss: 583339.311
# Stream: 298, user_count: 55, avg_reward@stream: 0.45, avg_reward: 0.75, hr10: 0.321, regret: 9.545, coverage: 0.231, diversity: 1.0, batch_value_loss: 781530.545
# Stream: 299, user_count: 19, avg_reward@stream: 1.42, avg_reward: 0.75, hr10: 1.0, regret: 8.579, coverage: 0.407, diversity: 1.0, batch_value_loss: 718840.316
# Stream: 300, user_count: 57, avg_reward@stream: 0.91, avg_reward: 0.75, hr10: 0.525, regret: 9.088, coverage: 0.192, diversity: 1.0, batch_value_loss: 629662.175
# Stream: 301, user_count: 13, avg_reward@stream: 1.54, avg_reward: 0.75, hr10: 1.333, regret: 8.462, coverage: 0.467, diversity: 1.0, batch_value_loss: 601767.615
# Stream: 302, user_count: 269, avg_reward@stream: 0.61, avg_reward: 0.75, hr10: 0.418, regret: 9.387, coverage: 0.084, diversity: 1.0, batch_value_loss: 724865.368
# Stream: 303, user_count: 13, avg_reward@stream: 0.92, avg_reward: 0.75, hr10: 0.857, regret: 9.077, coverage: 0.786, diversity: 1.0, batch_value_loss: 889538.231
# Stream: 304, user_count: 28, avg_reward@stream: 1.25, avg_reward: 0.75, hr10: 1.061, regret: 8.75, coverage: 0.182, diversity: 1.0, batch_value_loss: 798686.857
# ...
# Stream: 1414, user_count: 46, avg_reward@stream: 1.46, avg_reward: 1.03, hr10: 1.0, regret: 8.543, coverage: 0.164, diversity: 1.0, batch_value_loss: 1175952606.609
# Stream: 1415, user_count: 100, avg_reward@stream: 1.18, avg_reward: 1.03, hr10: 0.648, regret: 8.82, coverage: 0.099, diversity: 0.955, batch_value_loss: 1279441797.12
# Stream: 1416, user_count: 118, avg_reward@stream: 1.17, avg_reward: 1.03, hr10: 0.654, regret: 8.831, coverage: 0.081, diversity: 0.958, batch_value_loss: 1209341223.051
# Stream: 1417, user_count: 46, avg_reward@stream: 1.33, avg_reward: 1.03, hr10: 0.693, regret: 8.674, coverage: 0.17, diversity: 0.96, batch_value_loss: 1448891881.739
# Stream: 1418, user_count: 51, avg_reward@stream: 1.53, avg_reward: 1.03, hr10: 1.026, regret: 8.471, coverage: 0.211, diversity: 1.0, batch_value_loss: 1259111845.647
# Stream: 1419, user_count: 139, avg_reward@stream: 1.43, avg_reward: 1.03, hr10: 0.734, regret: 8.568, coverage: 0.059, diversity: 0.955, batch_value_loss: 1139969841.727
# Stream: 1420, user_count: 41, avg_reward@stream: 2.0, avg_reward: 1.03, hr10: 1.139, regret: 8.0, coverage: 0.194, diversity: 1.0, batch_value_loss: 1034593754.537
# Stream: 1421, user_count: 38, avg_reward@stream: 1.42, avg_reward: 1.03, hr10: 0.818, regret: 8.579, coverage: 0.227, diversity: 1.0, batch_value_loss: 1131210752.0
# Stream: 1422, user_count: 24, avg_reward@stream: 1.29, avg_reward: 1.03, hr10: 0.912, regret: 8.708, coverage: 0.412, diversity: 1.0, batch_value_loss: 1209593002.667
# Stream: 1423, user_count: 119, avg_reward@stream: 1.9, avg_reward: 1.03, hr10: 1.306, regret: 8.101, coverage: 0.058, diversity: 1.0, batch_value_loss: 1180509192.605
# Stream: 1424, user_count: 61, avg_reward@stream: 0.72, avg_reward: 1.03, hr10: 0.444, regret: 9.279, coverage: 0.182, diversity: 0.939, batch_value_loss: 1180108363.541
# Stream: 1425, user_count: 426, avg_reward@stream: 0.81, avg_reward: 1.03, hr10: 0.506, regret: 9.19, coverage: 0.026, diversity: 1.0, batch_value_loss: 1317029916.845
# Stream: 1426, user_count: 61, avg_reward@stream: 0.82, avg_reward: 1.03, hr10: 0.61, regret: 9.18, coverage: 0.268, diversity: 0.786, batch_value_loss: 1425305532.852
# Stream: 1427, user_count: 18, avg_reward@stream: 1.67, avg_reward: 1.03, hr10: 1.2, regret: 8.333, coverage: 0.56, diversity: 1.0, batch_value_loss: 1468623985.778
# Stream: 1428, user_count: 152, avg_reward@stream: 1.25, avg_reward: 1.03, hr10: 0.704, regret: 8.75, coverage: 0.063, diversity: 0.95, batch_value_loss: 1310695424.0
# Stream: 1429, user_count: 48, avg_reward@stream: 1.25, avg_reward: 1.03, hr10: 0.779, regret: 8.75, coverage: 0.169, diversity: 0.944, batch_value_loss: 1212911445.333
# Stream: 1430, user_count: 70, avg_reward@stream: 0.61, avg_reward: 1.03, hr10: 0.453, regret: 9.386, coverage: 0.147, diversity: 0.704, batch_value_loss: 1386025428.114
# Stream: 1431, user_count: 35, avg_reward@stream: 1.83, avg_reward: 1.03, hr10: 1.255, regret: 8.171, coverage: 0.353, diversity: 1.0, batch_value_loss: 1225594002.286
# Stream: 1432, user_count: 42, avg_reward@stream: 1.62, avg_reward: 1.03, hr10: 1.097, regret: 8.381, coverage: 0.274, diversity: 0.913, batch_value_loss: 1276053699.048
# Stream: 1433, user_count: 142, avg_reward@stream: 1.61, avg_reward: 1.03, hr10: 0.946, regret: 8.394, coverage: 0.091, diversity: 0.853, batch_value_loss: 1356936379.493
# Stream: 1434, user_count: 61, avg_reward@stream: 1.03, avg_reward: 1.03, hr10: 0.926, regret: 8.967, coverage: 0.029, diversity: 1.0, batch_value_loss: 1259284849.311
# Stream: 1435, user_count: 35, avg_reward@stream: 1.89, avg_reward: 1.03, hr10: 0.892, regret: 8.114, coverage: 0.23, diversity: 0.92, batch_value_loss: 1372450933.029
# Stream: 1436, user_count: 40, avg_reward@stream: 1.23, avg_reward: 1.03, hr10: 1.114, regret: 8.775, coverage: 0.114, diversity: 1.0, batch_value_loss: 1269419008.0
# Stream: 1437, user_count: 47, avg_reward@stream: 1.23, avg_reward: 1.03, hr10: 1.055, regret: 8.766, coverage: 0.091, diversity: 1.0, batch_value_loss: 1480316884.426
# Stream: 1438, user_count: 3, avg_reward@stream: 1.67, avg_reward: 1.03, hr10: 1.25, regret: 8.333, coverage: 0.75, diversity: 1.0, batch_value_loss: 1757312341.333
# Stream: 1439, user_count: 3, avg_reward@stream: 1.33, avg_reward: 1.03, hr10: 1.0, regret: 8.667, coverage: 0.75, diversity: 1.0, batch_value_loss: 1385779200.0
# Stream: 1440, user_count: 28, avg_reward@stream: 1.43, avg_reward: 1.03, hr10: 0.952, regret: 8.571, coverage: 0.31, diversity: 1.0, batch_value_loss: 1672582144.0
# Stream: 1441, user_count: 26, avg_reward@stream: 2.23, avg_reward: 1.03, hr10: 1.45, regret: 7.769, coverage: 0.2, diversity: 1.0, batch_value_loss: 1436144561.231
# Stream: 1442, user_count: 231, avg_reward@stream: 1.48, avg_reward: 1.03, hr10: 0.983, regret: 8.524, coverage: 0.049, diversity: 1.0, batch_value_loss: 1451938022.511
# Stream: 1443, user_count: 1610, avg_reward@stream: 0.84, avg_reward: 1.03, hr10: 0.113, regret: 9.161, coverage: 0.006, diversity: 0.896, batch_value_loss: 1308853160.229
# Stream: 1444, user_count: 123, avg_reward@stream: 1.48, avg_reward: 1.03, hr10: 0.768, regret: 8.52, coverage: 0.072, diversity: 1.0, batch_value_loss: 1401904419.382
# Stream: 1445, user_count: 14, avg_reward@stream: 1.86, avg_reward: 1.03, hr10: 1.444, regret: 8.143, coverage: 0.611, diversity: 1.0, batch_value_loss: 1253797010.286
# Stream: 1446, user_count: 86, avg_reward@stream: 1.21, avg_reward: 1.03, hr10: 0.782, regret: 8.791, coverage: 0.105, diversity: 1.0, batch_value_loss: 1410691643.535
# Stream: 1447, user_count: 13, avg_reward@stream: 3.08, avg_reward: 1.03, hr10: 2.105, regret: 6.923, coverage: 0.526, diversity: 1.0, batch_value_loss: 1380931268.923
# Stream: 1448, user_count: 67, avg_reward@stream: 1.09, avg_reward: 1.03, hr10: 0.51, regret: 8.91, coverage: 0.14, diversity: 0.923, batch_value_loss: 1225851124.537
# Stream: 1449, user_count: 42, avg_reward@stream: 1.48, avg_reward: 1.03, hr10: 0.827, regret: 8.524, coverage: 0.187, diversity: 1.0, batch_value_loss: 1442260211.81
# Stream: 1450, user_count: 27, avg_reward@stream: 2.3, avg_reward: 1.03, hr10: 1.265, regret: 7.704, coverage: 0.306, diversity: 0.947, batch_value_loss: 1506367412.148
# Stream: 1451, user_count: 36, avg_reward@stream: 1.92, avg_reward: 1.03, hr10: 0.958, regret: 8.083, coverage: 0.222, diversity: 0.958, batch_value_loss: 1592176753.778
# Stream: 1452, user_count: 111, avg_reward@stream: 1.34, avg_reward: 1.03, hr10: 0.687, regret: 8.658, coverage: 0.083, diversity: 1.0, batch_value_loss: 1427400648.649
# Stream: 1453, user_count: 12, avg_reward@stream: 2.0, avg_reward: 1.03, hr10: 0.96, regret: 8.0, coverage: 0.4, diversity: 1.0, batch_value_loss: 1469911722.667
# Stream: 1454, user_count: 14, avg_reward@stream: 2.07, avg_reward: 1.03, hr10: 0.967, regret: 7.929, coverage: 0.4, diversity: 1.0, batch_value_loss: 1227170962.286
# Stream: 1455, user_count: 37, avg_reward@stream: 1.22, avg_reward: 1.03, hr10: 0.763, regret: 8.784, coverage: 0.254, diversity: 0.913, batch_value_loss: 1508248050.162
# Stream: 1456, user_count: 14, avg_reward@stream: 1.21, avg_reward: 1.03, hr10: 0.708, regret: 8.786, coverage: 0.625, diversity: 1.0, batch_value_loss: 1357079113.143
# Stream: 1457, user_count: 14, avg_reward@stream: 1.36, avg_reward: 1.03, hr10: 0.826, regret: 8.643, coverage: 0.565, diversity: 0.938, batch_value_loss: 1896520996.571
# Stream: 1458, user_count: 188, avg_reward@stream: 0.44, avg_reward: 1.03, hr10: 0.347, regret: 9.564, coverage: 0.085, diversity: 1.0, batch_value_loss: 1566294190.298
# Stream: 1459, user_count: 89, avg_reward@stream: 0.64, avg_reward: 1.03, hr10: 0.38, regret: 9.36, coverage: 0.08, diversity: 1.0, batch_value_loss: 1469358724.315
# Stream: 1460, user_count: 28, avg_reward@stream: 0.89, avg_reward: 1.03, hr10: 0.568, regret: 9.107, coverage: 0.227, diversity: 0.95, batch_value_loss: 1782784585.143
# Stream: 1461, user_count: 24, avg_reward@stream: 1.62, avg_reward: 1.03, hr10: 1.219, regret: 8.375, coverage: 0.312, diversity: 1.0, batch_value_loss: 1391813632.0
# Stream: 1462, user_count: 114, avg_reward@stream: 1.92, avg_reward: 1.03, hr10: 1.296, regret: 8.079, coverage: 0.059, diversity: 1.0, batch_value_loss: 1407548865.123
# Stream: 1463, user_count: 46, avg_reward@stream: 1.26, avg_reward: 1.03, hr10: 0.674, regret: 8.739, coverage: 0.198, diversity: 1.0, batch_value_loss: 1519274251.13
# Stream: 1464, user_count: 9, avg_reward@stream: 1.11, avg_reward: 1.03, hr10: 1.111, regret: 8.889, coverage: 0.444, diversity: 1.0, batch_value_loss: 1765933624.889
# Stream: 1465, user_count: 12, avg_reward@stream: 1.42, avg_reward: 1.03, hr10: 1.0, regret: 8.583, coverage: 0.294, diversity: 1.0, batch_value_loss: 1781968725.333
# Stream: 1466, user_count: 47, avg_reward@stream: 0.55, avg_reward: 1.03, hr10: 0.426, regret: 9.447, coverage: 0.279, diversity: 0.837, batch_value_loss: 1543403302.128
# Stream: 1467, user_count: 628, avg_reward@stream: 1.22, avg_reward: 1.03, hr10: 0.551, regret: 8.783, coverage: 0.021, diversity: 1.0, batch_value_loss: 1570297973.401
# Stream: 1468, user_count: 48, avg_reward@stream: 2.15, avg_reward: 1.04, hr10: 1.226, regret: 7.854, coverage: 0.167, diversity: 0.889, batch_value_loss: 1526825813.333
# Stream: 1469, user_count: 23, avg_reward@stream: 1.7, avg_reward: 1.04, hr10: 1.3, regret: 8.304, coverage: 0.3, diversity: 1.0, batch_value_loss: 1857451230.609
# Stream: 1470, user_count: 8, avg_reward@stream: 1.5, avg_reward: 1.04, hr10: 1.2, regret: 8.5, coverage: 0.5, diversity: 1.0, batch_value_loss: 1918775040.0
# Stream: 1471, user_count: 125, avg_reward@stream: 1.21, avg_reward: 1.04, hr10: 0.778, regret: 8.792, coverage: 0.088, diversity: 0.955, batch_value_loss: 1787884863.488
# Stream: 1472, user_count: 1, avg_reward@stream: 1.0, avg_reward: 1.04, hr10: 1.0, regret: 9.0, coverage: 1.0, diversity: 1.0, batch_value_loss: 1707154304.0
# Stream: 1473, user_count: 17, avg_reward@stream: 1.59, avg_reward: 1.04, hr10: 1.038, regret: 8.412, coverage: 0.423, diversity: 1.0, batch_value_loss: 1732593182.118
# Stream: 1474, user_count: 479, avg_reward@stream: 1.22, avg_reward: 1.04, hr10: 0.75, regret: 8.783, coverage: 0.017, diversity: 1.0, batch_value_loss: 1766824017.236
# Stream: 1475, user_count: 3, avg_reward@stream: 1.0, avg_reward: 1.04, hr10: 1.0, regret: 9.0, coverage: 0.667, diversity: 1.0, batch_value_loss: 2601318741.333
# Stream: 1476, user_count: 29, avg_reward@stream: 1.1, avg_reward: 1.04, hr10: 0.762, regret: 8.897, coverage: 0.238, diversity: 1.0, batch_value_loss: 1964128467.862
# Stream: 1477, user_count: 27, avg_reward@stream: 0.74, avg_reward: 1.04, hr10: 0.571, regret: 9.259, coverage: 0.286, diversity: 1.0, batch_value_loss: 1935406421.333
# Stream: 1478, user_count: 96, avg_reward@stream: 0.6, avg_reward: 1.04, hr10: 0.426, regret: 9.396, coverage: 0.11, diversity: 0.947, batch_value_loss: 1880360448.0
# Stream: 1479, user_count: 6, avg_reward@stream: 1.17, avg_reward: 1.04, hr10: 1.0, regret: 8.833, coverage: 0.714, diversity: 1.0, batch_value_loss: 2269857109.333
# Stream: 1480, user_count: 27, avg_reward@stream: 1.48, avg_reward: 1.04, hr10: 1.111, regret: 8.519, coverage: 0.361, diversity: 0.882, batch_value_loss: 2311123702.519
# Stream: 1481, user_count: 174, avg_reward@stream: 0.55, avg_reward: 1.04, hr10: 0.371, regret: 9.448, coverage: 0.093, diversity: 0.941, batch_value_loss: 1853895362.207
# Stream: 1482, user_count: 50, avg_reward@stream: 1.36, avg_reward: 1.04, hr10: 0.971, regret: 8.64, coverage: 0.186, diversity: 0.941, batch_value_loss: 1811686359.04
# Stream: 1483, user_count: 28, avg_reward@stream: 0.86, avg_reward: 1.04, hr10: 0.8, regret: 9.143, coverage: 0.4, diversity: 0.933, batch_value_loss: 1694765641.143
# Stream: 1484, user_count: 86, avg_reward@stream: 1.09, avg_reward: 1.04, hr10: 0.879, regret: 8.907, coverage: 0.14, diversity: 1.0, batch_value_loss: 1920504093.767
# Stream: 1485, user_count: 68, avg_reward@stream: 1.26, avg_reward: 1.04, hr10: 0.915, regret: 8.735, coverage: 0.149, diversity: 1.0, batch_value_loss: 1810876416.0
# Stream: 1486, user_count: 15, avg_reward@stream: 1.27, avg_reward: 1.04, hr10: 1.0, regret: 8.733, coverage: 0.211, diversity: 1.0, batch_value_loss: 1789994871.467
# Stream: 1487, user_count: 23, avg_reward@stream: 1.61, avg_reward: 1.04, hr10: 1.088, regret: 8.391, coverage: 0.412, diversity: 1.0, batch_value_loss: 2011480954.435
# Stream: 1488, user_count: 4, avg_reward@stream: 1.0, avg_reward: 1.04, hr10: 1.0, regret: 9.0, coverage: 0.5, diversity: 1.0, batch_value_loss: 1099369984.0
# Stream: 1489, user_count: 14, avg_reward@stream: 0.64, avg_reward: 1.04, hr10: 0.474, regret: 9.357, coverage: 0.368, diversity: 1.0, batch_value_loss: 1912435273.143
# Stream: 1490, user_count: 120, avg_reward@stream: 0.82, avg_reward: 1.04, hr10: 0.513, regret: 9.175, coverage: 0.073, diversity: 1.0, batch_value_loss: 2074554777.6
# Stream: 1491, user_count: 216, avg_reward@stream: 1.33, avg_reward: 1.04, hr10: 0.894, regret: 8.671, coverage: 0.062, diversity: 1.0, batch_value_loss: 1976775414.519
# Stream: 1492, user_count: 62, avg_reward@stream: 1.29, avg_reward: 1.04, hr10: 0.941, regret: 8.71, coverage: 0.129, diversity: 1.0, batch_value_loss: 2126969822.968
# Stream: 1493, user_count: 40, avg_reward@stream: 1.02, avg_reward: 1.04, hr10: 0.759, regret: 8.975, coverage: 0.204, diversity: 1.0, batch_value_loss: 2321414144.0
# Stream: 1494, user_count: 29, avg_reward@stream: 2.24, avg_reward: 1.04, hr10: 1.667, regret: 7.759, coverage: 0.333, diversity: 1.0, batch_value_loss: 1996590539.034
# Stream: 1495, user_count: 233, avg_reward@stream: 1.13, avg_reward: 1.04, hr10: 0.661, regret: 8.871, coverage: 0.04, diversity: 0.957, batch_value_loss: 2013292359.416
# Stream: 1496, user_count: 135, avg_reward@stream: 1.06, avg_reward: 1.04, hr10: 0.616, regret: 8.941, coverage: 0.073, diversity: 1.0, batch_value_loss: 2079437133.748
# Stream: 1497, user_count: 173, avg_reward@stream: 0.58, avg_reward: 1.04, hr10: 0.402, regret: 9.416, coverage: 0.08, diversity: 0.608, batch_value_loss: 1966988980.532
# Stream: 1498, user_count: 46, avg_reward@stream: 1.04, avg_reward: 1.04, hr10: 0.738, regret: 8.957, coverage: 0.292, diversity: 0.811, batch_value_loss: 2271188902.957
# Stream: 1499, user_count: 14, avg_reward@stream: 1.14, avg_reward: 1.04, hr10: 1.143, regret: 8.857, coverage: 0.286, diversity: 1.0, batch_value_loss: 2855837988.571
# Stream: 1500, user_count: 22, avg_reward@stream: 2.0, avg_reward: 1.04, hr10: 1.128, regret: 8.0, coverage: 0.308, diversity: 0.933, batch_value_loss: 1949218443.636
# Stream: 1501, user_count: 60, avg_reward@stream: 1.85, avg_reward: 1.04, hr10: 1.121, regret: 8.15, coverage: 0.172, diversity: 1.0, batch_value_loss: 1980567005.867
# Stream: 1502, user_count: 166, avg_reward@stream: 0.61, avg_reward: 1.04, hr10: 0.459, regret: 9.392, coverage: 0.095, diversity: 1.0, batch_value_loss: 2061970617.06
# Stream: 1503, user_count: 74, avg_reward@stream: 1.84, avg_reward: 1.04, hr10: 1.062, regret: 8.162, coverage: 0.133, diversity: 0.917, batch_value_loss: 2307676436.757
# Stream: 1504, user_count: 136, avg_reward@stream: 1.88, avg_reward: 1.04, hr10: 1.067, regret: 8.125, coverage: 0.079, diversity: 1.0, batch_value_loss: 2012099041.882
# Stream: 1505, user_count: 88, avg_reward@stream: 1.28, avg_reward: 1.04, hr10: 0.796, regret: 8.716, coverage: 0.12, diversity: 0.871, batch_value_loss: 2195731176.727
# Stream: 1506, user_count: 85, avg_reward@stream: 1.2, avg_reward: 1.04, hr10: 0.708, regret: 8.8, coverage: 0.125, diversity: 0.971, batch_value_loss: 1961557052.235
# Stream: 1507, user_count: 560, avg_reward@stream: 0.61, avg_reward: 1.04, hr10: 0.339, regret: 9.395, coverage: 0.033, diversity: 0.905, batch_value_loss: 2104098347.886
# Stream: 1508, user_count: 32, avg_reward@stream: 1.94, avg_reward: 1.04, hr10: 1.148, regret: 8.062, coverage: 0.333, diversity: 0.957, batch_value_loss: 2032417152.0
# Stream: 1509, user_count: 34, avg_reward@stream: 0.35, avg_reward: 1.04, hr10: 0.255, regret: 9.647, coverage: 0.128, diversity: 0.806, batch_value_loss: 1950010669.176

# %%
mode
# Out:
# 'diff_pca'

# %%
diff_items = {'mode': f'hybrid_param_pca', 
              'reward_records': reward_records, 
              'avg_rewards': avg_rewards,
              'hit_ratios': hit_ratios,
              'regret_list': regret_list,
              'coverage_list': coverage_list,
              'diversity_list': diversity_list}

with open(f'results/hybrid_param_pca.pkl', 'wb') as handle:
    pickle.dump(diff_items, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
tqdm.pandas()

# %%
MULTIPLIER.progress_apply(lambda x: 1/abs(x)).describe()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#          multiplier
# count  1.444095e+06
# mean   7.364891e-01
# std    8.688142e+00
# min    3.342274e-02
# 25%    3.504231e-01
# 50%    5.342021e-01
# 75%    8.352726e-01
# max    7.242473e+03

# %% [markdown]
# ---
# Previous version of Training methods

# %%
# def train(agent, reward_records=[], avg_rewards=[], warmup=100):
#   agent.actor.train(True)
#   agent.critic.train(True)
#   batch_value_loss, batch_policy_loss = 0., 0.
#   step_value_loss, step_policy_loss = 0., 0.
#   step = 0
#   # self.epsilon.clear()

#   # ------------------- Episode (State) -------------------------------
#   for stream in tqdm(STREAM_LIST[:4000]):
#     # self.__user_episode_context()
#     users = STREAM_USER_DICT[stream]
#     agent.curr_stream = stream
#     agent.curr_stream_items = STREAM_ITEM_DICT[stream]
#     stream_reward = 0
#     batch_value_loss, batch_policy_loss = 0., 0.

#     # ----------------- Runs (User under stream) ---------------------
#     for i, user in enumerate(users):
#       # update step
#       step += 1
      
#       # state & ongoing
#       agent.curr_user = user
#       state = USER_CONTEXT.loc[(user, stream)]
#       ongoing = i != len(users) - 1

#       # --------------- Actor net choose actions ----------------------
#       # make actor to choose action
#       # action = latent vector
#       if step <= warmup:
#         action = agent.random_action()
#       else:
#         action = agent.generate_latent_action(state)
          
#       # --------------- Get next state & info to store ---------------
#       # Generate reward
#       reward = agent.get_actions_rewards()

#       # next_state: next user's state
#       next_user = users[i + 1] if i + 1 < len(users) else None
#       # Remember only when reward > 0 or the memory is short
#       reward_records.append(reward)
#       stream_reward += reward
#       if reward > 0 or len(agent.buffer) < 10:
#         storing_state = (user, stream)
#         storing_next_state = (next_user, stream) if next_user else storing_state
#         agent.buffer.remember(storing_state, action, reward, storing_next_state, ongoing)

#       # --------------- Train on Actor and Critic --------------------
#       # store pre-training value for td_error
#       # old_Q = self.q_value()
#       if step > warmup :
#         step_value_loss, step_policy_loss = agent.update_policy()
#       # store post-training value for td_error
#       # new_Q = self.q_value()
#       batch_value_loss += step_value_loss
#       batch_policy_loss += step_policy_loss

#       # --------------- Update with TD error -------------------------
#       # self.epsilon.update_at_step(self.asid, [(new_Q - old_Q), self.learn_step_counter], 1/len(self.stream_items))

#       # --------------- Inspecting result at step -------------------------
#     ep_avg_reward = round(sum(reward_records)/step, 2)
#     avg_rewards.append(ep_avg_reward)
#     print(f'Stream: {stream}, user_count: {len(users)}, \
# sum_rewards: {round(sum(reward_records), 2)},avg_reward@stream: {round(stream_reward/len(users), 2)}, avg_reward: {ep_avg_reward}, \
# batch_value_loss: {round(float(batch_value_loss)/len(users), 3)}, batch_policy_loss: {round(float(batch_policy_loss)/len(users), 3)} | reward_len: {len(reward_records)}')
    
#     if len(reward_records) >= 247581: break
