# %% [markdown]
# # DDPG
# > Experiment list: Param Noise Constant -> Ax

# %%
import pandas as pd
import numpy as np
import itertools
from tqdm.notebook import tqdm
import pickle

import torch
import torch.utils.data as data
from torch.utils.data import DataLoader
import torch.utils.data.sampler as sampler
import torch.nn as nn
import torch.nn.functional as F

from matplotlib import pyplot as plt
from collections import defaultdict
import warnings
from sklearn.preprocessing import LabelEncoder
import random
from datetime import datetime
import pytz
import line_profiler
from functools import reduce

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Fix Random Seeds

# %%
def same_seeds(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  
  np.random.seed(seed)  
  torch.backends.cudnn.benchmark = False
  torch.backends.cudnn.deterministic = True

same_seeds(0)

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Available Files
#
# ||Title|File Name|
# |---|-----|---------|
# |order|Stream group by streamers|`streamer_stream_dict.pkl`|
# ||Stream list|`stream_list.pkl`|
# |Context|Final user context|`user_context.pkl`|
# ||Streamer context|`streamer.pkl`|
# ||Item context|`item_pca_df.pkl`|
# |Aux|stream: items list|`stream_item_dict.pkl`|
# ||stream: users list|`stream_users_dict.pkl`|
# ||item list the consumer actually bought|`user_bought_dict.pkl`|
# |Explore-Diff|PCA based diff vector|`diff_vectors_pca.pkl`|
# ||SVD based diff vector|`diff_vectors_svd.pkl`|
# ||VAE based diff vector|`diff_vectors_vae.pkl`|
# |Threshold|VAE reconstruction error df|`vae_recons_df.pkl`|

# %%
# STREAMER_STREAM_DICT = pd.read_pickle('../../data/streamer_stream_dict.pkl')
STREAM_LIST = pd.read_pickle('../../data/stream_list.pkl')
USER_CONTEXT = pd.read_pickle('../../data/user_context.pkl')
# STREAMER = pd.read_pickle('../../data/streamer.pkl')
ITEM_PCA_DF = pd.read_pickle('../../data/item_pca_df.pkl')
STREAM_ITEM_DICT = pd.read_pickle('../../data/stream_item_dict.pkl')
USER_BOUGHT_DICT = pd.read_pickle('../../data/user_bought_dict.pkl')
STREAM_USER_DICT = pd.read_pickle('../../data/stream_users_dict.pkl')
# Current used diff
ITEM_DIFF = pd.read_pickle('../../data/item_diff_vectors.pkl')

# %%
# DIFF_PCA = pd.read_pickle('../../data/diff_vectors_pca.pkl')
DIFF_SVD = pd.read_pickle('../../data/diff_vectors_svd.pkl')
# DIFF_VAE = pd.read_pickle('../../data/diff_vectors_vae.pkl')
# VAE_RECONS_DF = pd.read_pickle('../../data/vae_recons_df.pkl')
# VAE_RECONS64_DF = pd.read_pickle('../../data/vae_recons_64_df.pkl')
# MUL150_PCA = pd.read_pickle('../../data/mul150_pca_diff.pkl')
# MUL150_VAE = pd.read_pickle('../../data/mul150_vae_diff.pkl')
# MUL64_PCA = pd.read_pickle('../../data/mul64_pca_diff.pkl')
# MUL64_VAE = pd.read_pickle('../../data/mul64_vae_diff.pkl')

# %% [markdown]
# ---

# %% [markdown]
# ## Replay

# %%
class RingBuffer(object):
    def __init__(self, maxlen):
        self.maxlen = maxlen
        self.start = 0
        self.length = 0
        self.data = [None for _ in range(maxlen)]

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        if idx < 0 or idx >= self.length:
            raise KeyError()
        return self.data[(self.start + idx) % self.maxlen]

    def append(self, v):
        if self.length < self.maxlen:
            # We have space, simply increase the length.
            self.length += 1
        elif self.length == self.maxlen:
            # No space, "remove" the first item.
            self.start = (self.start + 1) % self.maxlen
        else:
            # This should never happen.
            raise RuntimeError()
        self.data[(self.start + self.length - 1) % self.maxlen] = v

class ReplayBuffer:
  def __init__(self, limit=10000):
    self.limit = limit
    # init 4 RingBuffers: states/actions/rewards/ongoing
    self.states_buffer = RingBuffer(limit)
    self.next_states_buffer = RingBuffer(limit)
    self.actions_buffer = RingBuffer(limit)
    self.rewards_buffer = RingBuffer(limit)
    self.ongoings_buffer = RingBuffer(limit)
    
  def __len__(self):
    assert len(self.states_buffer) == len(self.next_states_buffer) == len(self.actions_buffer) == \
           len(self.rewards_buffer) == len(self.ongoings_buffer)
    return len(self.states_buffer)

  def remember(self, state, actions, reward, next_state, ongoing):
    assert len(self.states_buffer) == len(self.next_states_buffer) == len(self.actions_buffer) == \
           len(self.rewards_buffer) == len(self.ongoings_buffer)
    # append each element separately in different list
    self.states_buffer.append(state)
    self.actions_buffer.append(actions)
    self.rewards_buffer.append(reward)
    self.next_states_buffer.append(next_state)
    self.ongoings_buffer.append(ongoing)
    
  def get_batch(self, batch_size=100):
    assert len(self.states_buffer) == len(self.next_states_buffer) == len(self.actions_buffer) == \
           len(self.rewards_buffer) == len(self.ongoings_buffer)
    # same for sample_and_split
    states0_batch = []
    states1_batch = []
    actions_batch = []
    rewards_batch = []
    ongoings_batch = []
    batch_indexs = np.random.randint(0, len(self.states_buffer), size=min(len(self.states_buffer), batch_size))
    for i in batch_indexs:
      states0_batch.append(USER_CONTEXT.xs(self.states_buffer[i]))
      states1_batch.append(USER_CONTEXT.xs(self.next_states_buffer[i]))
      actions_batch.append(self.actions_buffer[i])
      rewards_batch.append(self.rewards_buffer[i])
      ongoings_batch.append(self.ongoings_buffer[i])
    assert len(states0_batch) == len(states1_batch) == len(actions_batch) == \
           len(rewards_batch) == len(ongoings_batch)
    return np.array(states0_batch), np.array(actions_batch), np.array(rewards_batch), np.array(states1_batch), np.array(ongoings_batch)

# %% [markdown]
# ## Epsilon

# %%
from abc import ABC, abstractmethod
import math

class Epsilon(ABC):
  @abstractmethod
  def clear(self):
    pass
  
  @abstractmethod
  def get_epsilon(self, key):
    pass
  
  @abstractmethod
  def update_at_step(self, key, data, delta):
    pass
  
  @abstractmethod
  def update_at_epoch(self, data):
    pass

class Decay(Epsilon):
  # Ref: Decay(0.5, 0.85)
  '''
  Epsilon Decay EE method with update/decay at epoch
  '''
  def __init__(self, initial, epoch_decay=1.0, step_decay=1.0):
    self.initial = initial
    self.epoch_decay, self.step_decay = epoch_decay, step_decay
    self.epsilon = self.initial
    
  def clear(self):
    self.epsilon = self.initial # should be 4 for origin setting
    
  def get_epsilon(self, key):
    return self.epsilon
  
  def update_at_step(self, key, data, delta):
    # origin setting
    # pass
    # exponentially
    i = data[1]
    self.epsilon = 4 / ((i + 1) ** (1 / 4))
    
  def update_at_epoch(self, data):
    # origin settings
    # epoch = data
    # self.epsilon = 4 / ((epoch + 1) ** (1 / 2))
    # exponentially
    self.epsilon *= self.epoch_decay


class VDBE(Epsilon):
  # VDBE(0.5, 0.01)
  def __init__(self, initial, sigma):
    self.initial = initial
    self.sigma = sigma

  def clear(self):
    self.epsilon = defaultdict(lambda: self.initial)

  def get_epsilon(self, key):
    return self.epsilon[key]
  
  def update_at_step(self, key, data, delta):
    td_error = data[0]
    coeff = math.exp(-abs(td_error) / self.sigma)
    f = (1.0 - coeff) / (1.0 + coeff)
    self.epsilon[key] = delta * f + (1.0 - delta) * self.epsilon[key]
  
  def update_at_epoch(self, data):
    pass

# %% [markdown]
# ## Random Process

# %%
class RandomProcess(object):
    def reset_states(self):
        pass

class AnnealedGaussianProcess(RandomProcess):
    def __init__(self, mu, sigma, sigma_min, n_steps_annealing):
        self.mu = mu
        self.sigma = sigma
        self.n_steps = 0

        if sigma_min is not None:
            self.m = -float(sigma - sigma_min) / float(n_steps_annealing)
            self.c = sigma
            self.sigma_min = sigma_min
        else:
            self.m = 0.
            self.c = sigma
            self.sigma_min = sigma

    @property
    def current_sigma(self):
        sigma = max(self.sigma_min, self.m * float(self.n_steps) + self.c)
        return sigma


# Based on http://math.stackexchange.com/questions/1287634/implementing-ornstein-uhlenbeck-in-matlab
class OrnsteinUhlenbeckProcess(AnnealedGaussianProcess):
    def __init__(self, theta, mu=0., sigma=1., dt=1e-2, x0=None, size=1, sigma_min=None, n_steps_annealing=1000):
        super(OrnsteinUhlenbeckProcess, self).__init__(mu=mu, sigma=sigma, sigma_min=sigma_min, n_steps_annealing=n_steps_annealing)
        self.theta = theta
        self.mu = mu
        self.dt = dt
        self.x0 = x0
        self.size = size
        self.reset_states()

    def sample(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + self.current_sigma * np.sqrt(self.dt) * np.random.normal(size=self.size)
        self.x_prev = x
        self.n_steps += 1
        return x

    def reset_states(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros(self.size)

# %% [markdown]
# ## Models

# %%
def fanin_init(size, fanin=None):
    fanin = fanin or size[0]
    v = 1. / np.sqrt(fanin)
    return torch.Tensor(size).uniform_(-v, v)

class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, mode, hidden1=400, hidden2=300, init_w=3e-3):
        super(Actor, self).__init__()
        self.mode = mode
        self.fc1 = nn.Linear(state_dim, hidden1)
        self.fc2 = nn.Linear(hidden1, hidden2)
        self.fc3 = nn.Linear(hidden2, action_dim)
        self.norm1 = nn.LayerNorm(hidden1)
        self.norm2 = nn.LayerNorm(hidden2)
        self.norm3 = nn.LayerNorm(action_dim)
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()
        self.init_weights(init_w)
    
    def init_weights(self, init_w):
        self.fc1.weight.data = fanin_init(self.fc1.weight.data.size())
        self.fc2.weight.data = fanin_init(self.fc2.weight.data.size())
        self.fc3.weight.data.uniform_(-init_w, init_w)
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.norm1(out)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.norm2(out)
        out = self.relu(out)
        out = self.fc3(out)
        out = self.norm3(out)
        out = self.tanh(out)
        return out

    def add_parameter_noise(self, scalar=.1):
        self.fc1.weight.data += torch.randn_like(self.fc1.weight.data) * scalar
        self.fc2.weight.data += torch.randn_like(self.fc2.weight.data) * scalar
        self.fc3.weight.data += torch.randn_like(self.fc3.weight.data) * scalar


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim, hidden1=400, hidden2=300, init_w=3e-3):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(state_dim, hidden1)
        self.fc2 = nn.Linear(hidden1+action_dim, hidden2)
        self.fc3 = nn.Linear(hidden2, 1)
        self.relu = nn.ReLU()
        self.init_weights(init_w)
    
    def init_weights(self, init_w):
        self.fc1.weight.data = fanin_init(self.fc1.weight.data.size())
        self.fc2.weight.data = fanin_init(self.fc2.weight.data.size())
        self.fc3.weight.data.uniform_(-init_w, init_w)
    
    def forward(self, xs):
        x, a = xs
        out = self.fc1(x)
        out = self.relu(out)
        # debug()
        out = self.fc2(torch.cat([out,a],1))
        out = self.relu(out)
        out = self.fc3(out)
        return out

# %% [markdown]
# ## DDPG

# %%
def to_tensor(input_df):
  return torch.tensor(input_df).to(DEVICE).float()

class DDPG(object):
  def __init__(self, actor_lr, critic_lr, state_dim, action_dim, mode='baseline',
               hidden1=400, hidden2=300, diff_multiplier=1,
               top_k=10, max_memory=10000, depsilon=50000, discount=0.99,
               tau=0.001, batch_size=100, ou_theta=0.15, ou_mu=0.0, ou_sigma=0.2, 
               param_noise_scalar=.05, param_noise_scalar_alpha=1.01, desired_distance=.7):
    # State & Action dimension
    self.state_dim = state_dim
    self.action_dim = action_dim
    
    # Mode settings
    # baseline
    # diff: diff_pca, diff_svd, diff_vae
    # threshold: thres_vae, thres_vdbe
    # multiplier: MUL150_PCA, MUL150_VAE, MUL64_PCA, MUL64_VAE
    # Parameter noise: PARAM_NOISE
    self.mode = mode
    self.diff_multiplier = diff_multiplier
    
    # Param Noise
    self.distances = []
    self.desired_distance = desired_distance
    self.param_noise_scalar = param_noise_scalar
    self.param_noise_scalar_alpha = param_noise_scalar_alpha

    # Init Actor
    self.actor = Actor(state_dim, action_dim, mode, hidden1, hidden2)
    self.actor_noised = Actor(state_dim, action_dim, mode, hidden1, hidden2)
    self.actor_target = Actor(state_dim, action_dim, mode, hidden1, hidden2)
    self.actor_optim = torch.optim.Adam(self.actor.parameters(), lr=actor_lr)
    # Init Critic
    self.critic = Critic(state_dim, action_dim, hidden1, hidden2)
    self.critic_target = Critic(state_dim, action_dim, hidden1, hidden2)
    self.critic_optim = torch.optim.Adam(self.critic.parameters(), lr=critic_lr)

    # Memory
    self.buffer = ReplayBuffer(limit=max_memory)

    # Exploration
    self.epsilon = 1.0
    self.depsilon = 1.0 / depsilon
    self.random_process = OrnsteinUhlenbeckProcess(size=action_dim, theta=ou_theta, mu=ou_mu, sigma=ou_sigma)

    # Reward related
    self.top_k = top_k
    
    # Loss Function
    self.loss_fn = nn.MSELoss()
    
    # Hyperparameters
    self.discount = discount
    self.tau = tau
    self.batch_size = batch_size

    # Network to cuda
    self.actor.to(DEVICE)
    self.actor_noised.to(DEVICE)
    self.critic.to(DEVICE)
    self.actor_target.to(DEVICE)
    self.critic_target.to(DEVICE)
    
  def random_action(self):
    action = np.random.uniform(-1.,1.,self.action_dim).astype('float32')
    self.action = action
    return action
    
  def generate_latent_action(self, state, decay_epsilon=True, vdbe_epsilon=False):
    action = self.actor(to_tensor(state))
    '''
    Param Noise
    '''
    with torch.no_grad():
      # hard copy the actor to actor_noised
      self.actor_noised.load_state_dict(self.actor.state_dict().copy())

      # add noise to the copy
      self.actor_noised.add_parameter_noise(self.param_noise_scalar)

      # get the next action values from the noised actor
      action_noised = self.actor_noised(to_tensor(state))

      # meassure the distance between the action values from the regular and 
      # the noised actor to adjust the amount of noise that will be added next round
      distance = torch.sqrt(torch.mean(torch.square(action - action_noised))).cpu().detach().numpy()
      self.distances.append(distance)

      # adjust the amount of noise given to the actor_noised
      if distance < self.desired_distance:
          self.param_noise_scalar *= self.param_noise_scalar_alpha
      else:
          self.param_noise_scalar /= self.param_noise_scalar_alpha

      # set the noised action as action
      action = action_noised
    '''
    Add the diff vector to action
    '''
    if self.mode != 'baseline':
      current_diff = globals()[self.mode.upper()]

      if self.mode == 'thres_vae' and state.name in current_diff.index:
        if VAE_RECONS_DF.loc[state.name][0] > 0.275:
          action += to_tensor(DIFF_VAE.loc[state.name])
      elif self.mode == 'thres_vae_64' and state.name in current_diff.index:
        if VAE_RECONS64_DF.loc[state.name][0] > 0.02:
          action += to_tensor(DIFF_VAE.loc[state.name])
      elif state.name in current_diff.index:
        # for mode = [diff_pca, diff_svd, diff_vae, MUL150_VAE, MUL64_VAE, ITEM_DIFF]
        action += to_tensor(current_diff.loc[state.name]) * self.diff_multiplier * max(self.epsilon, 0)

    # else: action += max(self.epsilon, 0) * torch.tensor(self.random_process.sample()).to(DEVICE).float()
    action = torch.clamp(action, -1., 1.).cpu().detach().numpy()

    if decay_epsilon:
      self.epsilon -= self.depsilon
    # if vdbe_epsilon:
        
    self.action = action
    return action
  
  def get_actions_rewards(self):
    true_list = USER_BOUGHT_DICT[self.curr_user]
    # self.curr_stream_items: candidate items in current stream
    actions = ITEM_PCA_DF.iloc[self.curr_stream_items].apply(lambda x: np.dot(x, self.action), axis=1).nlargest(self.top_k).index
    res = sum([1 if a in true_list else 0 for a in actions])
    return res
    
  def update_policy(self):
    # Sample batch
    state_batch, action_batch, reward_batch, \
    next_state_batch, ongoing_batch = self.buffer.get_batch(self.batch_size)
    
    # Prepare for the target q batch
    next_q_values = self.critic_target([
        to_tensor(next_state_batch).detach(),
        self.actor_target(to_tensor(next_state_batch).detach()),
    ])
    
    # 如果 ongoing 為 True(1) 時，乘以 next_q 會有值
    # 但是 ongoing 為 False(0) 時，乘以 next_q 會等於 0
    target_q_batch = to_tensor(reward_batch).view(next_q_values.shape) + \
                       self.discount*to_tensor(ongoing_batch).view(next_q_values.shape)*next_q_values.detach()

    # Critic update
    self.critic_optim.zero_grad()

    q_batch = self.critic([ to_tensor(state_batch), to_tensor(action_batch) ])

    value_loss = self.loss_fn(q_batch, target_q_batch)
    value_loss.backward()
    self.critic_optim.step()

    # Actor update
    self.actor_optim.zero_grad()

    policy_loss = -self.critic([
        to_tensor(state_batch),
        self.actor(to_tensor(state_batch))
    ])

    policy_loss = policy_loss.mean()
    policy_loss.backward()
    self.actor_optim.step()

    # Target update
    self._soft_update(self.actor_target, self.actor)
    self._soft_update(self.critic_target, self.critic)
    return value_loss, policy_loss
    
  def _soft_update(self, target, source):
    for target_param, param in zip(target.parameters(), source.parameters()):
        target_param.data.copy_(
            target_param.data * (1.0 - self.tau) + param.data * self.tau
        )

# %% [markdown]
# ## Main Method

# %%
def train(agent, reward_records=[], avg_rewards=[], warmup=100):
  agent.actor.train(True)
  agent.critic.train(True)
  batch_value_loss, batch_policy_loss = 0., 0.
  step_value_loss, step_policy_loss = 0., 0.
  step = 0
  # self.epsilon.clear()

  # ------------------- Episode (State) -------------------------------
  for stream in tqdm(STREAM_LIST[:4000]):
    # self.__user_episode_context()
    users = STREAM_USER_DICT[stream]
    agent.curr_stream = stream
    agent.curr_stream_items = STREAM_ITEM_DICT[stream]
    stream_reward = 0
    batch_value_loss, batch_policy_loss = 0., 0.

    # ----------------- Runs (User under stream) ---------------------
    for i, user in enumerate(users):
      # update step
      step += 1
      
      # state & ongoing
      agent.curr_user = user
      state = USER_CONTEXT.loc[(user, stream)]
      ongoing = i != len(users) - 1

      # --------------- Actor net choose actions ----------------------
      # make actor to choose action
      # action = latent vector
      if step <= warmup:
        action = agent.random_action()
      else:
        action = agent.generate_latent_action(state)
          
      # --------------- Get next state & info to store ---------------
      # Generate reward
      reward = agent.get_actions_rewards()

      # next_state: next user's state
      next_user = users[i + 1] if i + 1 < len(users) else None
      # Remember only when reward > 0 or the memory is short
      reward_records.append(reward)
      stream_reward += reward
      if reward > 0 or len(agent.buffer) < 10:
        storing_state = (user, stream)
        storing_next_state = (next_user, stream) if next_user else storing_state
        agent.buffer.remember(storing_state, action, reward, storing_next_state, ongoing)

      # --------------- Train on Actor and Critic --------------------
      # store pre-training value for td_error
      # old_Q = self.q_value()
      if step > warmup :
        step_value_loss, step_policy_loss = agent.update_policy()
      # store post-training value for td_error
      # new_Q = self.q_value()
      batch_value_loss += step_value_loss
      batch_policy_loss += step_policy_loss

      # --------------- Update with TD error -------------------------
      # self.epsilon.update_at_step(self.asid, [(new_Q - old_Q), self.learn_step_counter], 1/len(self.stream_items))

      # --------------- Inspecting result at step -------------------------
    ep_avg_reward = round(sum(reward_records)/step, 2)
    avg_rewards.append(ep_avg_reward)

    print(f'Stream: {stream}, user_count: {len(users)}, \
distance_mean: {np.mean(agent.distances):.3f}, std: {np.std(agent.distances):.3f}, avg_reward@stream: {round(stream_reward/len(users), 2)}, avg_reward: {ep_avg_reward}, \
batch_value_loss: {round(float(batch_value_loss)/len(users), 3)}, batch_policy_loss: {round(float(batch_policy_loss)/len(users), 3)} | reward_len: {len(reward_records)}')
    
    if len(reward_records) >= 247581: break

# %%
pd.set_option('mode.chained_assignment', None)

actor_lr = 1.0e-3
critic_lr = 1.0e-3
state_dim = USER_CONTEXT.shape[1]
action_dim = ITEM_PCA_DF.shape[1]
hidden1 = 400
hidden2 = 300
diff_multiplier = 2.7 # 1.66266
top_k = 10
max_memory = 10000
depsilon = 50000
discount = 0.99
tau = 0.001
batch_size = 100
ou_theta = 0.15
ou_mu = 0.0
ou_sigma = 0.2
param_noise_scalar = 0.05
param_noise_scalar_alpha = 1.01
desired_distance = 0.7

mode = 'diff_svd'

warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Execute

# %%
ddpg_agent = DDPG(actor_lr, critic_lr, state_dim, action_dim, mode, hidden1, hidden2, diff_multiplier,
                  top_k, max_memory, depsilon, discount, tau, batch_size, ou_theta, ou_mu, ou_sigma, 
                  param_noise_scalar, param_noise_scalar_alpha, desired_distance)
reward_records = []
avg_rewards = []
train(ddpg_agent, reward_records, avg_rewards)
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]
# Stream: 0, user_count: 56, distance_mean: nan, std: nan, avg_reward@stream: 0.48, avg_reward: 0.48, batch_value_loss: 0.0, batch_policy_loss: 0.0 | reward_len: 32
# Stream: 1, user_count: 534, distance_mean: 0.546, std: 0.259, avg_reward@stream: 0.56, avg_reward: 0.55, batch_value_loss: 0.055, batch_policy_loss: -1.639 | reward_len: 254
# Stream: 2, user_count: 56, distance_mean: 0.563, std: 0.251, avg_reward@stream: 1.38, avg_reward: 0.62, batch_value_loss: 0.038, batch_policy_loss: -2.452 | reward_len: 299
# Stream: 3, user_count: 29, distance_mean: 0.570, std: 0.248, avg_reward@stream: 1.31, avg_reward: 0.65, batch_value_loss: 0.042, batch_policy_loss: -2.847 | reward_len: 323
# Stream: 4, user_count: 104, distance_mean: 0.590, std: 0.235, avg_reward@stream: 0.35, avg_reward: 0.61, batch_value_loss: 0.019, batch_policy_loss: -2.768 | reward_len: 355
# Stream: 5, user_count: 83, distance_mean: 0.601, std: 0.225, avg_reward@stream: 0.84, avg_reward: 0.63, batch_value_loss: 0.012, batch_policy_loss: -2.382 | reward_len: 413
# Stream: 6, user_count: 37, distance_mean: 0.606, std: 0.221, avg_reward@stream: 0.62, avg_reward: 0.63, batch_value_loss: 0.012, batch_policy_loss: -2.579 | reward_len: 429
# Stream: 7, user_count: 213, distance_mean: 0.628, std: 0.205, avg_reward@stream: 0.38, avg_reward: 0.58, batch_value_loss: 0.006, batch_policy_loss: -3.577 | reward_len: 502
# Stream: 8, user_count: 42, distance_mean: 0.633, std: 0.204, avg_reward@stream: 1.02, avg_reward: 0.6, batch_value_loss: 0.004, batch_policy_loss: -3.171 | reward_len: 544
# Stream: 9, user_count: 2628, distance_mean: 0.678, std: 0.148, avg_reward@stream: 0.58, avg_reward: 0.59, batch_value_loss: 0.016, batch_policy_loss: -4.875 | reward_len: 1675
# Stream: 10, user_count: 112, distance_mean: 0.680, std: 0.147, avg_reward@stream: 0.31, avg_reward: 0.58, batch_value_loss: 0.025, batch_policy_loss: -8.135 | reward_len: 1707
# Stream: 11, user_count: 343, distance_mean: 0.682, std: 0.144, avg_reward@stream: 0.66, avg_reward: 0.58, batch_value_loss: 0.037, batch_policy_loss: -8.88 | reward_len: 1867
# Stream: 12, user_count: 14, distance_mean: 0.682, std: 0.144, avg_reward@stream: 0.93, avg_reward: 0.59, batch_value_loss: 0.051, batch_policy_loss: -9.594 | reward_len: 1879
# Stream: 13, user_count: 51, distance_mean: 0.682, std: 0.143, avg_reward@stream: 0.53, avg_reward: 0.59, batch_value_loss: 0.074, batch_policy_loss: -9.29 | reward_len: 1902
# Stream: 14, user_count: 1, distance_mean: 0.682, std: 0.143, avg_reward@stream: 1.0, avg_reward: 0.59, batch_value_loss: 0.134, batch_policy_loss: -8.963 | reward_len: 1903
# Stream: 15, user_count: 115, distance_mean: 0.683, std: 0.142, avg_reward@stream: 1.21, avg_reward: 0.6, batch_value_loss: 0.081, batch_policy_loss: -9.068 | reward_len: 1984
# Stream: 16, user_count: 26, distance_mean: 0.683, std: 0.142, avg_reward@stream: 1.23, avg_reward: 0.61, batch_value_loss: 0.07, batch_policy_loss: -9.277 | reward_len: 2006
# Stream: 17, user_count: 20, distance_mean: 0.683, std: 0.142, avg_reward@stream: 1.1, avg_reward: 0.61, batch_value_loss: 0.104, batch_policy_loss: -9.332 | reward_len: 2019
# Stream: 18, user_count: 40, distance_mean: 0.682, std: 0.141, avg_reward@stream: 0.33, avg_reward: 0.61, batch_value_loss: 0.067, batch_policy_loss: -9.332 | reward_len: 2030
# Stream: 19, user_count: 34, distance_mean: 0.683, std: 0.141, avg_reward@stream: 0.88, avg_reward: 0.61, batch_value_loss: 0.097, batch_policy_loss: -9.409 | reward_len: 2052
# Stream: 20, user_count: 39, distance_mean: 0.683, std: 0.141, avg_reward@stream: 0.56, avg_reward: 0.61, batch_value_loss: 0.095, batch_policy_loss: -9.545 | reward_len: 2070
# Stream: 21, user_count: 23, distance_mean: 0.683, std: 0.140, avg_reward@stream: 0.57, avg_reward: 0.61, batch_value_loss: 0.091, batch_policy_loss: -9.698 | reward_len: 2082
# Stream: 22, user_count: 45, distance_mean: 0.683, std: 0.140, avg_reward@stream: 0.67, avg_reward: 0.61, batch_value_loss: 0.051, batch_policy_loss: -9.894 | reward_len: 2109
# Stream: 23, user_count: 36, distance_mean: 0.683, std: 0.140, avg_reward@stream: 1.0, avg_reward: 0.61, batch_value_loss: 0.051, batch_policy_loss: -9.952 | reward_len: 2145
# Stream: 24, user_count: 28, distance_mean: 0.683, std: 0.139, avg_reward@stream: 1.04, avg_reward: 0.61, batch_value_loss: 0.081, batch_policy_loss: -9.966 | reward_len: 2173
# Stream: 25, user_count: 101, distance_mean: 0.684, std: 0.138, avg_reward@stream: 0.28, avg_reward: 0.61, batch_value_loss: 0.07, batch_policy_loss: -9.964 | reward_len: 2198
# Stream: 26, user_count: 178, distance_mean: 0.685, std: 0.137, avg_reward@stream: 0.31, avg_reward: 0.6, batch_value_loss: 0.045, batch_policy_loss: -10.646 | reward_len: 2252
# Stream: 27, user_count: 1447, distance_mean: 0.688, std: 0.128, avg_reward@stream: 0.58, avg_reward: 0.59, batch_value_loss: 0.045, batch_policy_loss: -12.407 | reward_len: 2964
# Stream: 28, user_count: 9, distance_mean: 0.687, std: 0.128, avg_reward@stream: 1.0, avg_reward: 0.59, batch_value_loss: 0.04, batch_policy_loss: -13.747 | reward_len: 2973
# Stream: 29, user_count: 43, distance_mean: 0.688, std: 0.127, avg_reward@stream: 0.37, avg_reward: 0.59, batch_value_loss: 0.043, batch_policy_loss: -13.567 | reward_len: 2983
# Stream: 30, user_count: 64, distance_mean: 0.688, std: 0.127, avg_reward@stream: 0.39, avg_reward: 0.59, batch_value_loss: 0.114, batch_policy_loss: -13.685 | reward_len: 3002
# Stream: 31, user_count: 68, distance_mean: 0.688, std: 0.127, avg_reward@stream: 0.38, avg_reward: 0.59, batch_value_loss: 0.07, batch_policy_loss: -14.121 | reward_len: 3025
# Stream: 32, user_count: 56, distance_mean: 0.688, std: 0.126, avg_reward@stream: 0.5, avg_reward: 0.59, batch_value_loss: 0.084, batch_policy_loss: -14.531 | reward_len: 3049
# Stream: 33, user_count: 128, distance_mean: 0.688, std: 0.126, avg_reward@stream: 1.35, avg_reward: 0.6, batch_value_loss: 0.186, batch_policy_loss: -14.85 | reward_len: 3147
# Stream: 34, user_count: 28, distance_mean: 0.688, std: 0.126, avg_reward@stream: 0.96, avg_reward: 0.6, batch_value_loss: 0.222, batch_policy_loss: -14.94 | reward_len: 3170
# Stream: 35, user_count: 28, distance_mean: 0.688, std: 0.125, avg_reward@stream: 1.0, avg_reward: 0.6, batch_value_loss: 0.152, batch_policy_loss: -14.989 | reward_len: 3198
# Stream: 36, user_count: 127, distance_mean: 0.688, std: 0.125, avg_reward@stream: 1.06, avg_reward: 0.61, batch_value_loss: 0.23, batch_policy_loss: -15.185 | reward_len: 3290
# Stream: 37, user_count: 210, distance_mean: 0.689, std: 0.124, avg_reward@stream: 0.54, avg_reward: 0.61, batch_value_loss: 0.174, batch_policy_loss: -15.247 | reward_len: 3378
# Stream: 38, user_count: 6, distance_mean: 0.689, std: 0.124, avg_reward@stream: 1.33, avg_reward: 0.61, batch_value_loss: 0.19, batch_policy_loss: -15.312 | reward_len: 3384
# Stream: 39, user_count: 55, distance_mean: 0.689, std: 0.123, avg_reward@stream: 0.76, avg_reward: 0.61, batch_value_loss: 0.209, batch_policy_loss: -15.483 | reward_len: 3411
# Stream: 40, user_count: 93, distance_mean: 0.689, std: 0.123, avg_reward@stream: 1.24, avg_reward: 0.62, batch_value_loss: 0.16, batch_policy_loss: -15.969 | reward_len: 3475
# Stream: 41, user_count: 42, distance_mean: 0.689, std: 0.123, avg_reward@stream: 1.1, avg_reward: 0.62, batch_value_loss: 0.169, batch_policy_loss: -16.014 | reward_len: 3517
# Stream: 42, user_count: 125, distance_mean: 0.689, std: 0.123, avg_reward@stream: 0.37, avg_reward: 0.62, batch_value_loss: 0.158, batch_policy_loss: -16.044 | reward_len: 3562
# Stream: 43, user_count: 12, distance_mean: 0.689, std: 0.122, avg_reward@stream: 1.33, avg_reward: 0.62, batch_value_loss: 0.097, batch_policy_loss: -16.198 | reward_len: 3574
# Stream: 44, user_count: 126, distance_mean: 0.689, std: 0.122, avg_reward@stream: 0.96, avg_reward: 0.63, batch_value_loss: 0.241, batch_policy_loss: -16.26 | reward_len: 3649
# Stream: 45, user_count: 8, distance_mean: 0.689, std: 0.122, avg_reward@stream: 1.25, avg_reward: 0.63, batch_value_loss: 0.182, batch_policy_loss: -16.534 | reward_len: 3657
# Stream: 46, user_count: 645, distance_mean: 0.690, std: 0.119, avg_reward@stream: 0.36, avg_reward: 0.61, batch_value_loss: 0.159, batch_policy_loss: -17.704 | reward_len: 3866
# Stream: 47, user_count: 698, distance_mean: 0.691, std: 0.117, avg_reward@stream: 0.33, avg_reward: 0.58, batch_value_loss: 0.119, batch_policy_loss: -19.928 | reward_len: 4077
# Stream: 48, user_count: 107, distance_mean: 0.691, std: 0.117, avg_reward@stream: 1.53, avg_reward: 0.59, batch_value_loss: 0.155, batch_policy_loss: -21.363 | reward_len: 4161
# Stream: 49, user_count: 2, distance_mean: 0.691, std: 0.117, avg_reward@stream: 1.0, avg_reward: 0.6, batch_value_loss: 0.129, batch_policy_loss: -21.695 | reward_len: 4163
# Stream: 50, user_count: 29, distance_mean: 0.691, std: 0.117, avg_reward@stream: 0.59, avg_reward: 0.6, batch_value_loss: 0.447, batch_policy_loss: -21.57 | reward_len: 4180
# Stream: 51, user_count: 6, distance_mean: 0.691, std: 0.117, avg_reward@stream: 1.0, avg_reward: 0.6, batch_value_loss: 0.278, batch_policy_loss: -21.578 | reward_len: 4186
# Stream: 52, user_count: 15, distance_mean: 0.691, std: 0.117, avg_reward@stream: 1.0, avg_reward: 0.6, batch_value_loss: 0.603, batch_policy_loss: -21.905 | reward_len: 4201
# Stream: 53, user_count: 5, distance_mean: 0.691, std: 0.117, avg_reward@stream: 1.0, avg_reward: 0.6, batch_value_loss: 0.43, batch_policy_loss: -22.017 | reward_len: 4206
# Stream: 54, user_count: 20, distance_mean: 0.691, std: 0.117, avg_reward@stream: 0.5, avg_reward: 0.6, batch_value_loss: 0.648, batch_policy_loss: -21.819 | reward_len: 4216
# Stream: 55, user_count: 226, distance_mean: 0.691, std: 0.116, avg_reward@stream: 0.87, avg_reward: 0.6, batch_value_loss: 0.465, batch_policy_loss: -22.114 | reward_len: 4341
# Stream: 56, user_count: 18, distance_mean: 0.692, std: 0.116, avg_reward@stream: 1.0, avg_reward: 0.6, batch_value_loss: 0.228, batch_policy_loss: -22.532 | reward_len: 4359
# Stream: 57, user_count: 36, distance_mean: 0.691, std: 0.116, avg_reward@stream: 0.67, avg_reward: 0.6, batch_value_loss: 0.496, batch_policy_loss: -22.305 | reward_len: 4378
# Stream: 58, user_count: 41, distance_mean: 0.692, std: 0.116, avg_reward@stream: 0.59, avg_reward: 0.6, batch_value_loss: 0.431, batch_policy_loss: -22.628 | reward_len: 4398
# Stream: 59, user_count: 52, distance_mean: 0.692, std: 0.116, avg_reward@stream: 0.63, avg_reward: 0.6, batch_value_loss: 0.443, batch_policy_loss: -22.441 | reward_len: 4431
# Stream: 60, user_count: 7, distance_mean: 0.692, std: 0.116, avg_reward@stream: 1.29, avg_reward: 0.6, batch_value_loss: 0.295, batch_policy_loss: -22.671 | reward_len: 4438
# Stream: 61, user_count: 43, distance_mean: 0.692, std: 0.116, avg_reward@stream: 0.51, avg_reward: 0.6, batch_value_loss: 0.412, batch_policy_loss: -22.477 | reward_len: 4460
# Stream: 62, user_count: 33, distance_mean: 0.692, std: 0.116, avg_reward@stream: 0.85, avg_reward: 0.6, batch_value_loss: 0.476, batch_policy_loss: -22.711 | reward_len: 4488
# Stream: 63, user_count: 46, distance_mean: 0.692, std: 0.115, avg_reward@stream: 1.0, avg_reward: 0.61, batch_value_loss: 0.365, batch_policy_loss: -23.042 | reward_len: 4534
# Stream: 64, user_count: 2, distance_mean: 0.692, std: 0.115, avg_reward@stream: 1.0, avg_reward: 0.61, batch_value_loss: 0.249, batch_policy_loss: -23.744 | reward_len: 4536
# Stream: 65, user_count: 45, distance_mean: 0.692, std: 0.115, avg_reward@stream: 0.69, avg_reward: 0.61, batch_value_loss: 0.407, batch_policy_loss: -23.303 | reward_len: 4567
# Stream: 66, user_count: 15, distance_mean: 0.692, std: 0.115, avg_reward@stream: 0.6, avg_reward: 0.61, batch_value_loss: 0.293, batch_policy_loss: -23.817 | reward_len: 4575
# Stream: 67, user_count: 86, distance_mean: 0.692, std: 0.115, avg_reward@stream: 0.49, avg_reward: 0.61, batch_value_loss: 0.404, batch_policy_loss: -24.099 | reward_len: 4616
# Stream: 68, user_count: 33, distance_mean: 0.692, std: 0.115, avg_reward@stream: 1.0, avg_reward: 0.61, batch_value_loss: 0.478, batch_policy_loss: -24.171 | reward_len: 4649
# Stream: 69, user_count: 71, distance_mean: 0.692, std: 0.115, avg_reward@stream: 1.04, avg_reward: 0.61, batch_value_loss: 0.594, batch_policy_loss: -24.258 | reward_len: 4696
# Stream: 70, user_count: 10, distance_mean: 0.692, std: 0.115, avg_reward@stream: 1.4, avg_reward: 0.61, batch_value_loss: 0.259, batch_policy_loss: -24.463 | reward_len: 4706
# Stream: 71, user_count: 20, distance_mean: 0.692, std: 0.115, avg_reward@stream: 0.55, avg_reward: 0.61, batch_value_loss: 0.35, batch_policy_loss: -24.541 | reward_len: 4716
# Stream: 72, user_count: 24, distance_mean: 0.692, std: 0.115, avg_reward@stream: 1.29, avg_reward: 0.61, batch_value_loss: 0.798, batch_policy_loss: -24.448 | reward_len: 4733
# Stream: 73, user_count: 19, distance_mean: 0.692, std: 0.115, avg_reward@stream: 0.79, avg_reward: 0.61, batch_value_loss: 0.434, batch_policy_loss: -23.983 | reward_len: 4742
# Stream: 74, user_count: 45, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.71, avg_reward: 0.62, batch_value_loss: 0.787, batch_policy_loss: -24.45 | reward_len: 4781
# Stream: 75, user_count: 85, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.27, avg_reward: 0.62, batch_value_loss: 0.935, batch_policy_loss: -24.367 | reward_len: 4852
# Stream: 76, user_count: 21, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.24, avg_reward: 0.62, batch_value_loss: 1.384, batch_policy_loss: -24.178 | reward_len: 4869
# Stream: 77, user_count: 1, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.0, avg_reward: 0.62, batch_value_loss: 2.487, batch_policy_loss: -23.401 | reward_len: 4870
# Stream: 78, user_count: 12, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.0, avg_reward: 0.62, batch_value_loss: 1.621, batch_policy_loss: -24.263 | reward_len: 4882
# Stream: 79, user_count: 32, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.22, avg_reward: 0.63, batch_value_loss: 1.323, batch_policy_loss: -24.351 | reward_len: 4905
# Stream: 80, user_count: 24, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.83, avg_reward: 0.63, batch_value_loss: 1.476, batch_policy_loss: -25.007 | reward_len: 4929
# Stream: 81, user_count: 24, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.12, avg_reward: 0.63, batch_value_loss: 1.079, batch_policy_loss: -25.455 | reward_len: 4945
# Stream: 82, user_count: 8, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.12, avg_reward: 0.63, batch_value_loss: 0.613, batch_policy_loss: -25.782 | reward_len: 4953
# Stream: 83, user_count: 51, distance_mean: 0.692, std: 0.114, avg_reward@stream: 0.9, avg_reward: 0.63, batch_value_loss: 1.309, batch_policy_loss: -25.077 | reward_len: 4983
# Stream: 84, user_count: 15, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.27, avg_reward: 0.63, batch_value_loss: 1.38, batch_policy_loss: -25.414 | reward_len: 4998
# Stream: 85, user_count: 5, distance_mean: 0.692, std: 0.114, avg_reward@stream: 2.4, avg_reward: 0.63, batch_value_loss: 1.375, batch_policy_loss: -25.685 | reward_len: 5003
# Stream: 86, user_count: 6, distance_mean: 0.692, std: 0.114, avg_reward@stream: 2.17, avg_reward: 0.64, batch_value_loss: 2.775, batch_policy_loss: -24.429 | reward_len: 5009
# Stream: 87, user_count: 8, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.38, avg_reward: 0.64, batch_value_loss: 1.762, batch_policy_loss: -24.842 | reward_len: 5017
# Stream: 88, user_count: 2, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.5, avg_reward: 0.64, batch_value_loss: 1.733, batch_policy_loss: -24.047 | reward_len: 5019
# Stream: 89, user_count: 1, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.0, avg_reward: 0.64, batch_value_loss: 1.511, batch_policy_loss: -25.156 | reward_len: 5020
# Stream: 90, user_count: 36, distance_mean: 0.692, std: 0.114, avg_reward@stream: 1.75, avg_reward: 0.64, batch_value_loss: 1.608, batch_policy_loss: -24.918 | reward_len: 5056
# Stream: 91, user_count: 18, distance_mean: 0.692, std: 0.114, avg_reward@stream: 2.11, avg_reward: 0.64, batch_value_loss: 1.571, batch_policy_loss: -24.671 | reward_len: 5074
# Stream: 92, user_count: 42, distance_mean: 0.692, std: 0.114, avg_reward@stream: 0.86, avg_reward: 0.64, batch_value_loss: 1.351, batch_policy_loss: -25.429 | reward_len: 5094
# Stream: 93, user_count: 101, distance_mean: 0.692, std: 0.113, avg_reward@stream: 0.93, avg_reward: 0.65, batch_value_loss: 1.072, batch_policy_loss: -25.712 | reward_len: 5157
# Stream: 94, user_count: 58, distance_mean: 0.692, std: 0.113, avg_reward@stream: 0.45, avg_reward: 0.64, batch_value_loss: 0.867, batch_policy_loss: -25.941 | reward_len: 5176
# Stream: 95, user_count: 37, distance_mean: 0.693, std: 0.113, avg_reward@stream: 1.54, avg_reward: 0.65, batch_value_loss: 0.937, batch_policy_loss: -25.79 | reward_len: 5213
# Stream: 96, user_count: 9, distance_mean: 0.693, std: 0.113, avg_reward@stream: 1.89, avg_reward: 0.65, batch_value_loss: 0.743, batch_policy_loss: -26.204 | reward_len: 5222
# Stream: 97, user_count: 13, distance_mean: 0.693, std: 0.113, avg_reward@stream: 1.85, avg_reward: 0.65, batch_value_loss: 1.073, batch_policy_loss: -25.986 | reward_len: 5234
# Stream: 98, user_count: 26, distance_mean: 0.693, std: 0.113, avg_reward@stream: 1.88, avg_reward: 0.65, batch_value_loss: 1.075, batch_policy_loss: -25.775 | reward_len: 5260
# Stream: 99, user_count: 55, distance_mean: 0.693, std: 0.113, avg_reward@stream: 1.85, avg_reward: 0.66, batch_value_loss: 1.353, batch_policy_loss: -25.739 | reward_len: 5308
# Stream: 100, user_count: 3, distance_mean: 0.693, std: 0.113, avg_reward@stream: 1.0, avg_reward: 0.66, batch_value_loss: 1.361, batch_policy_loss: -25.848 | reward_len: 5311
# Stream: 101, user_count: 13, distance_mean: 0.693, std: 0.113, avg_reward@stream: 1.69, avg_reward: 0.66, batch_value_loss: 1.499, batch_policy_loss: -25.714 | reward_len: 5324
# Stream: 102, user_count: 13, distance_mean: 0.693, std: 0.113, avg_reward@stream: 0.92, avg_reward: 0.66, batch_value_loss: 1.632, batch_policy_loss: -26.145 | reward_len: 5333
# Stream: 103, user_count: 126, distance_mean: 0.693, std: 0.112, avg_reward@stream: 1.14, avg_reward: 0.67, batch_value_loss: 1.582, batch_policy_loss: -25.649 | reward_len: 5423
# Stream: 104, user_count: 37, distance_mean: 0.693, std: 0.112, avg_reward@stream: 1.16, avg_reward: 0.67, batch_value_loss: 1.252, batch_policy_loss: -25.322 | reward_len: 5452
# Stream: 105, user_count: 42, distance_mean: 0.693, std: 0.112, avg_reward@stream: 1.4, avg_reward: 0.67, batch_value_loss: 1.638, batch_policy_loss: -25.341 | reward_len: 5489
# Stream: 106, user_count: 56, distance_mean: 0.693, std: 0.112, avg_reward@stream: 1.14, avg_reward: 0.67, batch_value_loss: 1.427, batch_policy_loss: -25.439 | reward_len: 5526
# Stream: 107, user_count: 21, distance_mean: 0.693, std: 0.112, avg_reward@stream: 1.62, avg_reward: 0.68, batch_value_loss: 1.57, batch_policy_loss: -25.311 | reward_len: 5544
# Stream: 108, user_count: 17, distance_mean: 0.693, std: 0.112, avg_reward@stream: 1.65, avg_reward: 0.68, batch_value_loss: 1.246, batch_policy_loss: -25.456 | reward_len: 5559
# Stream: 109, user_count: 58, distance_mean: 0.693, std: 0.112, avg_reward@stream: 1.03, avg_reward: 0.68, batch_value_loss: 1.257, batch_policy_loss: -25.443 | reward_len: 5603
# Stream: 110, user_count: 30, distance_mean: 0.693, std: 0.112, avg_reward@stream: 0.83, avg_reward: 0.68, batch_value_loss: 1.62, batch_policy_loss: -25.146 | reward_len: 5621
# Stream: 111, user_count: 13, distance_mean: 0.693, std: 0.112, avg_reward@stream: 1.31, avg_reward: 0.68, batch_value_loss: 1.564, batch_policy_loss: -25.878 | reward_len: 5629
# Stream: 112, user_count: 34, distance_mean: 0.693, std: 0.112, avg_reward@stream: 1.47, avg_reward: 0.68, batch_value_loss: 1.651, batch_policy_loss: -25.667 | reward_len: 5652
# Stream: 113, user_count: 1, distance_mean: 0.693, std: 0.112, avg_reward@stream: 1.0, avg_reward: 0.68, batch_value_loss: 9.089, batch_policy_loss: -25.314 | reward_len: 5653
# Stream: 114, user_count: 117, distance_mean: 0.693, std: 0.112, avg_reward@stream: 0.55, avg_reward: 0.68, batch_value_loss: 1.279, batch_policy_loss: -25.542 | reward_len: 5700
# Stream: 115, user_count: 193, distance_mean: 0.693, std: 0.112, avg_reward@stream: 0.72, avg_reward: 0.68, batch_value_loss: 1.066, batch_policy_loss: -25.112 | reward_len: 5813
# Stream: 116, user_count: 16, distance_mean: 0.693, std: 0.111, avg_reward@stream: 1.56, avg_reward: 0.68, batch_value_loss: 1.576, batch_policy_loss: -24.55 | reward_len: 5829
# Stream: 117, user_count: 11, distance_mean: 0.693, std: 0.111, avg_reward@stream: 1.64, avg_reward: 0.68, batch_value_loss: 1.056, batch_policy_loss: -25.086 | reward_len: 5840
# Stream: 118, user_count: 118, distance_mean: 0.693, std: 0.111, avg_reward@stream: 1.04, avg_reward: 0.69, batch_value_loss: 0.979, batch_policy_loss: -25.145 | reward_len: 5917
# Stream: 119, user_count: 47, distance_mean: 0.694, std: 0.111, avg_reward@stream: 1.51, avg_reward: 0.69, batch_value_loss: 0.786, batch_policy_loss: -25.632 | reward_len: 5954
# Stream: 120, user_count: 48, distance_mean: 0.694, std: 0.111, avg_reward@stream: 0.46, avg_reward: 0.69, batch_value_loss: 1.256, batch_policy_loss: -25.803 | reward_len: 5973
# Stream: 121, user_count: 48, distance_mean: 0.694, std: 0.111, avg_reward@stream: 1.04, avg_reward: 0.69, batch_value_loss: 1.171, batch_policy_loss: -25.19 | reward_len: 6009
# Stream: 122, user_count: 11, distance_mean: 0.694, std: 0.111, avg_reward@stream: 1.27, avg_reward: 0.69, batch_value_loss: 1.241, batch_policy_loss: -24.982 | reward_len: 6020
# Stream: 123, user_count: 25, distance_mean: 0.694, std: 0.111, avg_reward@stream: 1.36, avg_reward: 0.69, batch_value_loss: 1.165, batch_policy_loss: -25.265 | reward_len: 6041
# Stream: 124, user_count: 23, distance_mean: 0.694, std: 0.111, avg_reward@stream: 1.61, avg_reward: 0.7, batch_value_loss: 1.091, batch_policy_loss: -25.209 | reward_len: 6064
# Stream: 125, user_count: 1, distance_mean: 0.694, std: 0.111, avg_reward@stream: 1.0, avg_reward: 0.7, batch_value_loss: 0.931, batch_policy_loss: -25.69 | reward_len: 6065
# Stream: 126, user_count: 41, distance_mean: 0.694, std: 0.111, avg_reward@stream: 1.49, avg_reward: 0.7, batch_value_loss: 1.722, batch_policy_loss: -25.431 | reward_len: 6101
# Stream: 127, user_count: 39, distance_mean: 0.694, std: 0.111, avg_reward@stream: 1.72, avg_reward: 0.7, batch_value_loss: 1.522, batch_policy_loss: -25.605 | reward_len: 6131
# Stream: 128, user_count: 22, distance_mean: 0.694, std: 0.111, avg_reward@stream: 1.36, avg_reward: 0.7, batch_value_loss: 1.299, batch_policy_loss: -25.507 | reward_len: 6149
# Stream: 129, user_count: 11, distance_mean: 0.694, std: 0.111, avg_reward@stream: 1.0, avg_reward: 0.7, batch_value_loss: 1.537, batch_policy_loss: -25.25 | reward_len: 6160
# Stream: 130, user_count: 25, distance_mean: 0.694, std: 0.111, avg_reward@stream: 1.64, avg_reward: 0.7, batch_value_loss: 2.014, batch_policy_loss: -25.068 | reward_len: 6183
# Stream: 131, user_count: 152, distance_mean: 0.694, std: 0.110, avg_reward@stream: 1.26, avg_reward: 0.71, batch_value_loss: 1.567, batch_policy_loss: -25.319 | reward_len: 6300
# Stream: 132, user_count: 1539, distance_mean: 0.694, std: 0.108, avg_reward@stream: 0.81, avg_reward: 0.72, batch_value_loss: 1.118, batch_policy_loss: -28.052 | reward_len: 7097
# Stream: 133, user_count: 402, distance_mean: 0.694, std: 0.107, avg_reward@stream: 0.2, avg_reward: 0.71, batch_value_loss: 1.049, batch_policy_loss: -31.27 | reward_len: 7176
# Stream: 134, user_count: 16, distance_mean: 0.694, std: 0.107, avg_reward@stream: 1.75, avg_reward: 0.71, batch_value_loss: 0.838, batch_policy_loss: -31.808 | reward_len: 7192
# Stream: 135, user_count: 74, distance_mean: 0.694, std: 0.107, avg_reward@stream: 1.51, avg_reward: 0.71, batch_value_loss: 1.409, batch_policy_loss: -31.808 | reward_len: 7266
# Stream: 136, user_count: 11, distance_mean: 0.694, std: 0.107, avg_reward@stream: 1.91, avg_reward: 0.71, batch_value_loss: 2.009, batch_policy_loss: -30.98 | reward_len: 7277
# Stream: 137, user_count: 17, distance_mean: 0.694, std: 0.107, avg_reward@stream: 0.71, avg_reward: 0.71, batch_value_loss: 2.075, batch_policy_loss: -31.752 | reward_len: 7284
# Stream: 138, user_count: 497, distance_mean: 0.694, std: 0.106, avg_reward@stream: 0.52, avg_reward: 0.71, batch_value_loss: 1.206, batch_policy_loss: -33.594 | reward_len: 7483
# Stream: 139, user_count: 7, distance_mean: 0.694, std: 0.106, avg_reward@stream: 1.29, avg_reward: 0.71, batch_value_loss: 0.971, batch_policy_loss: -34.443 | reward_len: 7490
# Stream: 140, user_count: 49, distance_mean: 0.694, std: 0.106, avg_reward@stream: 0.57, avg_reward: 0.71, batch_value_loss: 1.382, batch_policy_loss: -34.527 | reward_len: 7509
# Stream: 141, user_count: 5, distance_mean: 0.694, std: 0.106, avg_reward@stream: 1.0, avg_reward: 0.71, batch_value_loss: 1.015, batch_policy_loss: -34.535 | reward_len: 7514
# Stream: 142, user_count: 28, distance_mean: 0.694, std: 0.106, avg_reward@stream: 1.82, avg_reward: 0.71, batch_value_loss: 2.472, batch_policy_loss: -34.246 | reward_len: 7537
# Stream: 143, user_count: 94, distance_mean: 0.694, std: 0.106, avg_reward@stream: 1.65, avg_reward: 0.72, batch_value_loss: 1.999, batch_policy_loss: -35.255 | reward_len: 7631
# Stream: 144, user_count: 81, distance_mean: 0.695, std: 0.106, avg_reward@stream: 0.67, avg_reward: 0.72, batch_value_loss: 2.136, batch_policy_loss: -35.223 | reward_len: 7671
# Stream: 145, user_count: 1, distance_mean: 0.695, std: 0.106, avg_reward@stream: 1.0, avg_reward: 0.72, batch_value_loss: 0.943, batch_policy_loss: -35.078 | reward_len: 7672
# Stream: 146, user_count: 4, distance_mean: 0.695, std: 0.106, avg_reward@stream: 1.25, avg_reward: 0.72, batch_value_loss: 2.198, batch_policy_loss: -35.959 | reward_len: 7676
# Stream: 147, user_count: 18, distance_mean: 0.695, std: 0.106, avg_reward@stream: 0.78, avg_reward: 0.72, batch_value_loss: 1.725, batch_policy_loss: -36.438 | reward_len: 7688
# Stream: 148, user_count: 10, distance_mean: 0.695, std: 0.106, avg_reward@stream: 1.7, avg_reward: 0.72, batch_value_loss: 3.046, batch_policy_loss: -35.444 | reward_len: 7698
# Stream: 149, user_count: 24, distance_mean: 0.694, std: 0.106, avg_reward@stream: 1.25, avg_reward: 0.72, batch_value_loss: 2.873, batch_policy_loss: -35.285 | reward_len: 7717
# Stream: 150, user_count: 14, distance_mean: 0.695, std: 0.106, avg_reward@stream: 2.0, avg_reward: 0.72, batch_value_loss: 2.2, batch_policy_loss: -35.547 | reward_len: 7729
# Stream: 151, user_count: 24, distance_mean: 0.695, std: 0.106, avg_reward@stream: 1.33, avg_reward: 0.72, batch_value_loss: 4.962, batch_policy_loss: -34.809 | reward_len: 7746
# Stream: 152, user_count: 7, distance_mean: 0.695, std: 0.106, avg_reward@stream: 2.57, avg_reward: 0.72, batch_value_loss: 3.022, batch_policy_loss: -35.026 | reward_len: 7753
# Stream: 153, user_count: 289, distance_mean: 0.695, std: 0.106, avg_reward@stream: 0.41, avg_reward: 0.71, batch_value_loss: 2.195, batch_policy_loss: -35.893 | reward_len: 7857
# Stream: 154, user_count: 52, distance_mean: 0.695, std: 0.106, avg_reward@stream: 0.62, avg_reward: 0.71, batch_value_loss: 1.693, batch_policy_loss: -36.294 | reward_len: 7886
# Stream: 155, user_count: 119, distance_mean: 0.695, std: 0.105, avg_reward@stream: 0.51, avg_reward: 0.71, batch_value_loss: 1.906, batch_policy_loss: -36.801 | reward_len: 7938
# Stream: 156, user_count: 22, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.0, avg_reward: 0.71, batch_value_loss: 1.611, batch_policy_loss: -37.568 | reward_len: 7960
# Stream: 157, user_count: 33, distance_mean: 0.695, std: 0.105, avg_reward@stream: 0.55, avg_reward: 0.71, batch_value_loss: 1.513, batch_policy_loss: -37.475 | reward_len: 7973
# Stream: 158, user_count: 13, distance_mean: 0.695, std: 0.105, avg_reward@stream: 0.62, avg_reward: 0.71, batch_value_loss: 1.566, batch_policy_loss: -37.934 | reward_len: 7979
# Stream: 159, user_count: 7, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.0, avg_reward: 0.71, batch_value_loss: 5.892, batch_policy_loss: -36.799 | reward_len: 7986
# Stream: 160, user_count: 10, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.2, avg_reward: 0.71, batch_value_loss: 2.706, batch_policy_loss: -36.658 | reward_len: 7993
# Stream: 161, user_count: 34, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.26, avg_reward: 0.71, batch_value_loss: 2.489, batch_policy_loss: -37.561 | reward_len: 8019
# Stream: 162, user_count: 97, distance_mean: 0.695, std: 0.105, avg_reward@stream: 0.99, avg_reward: 0.72, batch_value_loss: 2.43, batch_policy_loss: -37.761 | reward_len: 8081
# Stream: 163, user_count: 19, distance_mean: 0.695, std: 0.105, avg_reward@stream: 0.95, avg_reward: 0.72, batch_value_loss: 2.938, batch_policy_loss: -37.788 | reward_len: 8096
# Stream: 164, user_count: 19, distance_mean: 0.695, std: 0.105, avg_reward@stream: 0.47, avg_reward: 0.72, batch_value_loss: 1.889, batch_policy_loss: -37.899 | reward_len: 8103
# Stream: 165, user_count: 35, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.0, avg_reward: 0.72, batch_value_loss: 2.496, batch_policy_loss: -38.309 | reward_len: 8138
# Stream: 166, user_count: 5, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.2, avg_reward: 0.72, batch_value_loss: 3.711, batch_policy_loss: -38.044 | reward_len: 8143
# Stream: 167, user_count: 29, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.93, avg_reward: 0.72, batch_value_loss: 2.595, batch_policy_loss: -38.598 | reward_len: 8172
# Stream: 168, user_count: 125, distance_mean: 0.695, std: 0.105, avg_reward@stream: 0.98, avg_reward: 0.72, batch_value_loss: 2.862, batch_policy_loss: -38.447 | reward_len: 8269
# Stream: 169, user_count: 17, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.65, avg_reward: 0.72, batch_value_loss: 2.571, batch_policy_loss: -38.845 | reward_len: 8286
# Stream: 170, user_count: 251, distance_mean: 0.695, std: 0.105, avg_reward@stream: 0.85, avg_reward: 0.72, batch_value_loss: 2.327, batch_policy_loss: -39.42 | reward_len: 8437
# Stream: 171, user_count: 21, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.38, avg_reward: 0.72, batch_value_loss: 2.515, batch_policy_loss: -39.53 | reward_len: 8458
# Stream: 172, user_count: 7, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.29, avg_reward: 0.72, batch_value_loss: 3.812, batch_policy_loss: -39.685 | reward_len: 8463
# Stream: 173, user_count: 24, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.33, avg_reward: 0.73, batch_value_loss: 2.487, batch_policy_loss: -39.515 | reward_len: 8483
# Stream: 174, user_count: 84, distance_mean: 0.695, std: 0.105, avg_reward@stream: 0.83, avg_reward: 0.73, batch_value_loss: 3.05, batch_policy_loss: -39.654 | reward_len: 8533
# Stream: 175, user_count: 4, distance_mean: 0.695, std: 0.105, avg_reward@stream: 1.25, avg_reward: 0.73, batch_value_loss: 3.579, batch_policy_loss: -40.979 | reward_len: 8537
# Stream: 176, user_count: 69, distance_mean: 0.695, std: 0.104, avg_reward@stream: 0.97, avg_reward: 0.73, batch_value_loss: 3.254, batch_policy_loss: -39.995 | reward_len: 8577
# Stream: 177, user_count: 20, distance_mean: 0.695, std: 0.104, avg_reward@stream: 1.8, avg_reward: 0.73, batch_value_loss: 3.48, batch_policy_loss: -40.383 | reward_len: 8597
# Stream: 178, user_count: 9, distance_mean: 0.695, std: 0.104, avg_reward@stream: 1.33, avg_reward: 0.73, batch_value_loss: 4.013, batch_policy_loss: -40.551 | reward_len: 8606
# Stream: 179, user_count: 61, distance_mean: 0.695, std: 0.104, avg_reward@stream: 0.56, avg_reward: 0.73, batch_value_loss: 3.649, batch_policy_loss: -40.515 | reward_len: 8633
# Stream: 180, user_count: 37, distance_mean: 0.695, std: 0.104, avg_reward@stream: 1.0, avg_reward: 0.73, batch_value_loss: 3.338, batch_policy_loss: -41.212 | reward_len: 8670
# Stream: 181, user_count: 21, distance_mean: 0.695, std: 0.104, avg_reward@stream: 1.57, avg_reward: 0.73, batch_value_loss: 2.891, batch_policy_loss: -40.69 | reward_len: 8691
# Stream: 182, user_count: 7, distance_mean: 0.695, std: 0.104, avg_reward@stream: 1.57, avg_reward: 0.73, batch_value_loss: 5.309, batch_policy_loss: -40.562 | reward_len: 8698
# Stream: 183, user_count: 19, distance_mean: 0.695, std: 0.104, avg_reward@stream: 1.79, avg_reward: 0.73, batch_value_loss: 4.306, batch_policy_loss: -40.736 | reward_len: 8717
# Stream: 184, user_count: 2637, distance_mean: 0.695, std: 0.102, avg_reward@stream: 0.26, avg_reward: 0.67, batch_value_loss: 2.207, batch_policy_loss: -46.472 | reward_len: 9300
# Stream: 185, user_count: 135, distance_mean: 0.695, std: 0.102, avg_reward@stream: 0.19, avg_reward: 0.66, batch_value_loss: 2.275, batch_policy_loss: -55.289 | reward_len: 9324
# Stream: 186, user_count: 47, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.85, avg_reward: 0.67, batch_value_loss: 3.177, batch_policy_loss: -55.483 | reward_len: 9367
# Stream: 187, user_count: 57, distance_mean: 0.695, std: 0.102, avg_reward@stream: 0.82, avg_reward: 0.67, batch_value_loss: 2.679, batch_policy_loss: -56.189 | reward_len: 9396
# Stream: 188, user_count: 12, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.42, avg_reward: 0.67, batch_value_loss: 6.25, batch_policy_loss: -56.338 | reward_len: 9408
# Stream: 189, user_count: 13, distance_mean: 0.695, std: 0.102, avg_reward@stream: 2.92, avg_reward: 0.67, batch_value_loss: 3.993, batch_policy_loss: -56.132 | reward_len: 9421
# Stream: 190, user_count: 4, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.25, avg_reward: 0.67, batch_value_loss: 3.477, batch_policy_loss: -55.31 | reward_len: 9425
# Stream: 191, user_count: 12, distance_mean: 0.695, std: 0.102, avg_reward@stream: 2.42, avg_reward: 0.67, batch_value_loss: 5.042, batch_policy_loss: -54.735 | reward_len: 9437
# Stream: 192, user_count: 32, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.94, avg_reward: 0.67, batch_value_loss: 4.127, batch_policy_loss: -56.204 | reward_len: 9469
# Stream: 193, user_count: 9, distance_mean: 0.695, std: 0.102, avg_reward@stream: 2.0, avg_reward: 0.67, batch_value_loss: 6.019, batch_policy_loss: -56.175 | reward_len: 9478
# Stream: 194, user_count: 5, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.0, avg_reward: 0.67, batch_value_loss: 3.099, batch_policy_loss: -56.243 | reward_len: 9483
# Stream: 195, user_count: 72, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.51, avg_reward: 0.68, batch_value_loss: 4.443, batch_policy_loss: -56.588 | reward_len: 9544
# Stream: 196, user_count: 30, distance_mean: 0.695, std: 0.102, avg_reward@stream: 2.0, avg_reward: 0.68, batch_value_loss: 6.443, batch_policy_loss: -55.254 | reward_len: 9573
# Stream: 197, user_count: 24, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.62, avg_reward: 0.68, batch_value_loss: 5.721, batch_policy_loss: -56.916 | reward_len: 9594
# Stream: 198, user_count: 103, distance_mean: 0.695, std: 0.102, avg_reward@stream: 0.87, avg_reward: 0.68, batch_value_loss: 5.386, batch_policy_loss: -56.841 | reward_len: 9652
# Stream: 199, user_count: 25, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.92, avg_reward: 0.68, batch_value_loss: 8.977, batch_policy_loss: -56.185 | reward_len: 9674
# Stream: 200, user_count: 55, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.67, avg_reward: 0.68, batch_value_loss: 5.86, batch_policy_loss: -56.608 | reward_len: 9722
# Stream: 201, user_count: 71, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.04, avg_reward: 0.69, batch_value_loss: 5.049, batch_policy_loss: -57.126 | reward_len: 9770
# Stream: 202, user_count: 11, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.55, avg_reward: 0.69, batch_value_loss: 4.365, batch_policy_loss: -58.335 | reward_len: 9781
# Stream: 203, user_count: 25, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.32, avg_reward: 0.69, batch_value_loss: 6.106, batch_policy_loss: -57.696 | reward_len: 9806
# Stream: 204, user_count: 10, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.5, avg_reward: 0.69, batch_value_loss: 7.216, batch_policy_loss: -58.132 | reward_len: 9816
# Stream: 205, user_count: 10, distance_mean: 0.695, std: 0.102, avg_reward@stream: 2.0, avg_reward: 0.69, batch_value_loss: 5.479, batch_policy_loss: -58.209 | reward_len: 9826
# Stream: 206, user_count: 17, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.06, avg_reward: 0.69, batch_value_loss: 5.15, batch_policy_loss: -58.712 | reward_len: 9843
# Stream: 207, user_count: 13, distance_mean: 0.695, std: 0.102, avg_reward@stream: 2.08, avg_reward: 0.69, batch_value_loss: 4.0, batch_policy_loss: -58.105 | reward_len: 9856
# Stream: 208, user_count: 14, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.36, avg_reward: 0.69, batch_value_loss: 12.032, batch_policy_loss: -57.929 | reward_len: 9870
# Stream: 209, user_count: 12, distance_mean: 0.695, std: 0.102, avg_reward@stream: 0.75, avg_reward: 0.69, batch_value_loss: 7.68, batch_policy_loss: -57.883 | reward_len: 9879
# Stream: 210, user_count: 33, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.79, avg_reward: 0.69, batch_value_loss: 9.459, batch_policy_loss: -57.757 | reward_len: 9908
# Stream: 211, user_count: 8, distance_mean: 0.695, std: 0.102, avg_reward@stream: 2.0, avg_reward: 0.69, batch_value_loss: 8.144, batch_policy_loss: -58.645 | reward_len: 9916
# Stream: 212, user_count: 97, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.66, avg_reward: 0.7, batch_value_loss: 8.789, batch_policy_loss: -57.885 | reward_len: 9996
# Stream: 213, user_count: 8, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.0, avg_reward: 0.7, batch_value_loss: 5.116, batch_policy_loss: -58.483 | reward_len: 10004
# Stream: 214, user_count: 57, distance_mean: 0.695, std: 0.102, avg_reward@stream: 0.84, avg_reward: 0.7, batch_value_loss: 6.711, batch_policy_loss: -59.131 | reward_len: 10039
# Stream: 215, user_count: 25, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.56, avg_reward: 0.7, batch_value_loss: 6.787, batch_policy_loss: -59.168 | reward_len: 10063
# Stream: 216, user_count: 7, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.29, avg_reward: 0.7, batch_value_loss: 6.152, batch_policy_loss: -58.841 | reward_len: 10070
# Stream: 217, user_count: 9, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.22, avg_reward: 0.7, batch_value_loss: 6.003, batch_policy_loss: -59.447 | reward_len: 10079
# Stream: 218, user_count: 67, distance_mean: 0.695, std: 0.102, avg_reward@stream: 2.25, avg_reward: 0.7, batch_value_loss: 6.966, batch_policy_loss: -59.503 | reward_len: 10146
# Stream: 219, user_count: 48, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.65, avg_reward: 0.71, batch_value_loss: 8.757, batch_policy_loss: -59.502 | reward_len: 10186
# Stream: 220, user_count: 34, distance_mean: 0.695, std: 0.102, avg_reward@stream: 0.62, avg_reward: 0.71, batch_value_loss: 6.757, batch_policy_loss: -60.284 | reward_len: 10200
# Stream: 221, user_count: 38, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.34, avg_reward: 0.71, batch_value_loss: 7.186, batch_policy_loss: -60.699 | reward_len: 10231
# Stream: 222, user_count: 68, distance_mean: 0.695, std: 0.102, avg_reward@stream: 0.5, avg_reward: 0.71, batch_value_loss: 8.341, batch_policy_loss: -60.729 | reward_len: 10257
# Stream: 223, user_count: 8, distance_mean: 0.695, std: 0.102, avg_reward@stream: 2.12, avg_reward: 0.71, batch_value_loss: 8.367, batch_policy_loss: -60.343 | reward_len: 10265
# Stream: 224, user_count: 3, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.0, avg_reward: 0.71, batch_value_loss: 7.84, batch_policy_loss: -59.645 | reward_len: 10268
# Stream: 225, user_count: 2, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.0, avg_reward: 0.71, batch_value_loss: 6.756, batch_policy_loss: -60.499 | reward_len: 10270
# Stream: 226, user_count: 7, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.29, avg_reward: 0.71, batch_value_loss: 12.028, batch_policy_loss: -60.771 | reward_len: 10277
# Stream: 227, user_count: 60, distance_mean: 0.695, std: 0.102, avg_reward@stream: 0.72, avg_reward: 0.71, batch_value_loss: 9.331, batch_policy_loss: -61.12 | reward_len: 10308
# Stream: 228, user_count: 2, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.0, avg_reward: 0.71, batch_value_loss: 7.794, batch_policy_loss: -60.998 | reward_len: 10310
# Stream: 229, user_count: 20, distance_mean: 0.695, std: 0.102, avg_reward@stream: 1.5, avg_reward: 0.71, batch_value_loss: 7.419, batch_policy_loss: -61.073 | reward_len: 10324
# Stream: 230, user_count: 41, distance_mean: 0.695, std: 0.101, avg_reward@stream: 0.95, avg_reward: 0.71, batch_value_loss: 9.321, batch_policy_loss: -61.425 | reward_len: 10351
# Stream: 231, user_count: 124, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.11, avg_reward: 0.71, batch_value_loss: 8.626, batch_policy_loss: -61.973 | reward_len: 10440
# Stream: 232, user_count: 13, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.46, avg_reward: 0.71, batch_value_loss: 7.141, batch_policy_loss: -63.711 | reward_len: 10453
# Stream: 233, user_count: 24, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.75, avg_reward: 0.71, batch_value_loss: 9.625, batch_policy_loss: -61.786 | reward_len: 10476
# Stream: 234, user_count: 84, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.25, avg_reward: 0.71, batch_value_loss: 7.572, batch_policy_loss: -62.507 | reward_len: 10538
# Stream: 235, user_count: 22, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.23, avg_reward: 0.72, batch_value_loss: 11.004, batch_policy_loss: -62.66 | reward_len: 10554
# Stream: 236, user_count: 35, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.86, avg_reward: 0.72, batch_value_loss: 9.09, batch_policy_loss: -62.58 | reward_len: 10587
# Stream: 237, user_count: 45, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.24, avg_reward: 0.72, batch_value_loss: 7.961, batch_policy_loss: -63.168 | reward_len: 10618
# Stream: 238, user_count: 39, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.54, avg_reward: 0.72, batch_value_loss: 8.029, batch_policy_loss: -64.011 | reward_len: 10650
# Stream: 239, user_count: 84, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.26, avg_reward: 0.72, batch_value_loss: 7.571, batch_policy_loss: -64.589 | reward_len: 10715
# Stream: 240, user_count: 10, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.7, avg_reward: 0.72, batch_value_loss: 8.455, batch_policy_loss: -64.806 | reward_len: 10725
# Stream: 241, user_count: 8, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.5, avg_reward: 0.72, batch_value_loss: 15.388, batch_policy_loss: -63.974 | reward_len: 10733
# Stream: 242, user_count: 10, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.6, avg_reward: 0.72, batch_value_loss: 7.424, batch_policy_loss: -64.706 | reward_len: 10743
# Stream: 243, user_count: 25, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.36, avg_reward: 0.72, batch_value_loss: 8.827, batch_policy_loss: -64.636 | reward_len: 10768
# Stream: 244, user_count: 6, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.5, avg_reward: 0.72, batch_value_loss: 15.064, batch_policy_loss: -65.696 | reward_len: 10774
# Stream: 245, user_count: 7, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.14, avg_reward: 0.72, batch_value_loss: 10.953, batch_policy_loss: -64.384 | reward_len: 10781
# Stream: 246, user_count: 90, distance_mean: 0.695, std: 0.101, avg_reward@stream: 0.84, avg_reward: 0.72, batch_value_loss: 9.526, batch_policy_loss: -64.728 | reward_len: 10838
# Stream: 247, user_count: 25, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.52, avg_reward: 0.73, batch_value_loss: 8.776, batch_policy_loss: -65.857 | reward_len: 10863
# Stream: 248, user_count: 25, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.28, avg_reward: 0.73, batch_value_loss: 8.057, batch_policy_loss: -65.449 | reward_len: 10888
# Stream: 249, user_count: 7, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.29, avg_reward: 0.73, batch_value_loss: 5.263, batch_policy_loss: -65.671 | reward_len: 10895
# Stream: 250, user_count: 10, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.7, avg_reward: 0.73, batch_value_loss: 14.251, batch_policy_loss: -65.009 | reward_len: 10905
# Stream: 251, user_count: 23, distance_mean: 0.695, std: 0.101, avg_reward@stream: 0.83, avg_reward: 0.73, batch_value_loss: 12.882, batch_policy_loss: -66.946 | reward_len: 10924
# Stream: 252, user_count: 28, distance_mean: 0.695, std: 0.101, avg_reward@stream: 2.0, avg_reward: 0.73, batch_value_loss: 10.027, batch_policy_loss: -66.559 | reward_len: 10950
# Stream: 253, user_count: 4, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.0, avg_reward: 0.73, batch_value_loss: 12.885, batch_policy_loss: -66.797 | reward_len: 10954
# Stream: 254, user_count: 64, distance_mean: 0.695, std: 0.101, avg_reward@stream: 0.97, avg_reward: 0.73, batch_value_loss: 11.494, batch_policy_loss: -66.952 | reward_len: 10992
# Stream: 255, user_count: 32, distance_mean: 0.695, std: 0.101, avg_reward@stream: 1.47, avg_reward: 0.73, batch_value_loss: 9.7, batch_policy_loss: -67.818 | reward_len: 11024
# Stream: 256, user_count: 1265, distance_mean: 0.695, std: 0.100, avg_reward@stream: 0.75, avg_reward: 0.73, batch_value_loss: 7.55, batch_policy_loss: -72.34 | reward_len: 11668
# Stream: 257, user_count: 14, distance_mean: 0.695, std: 0.100, avg_reward@stream: 1.57, avg_reward: 0.73, batch_value_loss: 4.863, batch_policy_loss: -78.375 | reward_len: 11682
# Stream: 258, user_count: 16, distance_mean: 0.695, std: 0.100, avg_reward@stream: 1.69, avg_reward: 0.73, batch_value_loss: 6.626, batch_policy_loss: -78.041 | reward_len: 11698
# Stream: 259, user_count: 28, distance_mean: 0.695, std: 0.100, avg_reward@stream: 0.36, avg_reward: 0.73, batch_value_loss: 9.682, batch_policy_loss: -78.374 | reward_len: 11708
# Stream: 260, user_count: 8, distance_mean: 0.695, std: 0.100, avg_reward@stream: 1.25, avg_reward: 0.73, batch_value_loss: 10.226, batch_policy_loss: -78.217 | reward_len: 11716
# Stream: 261, user_count: 122, distance_mean: 0.695, std: 0.100, avg_reward@stream: 1.17, avg_reward: 0.74, batch_value_loss: 8.096, batch_policy_loss: -79.226 | reward_len: 11802
# Stream: 262, user_count: 21, distance_mean: 0.695, std: 0.100, avg_reward@stream: 0.9, avg_reward: 0.74, batch_value_loss: 7.249, batch_policy_loss: -79.934 | reward_len: 11816
# Stream: 263, user_count: 34, distance_mean: 0.695, std: 0.100, avg_reward@stream: 0.74, avg_reward: 0.74, batch_value_loss: 7.767, batch_policy_loss: -79.874 | reward_len: 11833
# Stream: 264, user_count: 6, distance_mean: 0.695, std: 0.100, avg_reward@stream: 1.67, avg_reward: 0.74, batch_value_loss: 7.659, batch_policy_loss: -79.673 | reward_len: 11839
# Stream: 265, user_count: 23, distance_mean: 0.695, std: 0.100, avg_reward@stream: 1.43, avg_reward: 0.74, batch_value_loss: 9.758, batch_policy_loss: -80.383 | reward_len: 11858
# Stream: 266, user_count: 1335, distance_mean: 0.695, std: 0.099, avg_reward@stream: 0.76, avg_reward: 0.74, batch_value_loss: 7.184, batch_policy_loss: -86.595 | reward_len: 12552
# Stream: 267, user_count: 62, distance_mean: 0.695, std: 0.099, avg_reward@stream: 0.63, avg_reward: 0.74, batch_value_loss: 8.335, batch_policy_loss: -98.743 | reward_len: 12581
# Stream: 268, user_count: 29, distance_mean: 0.695, std: 0.099, avg_reward@stream: 1.24, avg_reward: 0.74, batch_value_loss: 9.095, batch_policy_loss: -99.625 | reward_len: 12604
# Stream: 269, user_count: 75, distance_mean: 0.695, std: 0.099, avg_reward@stream: 0.55, avg_reward: 0.74, batch_value_loss: 8.792, batch_policy_loss: -102.12 | reward_len: 12634
# Stream: 270, user_count: 16, distance_mean: 0.695, std: 0.099, avg_reward@stream: 1.75, avg_reward: 0.74, batch_value_loss: 9.368, batch_policy_loss: -102.404 | reward_len: 12650
# Stream: 271, user_count: 84, distance_mean: 0.695, std: 0.099, avg_reward@stream: 1.26, avg_reward: 0.74, batch_value_loss: 12.585, batch_policy_loss: -102.421 | reward_len: 12718
# ...
# Stream: 2748, user_count: 245, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.73, avg_reward: 1.03, batch_value_loss: 378436227.657, batch_policy_loss: -36535.522 | reward_len: 163802
# Stream: 2749, user_count: 51, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.16, avg_reward: 1.03, batch_value_loss: 363069640.784, batch_policy_loss: -36782.593 | reward_len: 163840
# Stream: 2750, user_count: 122, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.32, avg_reward: 1.03, batch_value_loss: 346335366.295, batch_policy_loss: -38154.59 | reward_len: 163870
# Stream: 2751, user_count: 3, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.33, avg_reward: 1.03, batch_value_loss: 289172906.667, batch_policy_loss: -34742.966 | reward_len: 163873
# Stream: 2752, user_count: 557, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.99, avg_reward: 1.03, batch_value_loss: 355474911.828, batch_policy_loss: -38344.262 | reward_len: 164351
# Stream: 2753, user_count: 2420, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.3, avg_reward: 1.02, batch_value_loss: 321838223.868, batch_policy_loss: -45623.679 | reward_len: 164978
# Stream: 2754, user_count: 260, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.84, avg_reward: 1.02, batch_value_loss: 349655355.077, batch_policy_loss: -51751.881 | reward_len: 165183
# Stream: 2755, user_count: 619, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.81, avg_reward: 1.03, batch_value_loss: 405332060.64, batch_policy_loss: -54259.502 | reward_len: 165692
# Stream: 2756, user_count: 169, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.01, avg_reward: 1.03, batch_value_loss: 419374122.414, batch_policy_loss: -55808.124 | reward_len: 165811
# Stream: 2757, user_count: 69, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.0, avg_reward: 1.03, batch_value_loss: 408382003.942, batch_policy_loss: -55636.167 | reward_len: 165880
# Stream: 2758, user_count: 87, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.52, avg_reward: 1.03, batch_value_loss: 427515056.552, batch_policy_loss: -56492.603 | reward_len: 165961
# Stream: 2759, user_count: 94, distance_mean: 0.700, std: 0.092, avg_reward@stream: 3.03, avg_reward: 1.03, batch_value_loss: 443931321.191, batch_policy_loss: -56729.436 | reward_len: 166052
# Stream: 2760, user_count: 225, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.81, avg_reward: 1.03, batch_value_loss: 447836724.338, batch_policy_loss: -57489.649 | reward_len: 166232
# Stream: 2761, user_count: 326, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.28, avg_reward: 1.03, batch_value_loss: 479884193.767, batch_policy_loss: -59005.08 | reward_len: 166537
# Stream: 2762, user_count: 4, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.5, avg_reward: 1.03, batch_value_loss: 367777632.0, batch_policy_loss: -62391.125 | reward_len: 166541
# Stream: 2776, user_count: 1510, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.78, avg_reward: 1.03, batch_value_loss: 467113568.975, batch_policy_loss: -75977.542 | reward_len: 168670
# Stream: 2777, user_count: 97, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.49, avg_reward: 1.03, batch_value_loss: 460350157.856, batch_policy_loss: -80613.227 | reward_len: 168745
# Stream: 2778, user_count: 336, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.48, avg_reward: 1.03, batch_value_loss: 466225395.81, batch_policy_loss: -84247.845 | reward_len: 168995
# Stream: 2779, user_count: 223, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.72, avg_reward: 1.03, batch_value_loss: 456389067.193, batch_policy_loss: -88875.247 | reward_len: 169125
# Stream: 2780, user_count: 210, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.52, avg_reward: 1.03, batch_value_loss: 473569689.6, batch_policy_loss: -91053.219 | reward_len: 169289
# Stream: 2781, user_count: 422, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.95, avg_reward: 1.03, batch_value_loss: 485407331.488, batch_policy_loss: -91625.678 | reward_len: 169626
# Stream: 2782, user_count: 70, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.57, avg_reward: 1.03, batch_value_loss: 453210404.571, batch_policy_loss: -92185.929 | reward_len: 169690
# Stream: 2783, user_count: 12, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.0, avg_reward: 1.03, batch_value_loss: 428247210.667, batch_policy_loss: -96689.031 | reward_len: 169702
# Stream: 2784, user_count: 45, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.38, avg_reward: 1.03, batch_value_loss: 474524239.644, batch_policy_loss: -94184.989 | reward_len: 169743
# Stream: 2785, user_count: 46, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.65, avg_reward: 1.03, batch_value_loss: 480024576.0, batch_policy_loss: -93550.663 | reward_len: 169784
# Stream: 2786, user_count: 174, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.0, avg_reward: 1.03, batch_value_loss: 489513713.287, batch_policy_loss: -93484.845 | reward_len: 169926
# Stream: 2797, user_count: 312, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.78, avg_reward: 1.02, batch_value_loss: 465522793.026, batch_policy_loss: -123658.59 | reward_len: 172151
# Stream: 2798, user_count: 48, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.17, avg_reward: 1.02, batch_value_loss: 543735637.333, batch_policy_loss: -122308.115 | reward_len: 172199
# Stream: 2799, user_count: 17, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.0, avg_reward: 1.02, batch_value_loss: 558156559.059, batch_policy_loss: -124406.868 | reward_len: 172216
# Stream: 2800, user_count: 247, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.24, avg_reward: 1.03, batch_value_loss: 538945942.283, batch_policy_loss: -125444.599 | reward_len: 172436
# Stream: 2801, user_count: 5, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.4, avg_reward: 1.03, batch_value_loss: 465391513.6, batch_policy_loss: -127748.425 | reward_len: 172441
# Stream: 2802, user_count: 42, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.64, avg_reward: 1.03, batch_value_loss: 520401822.476, batch_policy_loss: -124113.905 | reward_len: 172470
# Stream: 2803, user_count: 71, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.93, avg_reward: 1.03, batch_value_loss: 526161083.493, batch_policy_loss: -124486.493 | reward_len: 172508
# Stream: 2804, user_count: 468, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.35, avg_reward: 1.02, batch_value_loss: 501389749.607, batch_policy_loss: -124098.051 | reward_len: 172651
# Stream: 2805, user_count: 17, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.18, avg_reward: 1.02, batch_value_loss: 497529374.118, batch_policy_loss: -120529.926 | reward_len: 172666
# Stream: 2806, user_count: 286, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.51, avg_reward: 1.03, batch_value_loss: 499959936.895, batch_policy_loss: -123498.434 | reward_len: 172919
# Stream: 2807, user_count: 66, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.88, avg_reward: 1.03, batch_value_loss: 529414764.606, batch_policy_loss: -126305.136 | reward_len: 172951
# Stream: 2808, user_count: 28, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.25, avg_reward: 1.03, batch_value_loss: 530045330.286, batch_policy_loss: -126087.464 | reward_len: 172976
# Stream: 2809, user_count: 28, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.5, avg_reward: 1.03, batch_value_loss: 500326400.0, batch_policy_loss: -125478.116 | reward_len: 172997
# Stream: 2810, user_count: 128, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.23, avg_reward: 1.03, batch_value_loss: 519241344.0, batch_policy_loss: -124099.266 | reward_len: 173107
# Stream: 2811, user_count: 281, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.97, avg_reward: 1.03, batch_value_loss: 531411949.779, batch_policy_loss: -126856.826 | reward_len: 173347
# Stream: 2812, user_count: 106, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.77, avg_reward: 1.03, batch_value_loss: 512114224.302, batch_policy_loss: -127832.151 | reward_len: 173435
# Stream: 2813, user_count: 32, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.0, avg_reward: 1.03, batch_value_loss: 544604928.0, batch_policy_loss: -125332.969 | reward_len: 173467
# Stream: 2814, user_count: 367, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.35, avg_reward: 1.03, batch_value_loss: 533592103.063, batch_policy_loss: -127146.191 | reward_len: 173740
# Stream: 2815, user_count: 356, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.62, avg_reward: 1.03, batch_value_loss: 524631373.663, batch_policy_loss: -129946.787 | reward_len: 174017
# Stream: 2816, user_count: 37, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.73, avg_reward: 1.03, batch_value_loss: 535750656.0, batch_policy_loss: -131827.824 | reward_len: 174040
# Stream: 2817, user_count: 158, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.46, avg_reward: 1.03, batch_value_loss: 576265151.19, batch_policy_loss: -131655.519 | reward_len: 174179
# Stream: 2818, user_count: 745, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.63, avg_reward: 1.03, batch_value_loss: 628730787.909, batch_policy_loss: -128935.817 | reward_len: 174553
# Stream: 2819, user_count: 32, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.91, avg_reward: 1.03, batch_value_loss: 709212864.0, batch_policy_loss: -127569.633 | reward_len: 174574
# Stream: 2820, user_count: 31, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.35, avg_reward: 1.03, batch_value_loss: 683873577.29, batch_policy_loss: -125513.645 | reward_len: 174584
# Stream: 2821, user_count: 3455, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.5, avg_reward: 1.02, batch_value_loss: 498833627.915, batch_policy_loss: -133238.979 | reward_len: 175940
# Stream: 2822, user_count: 4, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.25, avg_reward: 1.02, batch_value_loss: 515554144.0, batch_policy_loss: -142909.688 | reward_len: 175944
# Stream: 2823, user_count: 387, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.88, avg_reward: 1.02, batch_value_loss: 562848738.894, batch_policy_loss: -143278.45 | reward_len: 176164
# Stream: 2824, user_count: 602, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.54, avg_reward: 1.02, batch_value_loss: 576560580.465, batch_policy_loss: -145921.475 | reward_len: 176625
# Stream: 2825, user_count: 5, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.6, avg_reward: 1.02, batch_value_loss: 844298342.4, batch_policy_loss: -142739.025 | reward_len: 176630
# Stream: 2826, user_count: 56, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.71, avg_reward: 1.02, batch_value_loss: 579599762.286, batch_policy_loss: -144684.098 | reward_len: 176659
# Stream: 2827, user_count: 12, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.75, avg_reward: 1.02, batch_value_loss: 591451818.667, batch_policy_loss: -143644.667 | reward_len: 176664
# Stream: 2828, user_count: 5, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.4, avg_reward: 1.02, batch_value_loss: 535607193.6, batch_policy_loss: -154179.6 | reward_len: 176669
# Stream: 2829, user_count: 58, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.95, avg_reward: 1.02, batch_value_loss: 610428151.172, batch_policy_loss: -143420.483 | reward_len: 176708
# Stream: 2830, user_count: 22, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.45, avg_reward: 1.02, batch_value_loss: 584178688.0, batch_policy_loss: -145823.807 | reward_len: 176724
# Stream: 2831, user_count: 186, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.09, avg_reward: 1.02, batch_value_loss: 608718539.699, batch_policy_loss: -146084.247 | reward_len: 176843
# Stream: 2832, user_count: 82, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.77, avg_reward: 1.02, batch_value_loss: 652391998.439, batch_policy_loss: -146877.537 | reward_len: 176884
# Stream: 2833, user_count: 18, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.11, avg_reward: 1.02, batch_value_loss: 615286385.778, batch_policy_loss: -145970.583 | reward_len: 176898
# Stream: 2834, user_count: 386, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.61, avg_reward: 1.02, batch_value_loss: 634136480.497, batch_policy_loss: -146698.694 | reward_len: 177190
# Stream: 2835, user_count: 17, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.12, avg_reward: 1.02, batch_value_loss: 616443723.294, batch_policy_loss: -146444.632 | reward_len: 177207
# Stream: 2836, user_count: 185, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.5, avg_reward: 1.03, batch_value_loss: 624473857.384, batch_policy_loss: -146456.714 | reward_len: 177388
# Stream: 2837, user_count: 390, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.69, avg_reward: 1.02, batch_value_loss: 655532830.195, batch_policy_loss: -147715.333 | reward_len: 177587
# Stream: 2838, user_count: 5, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.8, avg_reward: 1.02, batch_value_loss: 754973081.6, batch_policy_loss: -137119.6 | reward_len: 177592
# Stream: 2839, user_count: 22, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.91, avg_reward: 1.02, batch_value_loss: 631580206.545, batch_policy_loss: -147040.295 | reward_len: 177614
# Stream: 2840, user_count: 433, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.11, avg_reward: 1.03, batch_value_loss: 662843514.975, batch_policy_loss: -146670.42 | reward_len: 178002
# Stream: 2841, user_count: 2, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.0, avg_reward: 1.03, batch_value_loss: 877294720.0, batch_policy_loss: -145113.984 | reward_len: 178004
# Stream: 2842, user_count: 2266, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.35, avg_reward: 1.02, batch_value_loss: 662880733.204, batch_policy_loss: -156730.634 | reward_len: 178660
# Stream: 2843, user_count: 332, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.18, avg_reward: 1.02, batch_value_loss: 690284075.181, batch_policy_loss: -169637.699 | reward_len: 178941
# Stream: 2844, user_count: 56, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.82, avg_reward: 1.02, batch_value_loss: 749395529.143, batch_policy_loss: -170311.714 | reward_len: 178969
# Stream: 2845, user_count: 115, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.39, avg_reward: 1.02, batch_value_loss: 698600082.922, batch_policy_loss: -171648.87 | reward_len: 179007
# Stream: 2846, user_count: 29, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.83, avg_reward: 1.02, batch_value_loss: 821869673.931, batch_policy_loss: -172246.879 | reward_len: 179027
# Stream: 2847, user_count: 39, distance_mean: 0.700, std: 0.092, avg_reward@stream: 2.03, avg_reward: 1.02, batch_value_loss: 703311819.487, batch_policy_loss: -173506.641 | reward_len: 179060
# Stream: 2848, user_count: 62, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.74, avg_reward: 1.02, batch_value_loss: 742229223.226, batch_policy_loss: -173388.29 | reward_len: 179114
# Stream: 2849, user_count: 243, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.94, avg_reward: 1.02, batch_value_loss: 796579966.42, batch_policy_loss: -174736.988 | reward_len: 179301
# Stream: 2850, user_count: 37, distance_mean: 0.700, std: 0.092, avg_reward@stream: 0.38, avg_reward: 1.02, batch_value_loss: 796088984.216, batch_policy_loss: -179066.595 | reward_len: 179313
# Stream: 2851, user_count: 256, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.62, avg_reward: 1.02, batch_value_loss: 745712512.0, batch_policy_loss: -176951.219 | reward_len: 179507
# Stream: 2852, user_count: 36, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.03, avg_reward: 1.02, batch_value_loss: 860620856.889, batch_policy_loss: -176482.25 | reward_len: 179543
# Stream: 2853, user_count: 462, distance_mean: 0.700, std: 0.092, avg_reward@stream: 1.21, avg_reward: 1.02, batch_value_loss: 830595533.022, batch_policy_loss: -178442.805 | reward_len: 179849

# %%
mode
# Out:
# 'diff_svd'

# %%
diff_items = {'mode': f'{mode}_AX_27', 'reward_records': reward_records, 'avg_rewards': avg_rewards}

with open(f'results/hybrid_{mode}_AX_27.pkl', 'wb') as handle:
    pickle.dump(diff_items, handle, protocol=pickle.HIGHEST_PROTOCOL)

torch.save(ddpg_agent, f'models/hybrid_{mode}_AX_27.pth')

model = torch.load(f'models/hybrid_{mode}_AX_27.pth')

model.depsilon == ddpg_agent.depsilon
# Out:
# True

# %%
np.round(np.mean([1, 324, 6,5345, 35, 645, 656 ,34, 
56721,1, 4, 456 ,43,74]), 3)
# Out:
# 4596.071
